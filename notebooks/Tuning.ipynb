# %%
import numpy as np
import modin.pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

from src.model_selection import XGBGridSearch
import src.model_builder as mb
import src.data_handling as dh

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Input selection

# %%
genes = ["ESR1", "ERBB2", "CDK4"]

# %%
VS = dh.VariableSelector("Cancer")

# %%
VS.compute_corr(["ESR1", "ERBB2", "CDK4"], verbose=1)

# %%
datasets = {}

for gene in genes:
    datasets[gene] = {}
    print(gene)
    nan_share=0.2
    X, Y, datasets[gene]["alpha"] = VS.extract_data(gene, nan_limit=nan_share, select_n=1000, verbose=1)
    datasets[gene]["X_train"], datasets[gene]["X_test"], datasets[gene]["y_train"], datasets[gene]["y_test"] = train_test_split(X, Y, random_state=10)
# Out:
# ESR1
# Selected 1002 input genes with alpha = 4e-19
# ERBB2
# Selected 999 input genes with alpha = 9e-14
# CDK4
# Selected 998 input genes with alpha = 9e-09

# %%
datasets["ESR1"]["X_train"]
# Out:
# Genes                          FAM87B     RPL22   TNFRSF9      ENO1  \
# sc5rJUQ064_GGGATGACAGCCAGAA -0.040507 -2.981073 -0.077511 -0.539985
# sc5rJUQ064_AACACGTGTAGGAGTC -0.027225  0.669832 -0.055435 -0.732615
# sc5rJUQ064_CAAGTTGTCTCTTATG -0.025901  0.061817 -0.054697 -0.765161
# sc5rJUQ064_GCATGTACATCGATGT -0.038889  0.638745 -0.075866 -0.572964
# sc5rJUQ042_ACTTTCACAACTGGCC       NaN  0.630844 -0.115187 -0.977357
# ...                               ...       ...       ...       ...
# sc5rJUQ064_CTGAAGTGTTCTCATT -0.023381  0.940060 -0.050904  1.199757
# sc5rJUQ064_AGCGTATTCACTGGGC -0.011083  0.224024 -0.023634  0.253006
# sc5rJUQ064_ATGGGAGCACGAGAGT -0.045860 -2.888776 -0.085712 -0.455983
# sc5rJUQ060_CAAGATCGTCGCATAT       NaN -0.366404 -0.331424  0.708166
# sc5rJUQ064_ATCACGAGTCATGCCG -0.008646  0.272586 -0.019295  0.169485
#
# Genes                        PIK3CD-AS1     CASZ1  TNFRSF1B      PDPN  \
# sc5rJUQ064_GGGATGACAGCCAGAA   -0.004778 -0.364339 -0.156292 -0.082028
# sc5rJUQ064_AACACGTGTAGGAGTC   -0.008979  1.718793 -0.172866 -0.062008
# sc5rJUQ064_CAAGTTGTCTCTTATG   -0.005598  1.827977 -0.186279 -0.056509
# sc5rJUQ064_GCATGTACATCGATGT   -0.002580 -0.384476 -0.166700 -0.077091
# sc5rJUQ042_ACTTTCACAACTGGCC   -0.048998 -0.229638 -0.532176 -0.157765
# ...                                 ...       ...       ...       ...
# sc5rJUQ064_CTGAAGTGTTCTCATT   -0.005368  1.681674 -0.192605 -0.051763
# sc5rJUQ064_AGCGTATTCACTGGGC   -0.026992  0.515000 -0.153063 -0.049573
# sc5rJUQ064_ATGGGAGCACGAGAGT   -0.004896  4.552282 -0.144006 -0.091767
# sc5rJUQ060_CAAGATCGTCGCATAT   -0.057387 -1.356438 -0.645021 -0.231668
# sc5rJUQ064_ATCACGAGTCATGCCG   -0.028508  0.418684 -0.153797 -0.046587
#
# Genes                         C1orf64    AKR7A3  ...      TTC3    KCNJ15  \
# sc5rJUQ064_GGGATGACAGCCAGAA -0.325266 -0.671143  ...  1.898622 -0.025446
# sc5rJUQ064_AACACGTGTAGGAGTC -0.458159 -0.878003  ... -1.253620 -0.032419
# sc5rJUQ064_CAAGTTGTCTCTTATG -0.467202 -0.872744  ...  0.547933 -0.035644
# sc5rJUQ064_GCATGTACATCGATGT -0.338452 -0.677877  ... -0.978254 -0.028100
# sc5rJUQ042_ACTTTCACAACTGGCC -0.179881 -0.125896  ...  1.843025 -0.059322
# ...                               ...       ...  ...       ...       ...
# sc5rJUQ064_CTGAAGTGTTCTCATT -0.491280 -0.904996  ...  0.406238 -0.037651
# sc5rJUQ064_AGCGTATTCACTGGGC  0.855573  0.144889  ... -0.618947 -0.032298
# sc5rJUQ064_ATGGGAGCACGAGAGT -0.273706 -0.600101  ... -0.818403 -0.021430
# sc5rJUQ060_CAAGATCGTCGCATAT  0.822488 -0.485026  ...  0.509268 -0.064176
# sc5rJUQ064_ATCACGAGTCATGCCG  0.765943 -1.260353  ...  1.244796 -0.033081
#
# Genes                           FAM3B      TFF3      TFF1     ITGB2  \
# sc5rJUQ064_GGGATGACAGCCAGAA -0.765579 -1.062341 -0.302562 -0.334146
# sc5rJUQ064_AACACGTGTAGGAGTC  0.636292 -0.590149 -0.419319 -0.245397
# sc5rJUQ064_CAAGTTGTCTCTTATG  1.448845 -0.531230 -0.398638 -0.229772
# sc5rJUQ064_GCATGTACATCGATGT -0.783297  0.361282 -0.293728 -0.318502
# sc5rJUQ042_ACTTTCACAACTGGCC  5.846013 -0.153702 -0.043188 -0.600267
# ...                               ...       ...       ...       ...
# sc5rJUQ064_CTGAAGTGTTCTCATT -1.053871 -1.225674 -0.412052 -0.211099
# sc5rJUQ064_AGCGTATTCACTGGGC  0.173091 -0.292155 -0.671001 -0.160558
# sc5rJUQ064_ATGGGAGCACGAGAGT -0.676737 -1.014555 -0.270906 -0.373148
# sc5rJUQ060_CAAGATCGTCGCATAT -0.620946 -1.429620 -0.683809 -0.957840
# sc5rJUQ064_ATCACGAGTCATGCCG  0.456015 -1.250759 -0.698767 -0.145602
#
# Genes                        LINC00315   COL18A1    COL6A1    COL6A2
# sc5rJUQ064_GGGATGACAGCCAGAA   0.020172 -0.438571 -0.386839 -0.453190
# sc5rJUQ064_AACACGTGTAGGAGTC  -0.007831 -0.362126 -0.299089 -0.353099
# sc5rJUQ064_CAAGTTGTCTCTTATG  -0.016913 -0.365012 -0.292922 -0.349222
# sc5rJUQ064_GCATGTACATCGATGT   0.012275 -0.436754 -0.377993 -0.445351
# sc5rJUQ042_ACTTTCACAACTGGCC  -0.017680 -0.518237 -0.552497 -0.559723
# ...                                ...       ...       ...       ...
# sc5rJUQ064_CTGAAGTGTTCTCATT  -0.023928  2.141783 -0.276969 -0.331880
# sc5rJUQ064_AGCGTATTCACTGGGC  -0.020500 -0.233534 -0.183674 -0.210731
# sc5rJUQ064_ATGGGAGCACGAGAGT   0.034458 -0.464375 -0.420978 -0.490625
# sc5rJUQ060_CAAGATCGTCGCATAT        NaN -0.428910 -0.289539 -0.288277
# sc5rJUQ064_ATCACGAGTCATGCCG  -0.024404 -0.217445 -0.167065 -0.191167
#
# [2378 rows x 1002 columns]

# %%
# %matplotlib inline
datasets["ERBB2"]["y_train"].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Low learning rate experiment
# With a signicantly lower learning rate the model can likely achieve higher accuracy, but at a great computational cost. The number of estimators with a lower learning rate is in the thousands instead of a few hundred. The gain in accuracy also seems to be quite low with the cross validated results for ESR1 being RMSE=1.1. However, if the model below could run to 10000 it might have found an even lower minimum though it improves very slowly.

# %%
ESR1_train = xgb.DMatrix(datasets["ESR1"]["X_train"], label=datasets["ESR1"]["y_train"])

# %%
ESR1_test = xgb.DMatrix(datasets["ESR1"]["X_test"], label=datasets["ESR1"]["y_test"])

# %%
params = {
    "eta": 0.002,
    "max_depth": 3,
    "objective": "reg:squarederror",
    "subsample": 0.5
}
model_train = xgb.train(params, ESR1_train, 10000, evals = [(ESR1_test, "test")], verbose_eval=100)
# Out:
# [0]	test-rmse:2.12323
# [100]	test-rmse:1.95993
# [200]	test-rmse:1.82963
# [300]	test-rmse:1.72123
# [400]	test-rmse:1.63695
# [500]	test-rmse:1.56433
# [600]	test-rmse:1.50471
# [700]	test-rmse:1.45359
# [800]	test-rmse:1.41119
# [900]	test-rmse:1.37473
# [1000]	test-rmse:1.34469
# [1100]	test-rmse:1.31744
# [1200]	test-rmse:1.29311
# [1300]	test-rmse:1.27130
# [1400]	test-rmse:1.25286
# [1500]	test-rmse:1.23705
# [1600]	test-rmse:1.22192
# [1700]	test-rmse:1.20933
# [1800]	test-rmse:1.19803
# [1900]	test-rmse:1.18786
# [2000]	test-rmse:1.17840
# [2100]	test-rmse:1.17022
# [2200]	test-rmse:1.16299
# [2300]	test-rmse:1.15617
# [2400]	test-rmse:1.14933
# [2500]	test-rmse:1.14301
# [2600]	test-rmse:1.13778
# [2700]	test-rmse:1.13258
# [2800]	test-rmse:1.12795
# [2900]	test-rmse:1.12396
# [3000]	test-rmse:1.12028
# [3100]	test-rmse:1.11697
# [3200]	test-rmse:1.11389
# [3300]	test-rmse:1.11130
# [3400]	test-rmse:1.10911
# [3500]	test-rmse:1.10674
# [3600]	test-rmse:1.10465
# [3700]	test-rmse:1.10216
# [3800]	test-rmse:1.10012
# [3900]	test-rmse:1.09821
# [4000]	test-rmse:1.09679
# [4100]	test-rmse:1.09519
# [4200]	test-rmse:1.09404
# [4300]	test-rmse:1.09280
# [4400]	test-rmse:1.09143
# [4500]	test-rmse:1.09019
# [4600]	test-rmse:1.08903
# [4700]	test-rmse:1.08822
# [4800]	test-rmse:1.08738
# [4900]	test-rmse:1.08659
# [5000]	test-rmse:1.08616
# [5100]	test-rmse:1.08543
# [5200]	test-rmse:1.08478
# [5300]	test-rmse:1.08432
# [5400]	test-rmse:1.08345
# [5500]	test-rmse:1.08282
# [5600]	test-rmse:1.08255
# [5700]	test-rmse:1.08182
# [5800]	test-rmse:1.08133
# [5900]	test-rmse:1.08087
# [6000]	test-rmse:1.08054
# [6100]	test-rmse:1.08010
# [6200]	test-rmse:1.07991
# [6300]	test-rmse:1.07942
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-82e1306d6aaa> in <module>
#       5     "subsample": 0.5
#       6 }
# ----> 7 model_train = xgb.train(params, ESR1_train, 10000, evals = [(ESR1_test, "test")], verbose_eval=100)
#
# /data/severs/miniconda3/envs/ml-severs/lib/python3.9/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     225     Booster : a trained booster model
#     226     """
# --> 227     bst = _train_internal(params, dtrain,
#     228                           num_boost_round=num_boost_round,
#     229                           evals=evals,
#
# /data/severs/miniconda3/envs/ml-severs/lib/python3.9/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#     100         # Skip the first update if it is a recovery step.
#     101         if version % 2 == 0:
# --> 102             bst.update(dtrain, i, obj)
#     103             bst.save_rabit_checkpoint()
#     104             version += 1
#
# /data/severs/miniconda3/envs/ml-severs/lib/python3.9/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1278
#    1279         if fobj is None:
# -> 1280             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1281                                                     ctypes.c_int(iteration),
#    1282                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Tuning

# %%
# The base model used for tuning
xgb1 = xgb.XGBRegressor(objective="reg:squarederror", 
                   seed=1, 
                   learning_rate=0.03, 
                   n_estimators=1000, 
                   n_jobs=80, max_depth=3, 
                   colsample_bytree=1,
                   subsample=1, verbosity=0, silent=True)

# %%
param_test1 = {
   'learning_rate' : [0.03, 0.05, 0.07],
    'max_depth' : [3,5,7],
    'min_child_weight' : [1, 3, 5, 7]
}

# %%
results = {}
for gene in genes:
    print(f"STARTING SEARCH FOR {gene.upper()}")
    print("===========================================================")
    GS1 = XGBGridSearch(xgb1, param_test1, cv=5)
    X = datasets[gene]["X_train"]
    Y = datasets[gene]["y_train"]
    GS1.fit(X, Y)
    results[gene] = GS1
# Out:
# STARTING SEARCH FOR ESR1
# ===========================================================
# Fitting 5 folds for each of 36 candidates, totalling 180 fits.
# Fitting candidate 1 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0889     std: 0.0434       n iter: 1000
#     Train Result: 0.3447     std: 0.0088
#     elapsed time: 0:33, 5 fold time: 0:33
#     time left: 19: 8
#
#
#
# Fitting candidate 2 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0847     std: 0.0447       n iter: 1000
#     Train Result: 0.3400     std: 0.0095
#     elapsed time: 1: 6, 5 fold time: 0:33
#     time left: 18:47
#
#
#
# Fitting candidate 3 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 5
#     Test Result: 1.0840     std: 0.0412       n iter: 1000
#     Train Result: 0.3438     std: 0.0049
#     elapsed time: 1:40, 5 fold time: 0:33
#     time left: 18:16
#
#
#
# Fitting candidate 4 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0952     std: 0.0422       n iter: 1000
#     Train Result: 0.3479     std: 0.0060
#     elapsed time: 2:13, 5 fold time: 0:34
#     time left: 17:45
#
#
#
# Fitting candidate 5 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 1
#     Test Result: 1.0841     std: 0.0628       n iter: 873
#     Train Result: 0.0826     std: 0.0047
#     elapsed time: 3: 1, 5 fold time: 0:48
#     time left: 18:42
#
#
#
# Fitting candidate 6 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 3
#     Test Result: 1.0761     std: 0.0548       n iter: 1000
#     Train Result: 0.0602     std: 0.0048
#     elapsed time: 3:51, 5 fold time: 0:50
#     time left: 19:16
#
#
#
# Fitting candidate 7 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0696     std: 0.0597       n iter: 846
#     Train Result: 0.0883     std: 0.0054
#     elapsed time: 4:39, 5 fold time: 0:48
#     time left: 19:17
#
#
#
# Fitting candidate 8 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 7
#     Test Result: 1.0711     std: 0.0516       n iter: 724
#     Train Result: 0.1270     std: 0.0081
#     elapsed time: 5:20, 5 fold time: 0:41
#     time left: 18:41
#
#
#
# Fitting candidate 9 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 1
#     Test Result: 1.1221     std: 0.0636       n iter: 780
#     Train Result: 0.0129     std: 0.0016
#     elapsed time: 6:19, 5 fold time: 0:58
#     time left: 18:56
#
#
#
# Fitting candidate 10 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 3
#     Test Result: 1.1037     std: 0.0594       n iter: 1000
#     Train Result: 0.0055     std: 0.0006
#     elapsed time: 7:27, 5 fold time: 1: 8
#     time left: 19:22
#
#
#
# Fitting candidate 11 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 5
#     Test Result: 1.0987     std: 0.0601       n iter: 510
#     Train Result: 0.0516     std: 0.0018
#     elapsed time: 8: 8, 5 fold time: 0:41
#     time left: 18:29
#
#
#
# Fitting candidate 12 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 7
#     Test Result: 1.1011     std: 0.0514       n iter: 464
#     Train Result: 0.0812     std: 0.0044
#     elapsed time: 8:45, 5 fold time: 0:38
#     time left: 17:31
#
#
#
# Fitting candidate 13 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0900     std: 0.0487       n iter: 840
#     Train Result: 0.2480     std: 0.0064
#     elapsed time: 9:16, 5 fold time: 0:30
#     time left: 16:23
#
#
#
# Fitting candidate 14 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0926     std: 0.0525       n iter: 685
#     Train Result: 0.2987     std: 0.0073
#     elapsed time: 9:42, 5 fold time: 0:26
#     time left: 15:14
#
#
#
# Fitting candidate 15 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 5
#     Test Result: 1.0834     std: 0.0448       n iter: 688
#     Train Result: 0.3003     std: 0.0063
#     elapsed time: 10: 7, 5 fold time: 0:26
#     time left: 14:10
#
#
#
# Fitting candidate 16 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0978     std: 0.0482       n iter: 839
#     Train Result: 0.2520     std: 0.0069
#     elapsed time: 10:38, 5 fold time: 0:31
#     time left: 13:18
#
#
#
# Fitting candidate 17 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 1
#     Test Result: 1.0853     std: 0.0641       n iter: 658
#     Train Result: 0.0469     std: 0.0039
#     elapsed time: 11:17, 5 fold time: 0:38
#     time left: 12:36
#
#
#
# Fitting candidate 18 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 3
#     Test Result: 1.0822     std: 0.0568       n iter: 1000
#     Train Result: 0.0137     std: 0.0011
#     elapsed time: 12: 8, 5 fold time: 0:51
#     time left: 12: 8
#
#
#
# Fitting candidate 19 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0609     std: 0.0604       n iter: 618
#     Train Result: 0.0578     std: 0.0024
#     elapsed time: 12:43, 5 fold time: 0:35
#     time left: 11:23
#
#
#
# Fitting candidate 20 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 7
#     Test Result: 1.0729     std: 0.0572       n iter: 459
#     Train Result: 0.1193     std: 0.0034
#     elapsed time: 13:11, 5 fold time: 0:28
#     time left: 10:33
#
#
#
# Fitting candidate 21 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 1
#     Test Result: 1.1218     std: 0.0630       n iter: 1000
#     Train Result: 0.0006     std: 0.0000
#     elapsed time: 14:17, 5 fold time: 1: 6
#     time left: 10:12
#
#
#
# Fitting candidate 22 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 3
#     Test Result: 1.1078     std: 0.0496       n iter: 529
#     Train Result: 0.0087     std: 0.0005
#     elapsed time: 14:60, 5 fold time: 0:43
#     time left: 9:32
#
#
#
# Fitting candidate 23 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 5
#     Test Result: 1.1104     std: 0.0619       n iter: 634
#     Train Result: 0.0059     std: 0.0011
#     elapsed time: 15:50, 5 fold time: 0:50
#     time left: 8:57
#
#
#
# Fitting candidate 24 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 7
#     Test Result: 1.1040     std: 0.0516       n iter: 567
#     Train Result: 0.0135     std: 0.0020
#     elapsed time: 16:36, 5 fold time: 0:46
#     time left: 8:18
#
#
#
# Fitting candidate 25 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0986     std: 0.0501       n iter: 489
#     Train Result: 0.2993     std: 0.0082
#     elapsed time: 16:55, 5 fold time: 0:19
#     time left: 7:27
#
#
#
# Fitting candidate 26 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0881     std: 0.0503       n iter: 552
#     Train Result: 0.2648     std: 0.0082
#     elapsed time: 17:16, 5 fold time: 0:21
#     time left: 6:38
#
#
#
# Fitting candidate 27 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 5
#     Test Result: 1.0864     std: 0.0464       n iter: 493
#     Train Result: 0.3016     std: 0.0064
#     elapsed time: 17:36, 5 fold time: 0:20
#     time left: 5:52
#
#
#
# Fitting candidate 28 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0950     std: 0.0419       n iter: 311
#     Train Result: 0.4395     std: 0.0116
#     elapsed time: 17:49, 5 fold time: 0:13
#     time left: 5: 5
#
#
#
# Fitting candidate 29 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 1
#     Test Result: 1.0843     std: 0.0684       n iter: 316
#     Train Result: 0.1011     std: 0.0046
#     elapsed time: 18: 9, 5 fold time: 0:21
#     time left: 4:23
#
#
#
# Fitting candidate 30 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 3
#     Test Result: 1.0755     std: 0.0549       n iter: 691
#     Train Result: 0.0145     std: 0.0014
#     elapsed time: 18:50, 5 fold time: 0:40
#     time left: 3:46
#
#
#
# Fitting candidate 31 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0631     std: 0.0531       n iter: 316
#     Train Result: 0.1113     std: 0.0034
#     elapsed time: 19:10, 5 fold time: 0:20
#     time left: 3: 5
#
#
#
# Fitting candidate 32 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 7
#     Test Result: 1.0752     std: 0.0454       n iter: 418
#     Train Result: 0.0704     std: 0.0059
#     elapsed time: 19:36, 5 fold time: 0:26
#     time left: 2:27
#
#
#
# Fitting candidate 33 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 1
#     Test Result: 1.1150     std: 0.0671       n iter: 653
#     Train Result: 0.0006     std: 0.0000
#     elapsed time: 20:23, 5 fold time: 0:47
#     time left: 1:51
#
#
#
# Fitting candidate 34 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 3
#     Test Result: 1.1154     std: 0.0571       n iter: 510
#     Train Result: 0.0021     std: 0.0004
#     elapsed time: 21: 4, 5 fold time: 0:41
#     time left: 1:14
#
#
#
# Fitting candidate 35 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 5
#     Test Result: 1.0979     std: 0.0580       n iter: 171
#     Train Result: 0.0845     std: 0.0076
#     elapsed time: 21:21, 5 fold time: 0:18
#     time left: 0:37
#
#
#
# Fitting candidate 36 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 7
#     Test Result: 1.1077     std: 0.0555       n iter: 360
#     Train Result: 0.0187     std: 0.0012
#     elapsed time: 21:52, 5 fold time: 0:30
#     time left: 0: 0
#
#
#
# STARTING SEARCH FOR ERBB2
# ===========================================================
# Fitting 5 folds for each of 36 candidates, totalling 180 fits.
# Fitting candidate 1 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 1
#     Test Result: 1.2647     std: 0.0324       n iter: 463
#     Train Result: 0.8465     std: 0.0079
#     elapsed time: 0:23, 5 fold time: 0:23
#     time left: 13:23
#
#
#
# Fitting candidate 2 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 3
#     Test Result: 1.2633     std: 0.0332       n iter: 618
#     Train Result: 0.7711     std: 0.0082
#     elapsed time: 0:53, 5 fold time: 0:30
#     time left: 14:54
#
#
#
# Fitting candidate 3 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 5
#     Test Result: 1.2678     std: 0.0344       n iter: 502
#     Train Result: 0.8271     std: 0.0080
#     elapsed time: 1:17, 5 fold time: 0:25
#     time left: 14: 9
#
#
#
# Fitting candidate 4 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 7
#     Test Result: 1.2660     std: 0.0342       n iter: 481
#     Train Result: 0.8392     std: 0.0093
#     elapsed time: 1:41, 5 fold time: 0:24
#     time left: 13:31
#
#
#
# Fitting candidate 5 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 1
#     Test Result: 1.2588     std: 0.0375       n iter: 194
#     Train Result: 0.7190     std: 0.0123
#     elapsed time: 1:59, 5 fold time: 0:18
#     time left: 12:20
#
#
#
# Fitting candidate 6 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 3
#     Test Result: 1.2560     std: 0.0344       n iter: 292
#     Train Result: 0.5995     std: 0.0056
#     elapsed time: 2:24, 5 fold time: 0:24
#     time left: 11:58
#
#
#
# Fitting candidate 7 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 5
#     Test Result: 1.2534     std: 0.0322       n iter: 277
#     Train Result: 0.6242     std: 0.0110
#     elapsed time: 2:47, 5 fold time: 0:23
#     time left: 11:32
#
#
#
# Fitting candidate 8 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 7
#     Test Result: 1.2546     std: 0.0327       n iter: 312
#     Train Result: 0.5905     std: 0.0100
#     elapsed time: 3:12, 5 fold time: 0:25
#     time left: 11:13
#
#
#
# Fitting candidate 9 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 1
#     Test Result: 1.2736     std: 0.0429       n iter: 188
#     Train Result: 0.4018     std: 0.0052
#     elapsed time: 3:36, 5 fold time: 0:24
#     time left: 10:49
#
#
#
# Fitting candidate 10 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 3
#     Test Result: 1.2753     std: 0.0385       n iter: 294
#     Train Result: 0.2732     std: 0.0086
#     elapsed time: 4: 9, 5 fold time: 0:33
#     time left: 10:48
#
#
#
# Fitting candidate 11 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 5
#     Test Result: 1.2673     std: 0.0340       n iter: 311
#     Train Result: 0.2596     std: 0.0064
#     elapsed time: 4:44, 5 fold time: 0:34
#     time left: 10:45
#
#
#
# Fitting candidate 12 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 7
#     Test Result: 1.2582     std: 0.0394       n iter: 493
#     Train Result: 0.1531     std: 0.0081
#     elapsed time: 5:33, 5 fold time: 0:50
#     time left: 11: 7
#
#
#
# Fitting candidate 13 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 1
#     Test Result: 1.2698     std: 0.0316       n iter: 438
#     Train Result: 0.7231     std: 0.0084
#     elapsed time: 5:55, 5 fold time: 0:22
#     time left: 10:28
#
#
#
# Fitting candidate 14 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 3
#     Test Result: 1.2664     std: 0.0329       n iter: 376
#     Train Result: 0.7652     std: 0.0095
#     elapsed time: 6:14, 5 fold time: 0:19
#     time left: 9:48
#
#
#
# Fitting candidate 15 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 5
#     Test Result: 1.2627     std: 0.0334       n iter: 291
#     Train Result: 0.8325     std: 0.0088
#     elapsed time: 6:30, 5 fold time: 0:16
#     time left: 9: 6
#
#
#
# Fitting candidate 16 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 7
#     Test Result: 1.2646     std: 0.0323       n iter: 359
#     Train Result: 0.7802     std: 0.0088
#     elapsed time: 6:48, 5 fold time: 0:18
#     time left: 8:30
#
#
#
# Fitting candidate 17 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 1
#     Test Result: 1.2569     std: 0.0398       n iter: 121
#     Train Result: 0.7059     std: 0.0088
#     elapsed time: 7: 1, 5 fold time: 0:13
#     time left: 7:51
#
#
#
# Fitting candidate 18 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 3
#     Test Result: 1.2564     std: 0.0357       n iter: 320
#     Train Result: 0.3847     std: 0.0088
#     elapsed time: 7:28, 5 fold time: 0:26
#     time left: 7:28
#
#
#
# Fitting candidate 19 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 5
#     Test Result: 1.2542     std: 0.0328       n iter: 219
#     Train Result: 0.5254     std: 0.0114
#     elapsed time: 7:47, 5 fold time: 0:19
#     time left: 6:58
#
#
#
# Fitting candidate 20 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 7
#     Test Result: 1.2542     std: 0.0419       n iter: 123
#     Train Result: 0.7131     std: 0.0105
#     elapsed time: 8: 0, 5 fold time: 0:13
#     time left: 6:24
#
#
#
# Fitting candidate 21 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 1
#     Test Result: 1.2753     std: 0.0349       n iter: 460
#     Train Result: 0.0527     std: 0.0027
#     elapsed time: 8:49, 5 fold time: 0:48
#     time left: 6:18
#
#
#
# Fitting candidate 22 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 3
#     Test Result: 1.2729     std: 0.0419       n iter: 172
#     Train Result: 0.2754     std: 0.0165
#     elapsed time: 9:11, 5 fold time: 0:22
#     time left: 5:51
#
#
#
# Fitting candidate 23 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 5
#     Test Result: 1.2664     std: 0.0302       n iter: 212
#     Train Result: 0.2239     std: 0.0068
#     elapsed time: 9:37, 5 fold time: 0:26
#     time left: 5:26
#
#
#
# Fitting candidate 24 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 7
#     Test Result: 1.2636     std: 0.0378       n iter: 112
#     Train Result: 0.4430     std: 0.0121
#     elapsed time: 9:54, 5 fold time: 0:17
#     time left: 4:57
#
#
#
# Fitting candidate 25 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 1
#     Test Result: 1.2669     std: 0.0354       n iter: 212
#     Train Result: 0.8282     std: 0.0089
#     elapsed time: 10: 6, 5 fold time: 0:12
#     time left: 4:27
#
#
#
# Fitting candidate 26 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 3
#     Test Result: 1.2628     std: 0.0335       n iter: 278
#     Train Result: 0.7557     std: 0.0077
#     elapsed time: 10:21, 5 fold time: 0:15
#     time left: 3:59
#
#
#
# Fitting candidate 27 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 5
#     Test Result: 1.2571     std: 0.0292       n iter: 162
#     Train Result: 0.8930     std: 0.0093
#     elapsed time: 10:31, 5 fold time: 0:10
#     time left: 3:30
#
#
#
# Fitting candidate 28 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 7
#     Test Result: 1.2642     std: 0.0362       n iter: 175
#     Train Result: 0.8757     std: 0.0124
#     elapsed time: 10:42, 5 fold time: 0:11
#     time left: 3: 3
#
#
#
# Fitting candidate 29 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 1
#     Test Result: 1.2612     std: 0.0374       n iter: 90
#     Train Result: 0.6962     std: 0.0193
#     elapsed time: 10:53, 5 fold time: 0:11
#     time left: 2:38
#
#
#
# Fitting candidate 30 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 3
#     Test Result: 1.2599     std: 0.0343       n iter: 179
#     Train Result: 0.4679     std: 0.0107
#     elapsed time: 11:10, 5 fold time: 0:17
#     time left: 2:14
#
#
#
# Fitting candidate 31 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 5
#     Test Result: 1.2612     std: 0.0397       n iter: 163
#     Train Result: 0.5073     std: 0.0141
#     elapsed time: 11:25, 5 fold time: 0:16
#     time left: 1:51
#
#
#
# Fitting candidate 32 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 7
#     Test Result: 1.2611     std: 0.0358       n iter: 114
#     Train Result: 0.6381     std: 0.0152
#     elapsed time: 11:38, 5 fold time: 0:13
#     time left: 1:27
#
#
#
# Fitting candidate 33 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 1
#     Test Result: 1.2782     std: 0.0422       n iter: 60
#     Train Result: 0.4898     std: 0.0154
#     elapsed time: 11:51, 5 fold time: 0:13
#     time left: 1: 5
#
#
#
# Fitting candidate 34 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 3
#     Test Result: 1.2740     std: 0.0390       n iter: 79
#     Train Result: 0.4033     std: 0.0111
#     elapsed time: 12: 5, 5 fold time: 0:14
#     time left: 0:43
#
#
#
# Fitting candidate 35 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 5
#     Test Result: 1.2659     std: 0.0484       n iter: 86
#     Train Result: 0.4079     std: 0.0072
#     elapsed time: 12:20, 5 fold time: 0:15
#     time left: 0:21
#
#
#
# Fitting candidate 36 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 7
#     Test Result: 1.2615     std: 0.0369       n iter: 76
#     Train Result: 0.4602     std: 0.0129
#     elapsed time: 12:34, 5 fold time: 0:14
#     time left: 0: 0
#
#
#
# STARTING SEARCH FOR CDK1
# ===========================================================
# Fitting 5 folds for each of 36 candidates, totalling 180 fits.
# Fitting candidate 1 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0922     std: 0.1106       n iter: 884
#     Train Result: 0.0875     std: 0.0081
#     elapsed time: 0:22, 5 fold time: 0:22
#     time left: 12:53
#
#
#
# Fitting candidate 2 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0916     std: 0.1025       n iter: 450
#     Train Result: 0.1947     std: 0.0116
#     elapsed time: 0:34, 5 fold time: 0:12
#     time left: 9:45
#
#
#
# Fitting candidate 3 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 5
#     Test Result: 1.0950     std: 0.0995       n iter: 1000
#     Train Result: 0.0611     std: 0.0055
#     elapsed time: 0:58, 5 fold time: 0:23
#     time left: 10:34
#
#
#
# Fitting candidate 4 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0900     std: 0.0945       n iter: 900
#     Train Result: 0.0782     std: 0.0061
#     elapsed time: 1:20, 5 fold time: 0:22
#     time left: 10:39
#
#
#
# Fitting candidate 5 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 1
#     Test Result: 1.1391     std: 0.0678       n iter: 1000
#     Train Result: 0.0024     std: 0.0004
#     elapsed time: 1:52, 5 fold time: 0:32
#     time left: 11:36
#
#
#
# Fitting candidate 6 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 3
#     Test Result: 1.1540     std: 0.1035       n iter: 593
#     Train Result: 0.0116     std: 0.0011
#     elapsed time: 2:14, 5 fold time: 0:22
#     time left: 11: 9
#
#
#
# Fitting candidate 7 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 5
#     Test Result: 1.1445     std: 0.0799       n iter: 595
#     Train Result: 0.0127     std: 0.0010
#     elapsed time: 2:36, 5 fold time: 0:22
#     time left: 10:47
#
#
#
# Fitting candidate 8 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 7
#     Test Result: 1.1299     std: 0.0826       n iter: 428
#     Train Result: 0.0349     std: 0.0031
#     elapsed time: 2:52, 5 fold time: 0:16
#     time left: 10: 2
#
#
#
# Fitting candidate 9 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 1
#     Test Result: 1.1829     std: 0.0891       n iter: 637
#     Train Result: 0.0006     std: 0.0001
#     elapsed time: 3:21, 5 fold time: 0:29
#     time left: 10: 3
#
#
#
# Fitting candidate 10 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 3
#     Test Result: 1.1960     std: 0.1042       n iter: 529
#     Train Result: 0.0035     std: 0.0013
#     elapsed time: 3:47, 5 fold time: 0:26
#     time left: 9:50
#
#
#
# Fitting candidate 11 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 5
#     Test Result: 1.1652     std: 0.0942       n iter: 1000
#     Train Result: 0.0018     std: 0.0004
#     elapsed time: 4:30, 5 fold time: 0:43
#     time left: 10:13
#
#
#
# Fitting candidate 12 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 7
#     Test Result: 1.1497     std: 0.0760       n iter: 342
#     Train Result: 0.0274     std: 0.0019
#     elapsed time: 4:47, 5 fold time: 0:18
#     time left: 9:34
#
#
#
# Fitting candidate 13 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0956     std: 0.0932       n iter: 606
#     Train Result: 0.0685     std: 0.0059
#     elapsed time: 5: 3, 5 fold time: 0:16
#     time left: 8:55
#
#
#
# Fitting candidate 14 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0942     std: 0.0855       n iter: 316
#     Train Result: 0.1618     std: 0.0118
#     elapsed time: 5:12, 5 fold time: 0: 9
#     time left: 8:10
#
#
#
# Fitting candidate 15 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 5
#     Test Result: 1.1008     std: 0.0830       n iter: 457
#     Train Result: 0.0964     std: 0.0092
#     elapsed time: 5:23, 5 fold time: 0:12
#     time left: 7:33
#
#
#
# Fitting candidate 16 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0864     std: 0.0831       n iter: 463
#     Train Result: 0.0989     std: 0.0066
#     elapsed time: 5:36, 5 fold time: 0:12
#     time left: 6:60
#
#
#
# Fitting candidate 17 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 1
#     Test Result: 1.1327     std: 0.0778       n iter: 699
#     Train Result: 0.0011     std: 0.0001
#     elapsed time: 6: 1, 5 fold time: 0:25
#     time left: 6:43
#
#
#
# Fitting candidate 18 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 3
#     Test Result: 1.1491     std: 0.0926       n iter: 341
#     Train Result: 0.0130     std: 0.0006
#     elapsed time: 6:15, 5 fold time: 0:14
#     time left: 6:15
#
#
#
# Fitting candidate 19 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 5
#     Test Result: 1.1282     std: 0.0808       n iter: 301
#     Train Result: 0.0204     std: 0.0025
#     elapsed time: 6:27, 5 fold time: 0:12
#     time left: 5:46
#
#
#
# Fitting candidate 20 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 7
#     Test Result: 1.1389     std: 0.0932       n iter: 353
#     Train Result: 0.0142     std: 0.0010
#     elapsed time: 6:40, 5 fold time: 0:14
#     time left: 5:20
#
#
#
# Fitting candidate 21 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 1
#     Test Result: 1.1859     std: 0.0785       n iter: 403
#     Train Result: 0.0005     std: 0.0000
#     elapsed time: 6:58, 5 fold time: 0:18
#     time left: 4:59
#
#
#
# Fitting candidate 22 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 3
#     Test Result: 1.1784     std: 0.1194       n iter: 378
#     Train Result: 0.0019     std: 0.0008
#     elapsed time: 7:18, 5 fold time: 0:19
#     time left: 4:39
#
#
#
# Fitting candidate 23 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 5
#     Test Result: 1.1739     std: 0.0936       n iter: 676
#     Train Result: 0.0008     std: 0.0004
#     elapsed time: 7:48, 5 fold time: 0:30
#     time left: 4:25
#
#
#
# Fitting candidate 24 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 7
#     Test Result: 1.1610     std: 0.0726       n iter: 1000
#     Train Result: 0.0006     std: 0.0002
#     elapsed time: 8:31, 5 fold time: 0:43
#     time left: 4:15
#
#
#
# Fitting candidate 25 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0919     std: 0.0997       n iter: 286
#     Train Result: 0.1250     std: 0.0076
#     elapsed time: 8:39, 5 fold time: 0: 8
#     time left: 3:48
#
#
#
# Fitting candidate 26 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0975     std: 0.0942       n iter: 419
#     Train Result: 0.0605     std: 0.0033
#     elapsed time: 8:50, 5 fold time: 0:11
#     time left: 3:24
#
#
#
# Fitting candidate 27 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 5
#     Test Result: 1.0794     std: 0.0854       n iter: 265
#     Train Result: 0.1304     std: 0.0085
#     elapsed time: 8:58, 5 fold time: 0: 8
#     time left: 2:59
#
#
#
# Fitting candidate 28 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0793     std: 0.0932       n iter: 359
#     Train Result: 0.0871     std: 0.0058
#     elapsed time: 9: 9, 5 fold time: 0:10
#     time left: 2:37
#
#
#
# Fitting candidate 29 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 1
#     Test Result: 1.1555     std: 0.0583       n iter: 324
#     Train Result: 0.0061     std: 0.0003
#     elapsed time: 9:21, 5 fold time: 0:12
#     time left: 2:15
#
#
#
# Fitting candidate 30 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 3
#     Test Result: 1.1458     std: 0.1053       n iter: 350
#     Train Result: 0.0041     std: 0.0003
#     elapsed time: 9:35, 5 fold time: 0:14
#     time left: 1:55
#
#
#
# Fitting candidate 31 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 5
#     Test Result: 1.1478     std: 0.1040       n iter: 243
#     Train Result: 0.0140     std: 0.0015
#     elapsed time: 9:45, 5 fold time: 0:10
#     time left: 1:34
#
#
#
# Fitting candidate 32 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 7
#     Test Result: 1.1267     std: 0.0847       n iter: 430
#     Train Result: 0.0019     std: 0.0003
#     elapsed time: 10: 2, 5 fold time: 0:17
#     time left: 1:15
#
#
#
# Fitting candidate 33 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 1
#     Test Result: 1.1908     std: 0.0684       n iter: 270
#     Train Result: 0.0005     std: 0.0001
#     elapsed time: 10:15, 5 fold time: 0:12
#     time left: 0:56
#
#
#
# Fitting candidate 34 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 3
#     Test Result: 1.1827     std: 0.1047       n iter: 213
#     Train Result: 0.0042     std: 0.0013
#     elapsed time: 10:27, 5 fold time: 0:13
#     time left: 0:37
#
#
#
# Fitting candidate 35 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 5
#     Test Result: 1.1774     std: 0.0957       n iter: 389
#     Train Result: 0.0023     std: 0.0008
#     elapsed time: 10:48, 5 fold time: 0:21
#     time left: 0:19
#
#
#
# Fitting candidate 36 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 7
#     Test Result: 1.1569     std: 0.0693       n iter: 826
#     Train Result: 0.0004     std: 0.0000
#     elapsed time: 11:20, 5 fold time: 0:32
#     time left: 0: 0
#
#
#
# STARTING SEARCH FOR CDK4
# ===========================================================
# Fitting 5 folds for each of 36 candidates, totalling 180 fits.
# Fitting candidate 1 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0124     std: 0.0217       n iter: 386
#     Train Result: 0.7526     std: 0.0074
#     elapsed time: 0:17, 5 fold time: 0:17
#     time left: 10:10
#
#
#
# Fitting candidate 2 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0125     std: 0.0224       n iter: 329
#     Train Result: 0.7814     std: 0.0079
#     elapsed time: 0:33, 5 fold time: 0:15
#     time left: 9:19
#
#
#
# Fitting candidate 3 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 5
#     Test Result: 1.0119     std: 0.0229       n iter: 402
#     Train Result: 0.7452     std: 0.0075
#     elapsed time: 0:51, 5 fold time: 0:18
#     time left: 9:19
#
#
#
# Fitting candidate 4 of 36
#     learning_rate : 0.03     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0127     std: 0.0242       n iter: 360
#     Train Result: 0.7691     std: 0.0075
#     elapsed time: 1: 7, 5 fold time: 0:16
#     time left: 8:58
#
#
#
# Fitting candidate 5 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 1
#     Test Result: 1.0132     std: 0.0277       n iter: 208
#     Train Result: 0.5779     std: 0.0127
#     elapsed time: 1:24, 5 fold time: 0:17
#     time left: 8:40
#
#
#
# Fitting candidate 6 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 3
#     Test Result: 1.0128     std: 0.0274       n iter: 167
#     Train Result: 0.6354     std: 0.0151
#     elapsed time: 1:38, 5 fold time: 0:14
#     time left: 8:11
#
#
#
# Fitting candidate 7 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0124     std: 0.0257       n iter: 158
#     Train Result: 0.6519     std: 0.0152
#     elapsed time: 1:52, 5 fold time: 0:14
#     time left: 7:44
#
#
#
# Fitting candidate 8 of 36
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 7
#     Test Result: 1.0117     std: 0.0251       n iter: 173
#     Train Result: 0.6377     std: 0.0126
#     elapsed time: 2: 7, 5 fold time: 0:15
#     time left: 7:23
#
#
#
# Fitting candidate 9 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 1
#     Test Result: 1.0191     std: 0.0273       n iter: 239
#     Train Result: 0.2598     std: 0.0093
#     elapsed time: 2:32, 5 fold time: 0:25
#     time left: 7:35
#
#
#
# Fitting candidate 10 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 3
#     Test Result: 1.0170     std: 0.0287       n iter: 184
#     Train Result: 0.3445     std: 0.0129
#     elapsed time: 2:53, 5 fold time: 0:21
#     time left: 7:29
#
#
#
# Fitting candidate 11 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 5
#     Test Result: 1.0168     std: 0.0304       n iter: 168
#     Train Result: 0.3835     std: 0.0113
#     elapsed time: 3:12, 5 fold time: 0:19
#     time left: 7:17
#
#
#
# Fitting candidate 12 of 36
#     learning_rate : 0.03     max_depth : 7     min_child_weight : 7
#     Test Result: 1.0156     std: 0.0305       n iter: 266
#     Train Result: 0.2656     std: 0.0105
#     elapsed time: 3:39, 5 fold time: 0:27
#     time left: 7:18
#
#
#
# Fitting candidate 13 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0128     std: 0.0217       n iter: 229
#     Train Result: 0.7535     std: 0.0086
#     elapsed time: 3:51, 5 fold time: 0:12
#     time left: 6:48
#
#
#
# Fitting candidate 14 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0129     std: 0.0211       n iter: 229
#     Train Result: 0.7529     std: 0.0074
#     elapsed time: 4: 2, 5 fold time: 0:12
#     time left: 6:21
#
#
#
# Fitting candidate 15 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 5
#     Test Result: 1.0110     std: 0.0237       n iter: 290
#     Train Result: 0.7057     std: 0.0065
#     elapsed time: 4:16, 5 fold time: 0:14
#     time left: 5:59
#
#
#
# Fitting candidate 16 of 36
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0115     std: 0.0234       n iter: 239
#     Train Result: 0.7477     std: 0.0070
#     elapsed time: 4:28, 5 fold time: 0:12
#     time left: 5:36
#
#
#
# Fitting candidate 17 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 1
#     Test Result: 1.0145     std: 0.0282       n iter: 110
#     Train Result: 0.6082     std: 0.0137
#     elapsed time: 4:40, 5 fold time: 0:11
#     time left: 5:12
#
#
#
# Fitting candidate 18 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 3
#     Test Result: 1.0129     std: 0.0266       n iter: 137
#     Train Result: 0.5547     std: 0.0108
#     elapsed time: 4:52, 5 fold time: 0:13
#     time left: 4:52
#
#
#
# Fitting candidate 19 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0140     std: 0.0278       n iter: 183
#     Train Result: 0.4788     std: 0.0092
#     elapsed time: 5: 7, 5 fold time: 0:15
#     time left: 4:35
#
#
#
# Fitting candidate 20 of 36
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 7
#     Test Result: 1.0121     std: 0.0258       n iter: 138
#     Train Result: 0.5660     std: 0.0121
#     elapsed time: 5:20, 5 fold time: 0:13
#     time left: 4:16
#
#
#
# Fitting candidate 21 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 1
#     Test Result: 1.0220     std: 0.0268       n iter: 90
#     Train Result: 0.3956     std: 0.0145
#     elapsed time: 5:34, 5 fold time: 0:13
#     time left: 3:58
#
#
#
# Fitting candidate 22 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 3
#     Test Result: 1.0179     std: 0.0336       n iter: 162
#     Train Result: 0.2307     std: 0.0101
#     elapsed time: 5:53, 5 fold time: 0:19
#     time left: 3:44
#
#
#
# Fitting candidate 23 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 5
#     Test Result: 1.0209     std: 0.0320       n iter: 153
#     Train Result: 0.2586     std: 0.0050
#     elapsed time: 6:11, 5 fold time: 0:18
#     time left: 3:30
#
#
#
# Fitting candidate 24 of 36
#     learning_rate : 0.05     max_depth : 7     min_child_weight : 7
#     Test Result: 1.0144     std: 0.0276       n iter: 180
#     Train Result: 0.2297     std: 0.0106
#     elapsed time: 6:31, 5 fold time: 0:20
#     time left: 3:16
#
#
#
# Fitting candidate 25 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 1
#     Test Result: 1.0145     std: 0.0207       n iter: 176
#     Train Result: 0.7368     std: 0.0074
#     elapsed time: 6:41, 5 fold time: 0:10
#     time left: 2:56
#
#
#
# Fitting candidate 26 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 3
#     Test Result: 1.0155     std: 0.0205       n iter: 169
#     Train Result: 0.7448     std: 0.0077
#     elapsed time: 6:50, 5 fold time: 0: 9
#     time left: 2:38
#
#
#
# Fitting candidate 27 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 5
#     Test Result: 1.0135     std: 0.0221       n iter: 134
#     Train Result: 0.7912     std: 0.0064
#     elapsed time: 6:58, 5 fold time: 0: 8
#     time left: 2:19
#
#
#
# Fitting candidate 28 of 36
#     learning_rate : 0.07     max_depth : 3     min_child_weight : 7
#     Test Result: 1.0155     std: 0.0215       n iter: 137
#     Train Result: 0.7894     std: 0.0059
#     elapsed time: 7: 7, 5 fold time: 0: 8
#     time left: 2: 2
#
#
#
# Fitting candidate 29 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 1
#     Test Result: 1.0166     std: 0.0260       n iter: 100
#     Train Result: 0.5455     std: 0.0090
#     elapsed time: 7:17, 5 fold time: 0:10
#     time left: 1:46
#
#
#
# Fitting candidate 30 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 3
#     Test Result: 1.0168     std: 0.0274       n iter: 57
#     Train Result: 0.6879     std: 0.0146
#     elapsed time: 7:25, 5 fold time: 0: 8
#     time left: 1:29
#
#
#
# Fitting candidate 31 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0149     std: 0.0279       n iter: 172
#     Train Result: 0.3944     std: 0.0116
#     elapsed time: 7:40, 5 fold time: 0:15
#     time left: 1:14
#
#
#
# Fitting candidate 32 of 36
#     learning_rate : 0.07     max_depth : 5     min_child_weight : 7
#     Test Result: 1.0123     std: 0.0241       n iter: 106
#     Train Result: 0.5387     std: 0.0069
#     elapsed time: 7:51, 5 fold time: 0:11
#     time left: 0:59
#
#
#
# Fitting candidate 33 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 1
#     Test Result: 1.0203     std: 0.0302       n iter: 109
#     Train Result: 0.2429     std: 0.0078
#     elapsed time: 8: 6, 5 fold time: 0:15
#     time left: 0:44
#
#
#
# Fitting candidate 34 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 3
#     Test Result: 1.0163     std: 0.0299       n iter: 68
#     Train Result: 0.3874     std: 0.0149
#     elapsed time: 8:17, 5 fold time: 0:12
#     time left: 0:29
#
#
#
# Fitting candidate 35 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 5
#     Test Result: 1.0256     std: 0.0301       n iter: 50
#     Train Result: 0.5002     std: 0.0157
#     elapsed time: 8:28, 5 fold time: 0:10
#     time left: 0:15
#
#
#
# Fitting candidate 36 of 36
#     learning_rate : 0.07     max_depth : 7     min_child_weight : 7
#     Test Result: 1.0188     std: 0.0306       n iter: 112
#     Train Result: 0.2637     std: 0.0060
#     elapsed time: 8:43, 5 fold time: 0:15
#     time left: 0: 0

# %%
r = results["ESR1"].results

# %%
fig, ax = plt.subplots(1,1, figsize=(6,6))
ax = sns.heatmap(r[1], annot=True,
                        yticklabels=param_test1["max_depth"],
                        xticklabels=param_test1["min_child_weight"],
                         fmt='.4g', 
                         cmap=sns.cm.rocket_r)
ax.set_ylabel("max_depth")
ax.set_xlabel("min_child_weight")
ax.set_title(f"learning_rate : {param_test1['learning_rate'][1]}")


plt.show()

# %%
def get_best_params(model):
    print("    Learning_rate:    ",model._best_params["learning_rate"])
    print("    max_depth:        ",model._best_params["max_depth"])
    print("    min_child_weight: ",model._best_params["min_child_weight"])

# %% [markdown]
# #### The best parameters for each gene after the coarse search

# %%
for gene in genes:
    print(f"{gene.upper()}:")
    get_best_params(results[gene])
    print(f"    best score: {results[gene]._best_score}")
# Out:
# ESR1:
#     Learning_rate:     0.05
#     max_depth:         5
#     min_child_weight:  5
#     best score: 1.0609126
# ERBB2:
#     Learning_rate:     0.03
#     max_depth:         5
#     min_child_weight:  5
#     best score: 1.2534399999999999
# CDK1:
#     Learning_rate:     0.07
#     max_depth:         3
#     min_child_weight:  7
#     best score: 1.0793371999999999
# CDK4:
#     Learning_rate:     0.05
#     max_depth:         3
#     min_child_weight:  5
#     best score: 1.0110366

# %% [markdown]
# # Fine tuning

# %% [markdown]
# ### ESR1

# %%
param_test_ESR1 = {
    "learning_rate" : [0.002, 0.008, 0.01],
    "max_depth" : [3, 4, 5, 6],
    "min_child_weight" : [2, 3, 4, 5, 6]
}

# %%
GS_ESR1 = XGBGridSearch(xgb1, param_test_ESR1, cv=5)
X = datasets["ESR1"]["X_train"]
Y = datasets["ESR1"]["y_train"]
GS_ESR1.fit(X, Y)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits.
# Fitting candidate 1 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 4
#     Test Result: 1.0869     std: 0.0838       n iter: 494
#     Train Result: 0.2561     std: 0.0104
#
#     elapsed time: 0:40, 5 fold time: 0:40
#     time left: 17:23
#
#
#
# Fitting candidate 2 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 5
#     Test Result: 1.0772     std: 0.0775       n iter: 556
#     Train Result: 0.2315     std: 0.0087
#
#     elapsed time: 1:24, 5 fold time: 0:44
#     time left: 17:33
#
#
#
# Fitting candidate 3 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 6
#     Test Result: 1.0857     std: 0.0831       n iter: 619
#     Train Result: 0.2085     std: 0.0081
#
#     elapsed time: 2:12, 5 fold time: 0:48
#     time left: 17:38
#
#
#
# Fitting candidate 4 of 27
#     learning_rate : 0.04     max_depth : 5     min_child_weight : 4
#     Test Result: 1.0926     std: 0.0897       n iter: 320
#     Train Result: 0.2301     std: 0.0080
#
#     elapsed time: 2:45, 5 fold time: 0:33
#     time left: 15:51
#
#
#
# Fitting candidate 5 of 27
#     learning_rate : 0.04     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0865     std: 0.0771       n iter: 468
#     Train Result: 0.1462     std: 0.0081
#
#     elapsed time: 3:31, 5 fold time: 0:45
#     time left: 15:28
#
#
#
# Fitting candidate 6 of 27
#     learning_rate : 0.04     max_depth : 5     min_child_weight : 6
#     Test Result: 1.0877     std: 0.0835       n iter: 701
#     Train Result: 0.0767     std: 0.0028
#
#     elapsed time: 4:35, 5 fold time: 1:05
#     time left: 16: 4
#
#
#
# Fitting candidate 7 of 27
#     learning_rate : 0.04     max_depth : 6     min_child_weight : 4
#     Test Result: 1.1162     std: 0.0929       n iter: 469
#     Train Result: 0.0680     std: 0.0047
#
#     elapsed time: 5:29, 5 fold time: 0:53
#     time left: 15:39
#
#
#
# Fitting candidate 8 of 27
#     learning_rate : 0.04     max_depth : 6     min_child_weight : 5
#     Test Result: 1.1162     std: 0.0816       n iter: 245
#     Train Result: 0.2044     std: 0.0080
#
#     elapsed time: 6:00, 5 fold time: 0:32
#     time left: 14:16
#
#
#
# Fitting candidate 9 of 27
#     learning_rate : 0.04     max_depth : 6     min_child_weight : 6
#     Test Result: 1.1088     std: 0.0902       n iter: 549
#     Train Result: 0.0578     std: 0.0036
#
#     elapsed time: 7:01, 5 fold time: 1:00
#     time left: 14: 2
#
#
#
# Fitting candidate 10 of 27
#     learning_rate : 0.05     max_depth : 4     min_child_weight : 4
#     Test Result: 1.0817     std: 0.0857       n iter: 336
#     Train Result: 0.2983     std: 0.0108
#
#     elapsed time: 7:30, 5 fold time: 0:29
#     time left: 12:44
#
#
#
# Fitting candidate 11 of 27
#     learning_rate : 0.05     max_depth : 4     min_child_weight : 5
#     Test Result: 1.0832     std: 0.0816       n iter: 295
#     Train Result: 0.3356     std: 0.0097
#
#     elapsed time: 7:55, 5 fold time: 0:26
#     time left: 11:31
#
#
#
# Fitting candidate 12 of 27
#     learning_rate : 0.05     max_depth : 4     min_child_weight : 6
#     Test Result: 1.0862     std: 0.0869       n iter: 766
#     Train Result: 0.1058     std: 0.0029
#
#     elapsed time: 8:53, 5 fold time: 0:58
#     time left: 11: 7
#
#
#
# Fitting candidate 13 of 27
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 4
#     Test Result: 1.0942     std: 0.0868       n iter: 451
#     Train Result: 0.1053     std: 0.0067
#
#     elapsed time: 9:38, 5 fold time: 0:44
#     time left: 10:22
#
#
#
# Fitting candidate 14 of 27
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0928     std: 0.0844       n iter: 479
#     Train Result: 0.0984     std: 0.0040
#
#     elapsed time: 10:24, 5 fold time: 0:46
#     time left: 9:39
#
#
#
# Fitting candidate 15 of 27
#     learning_rate : 0.05     max_depth : 5     min_child_weight : 6
#     Test Result: 1.0919     std: 0.0867       n iter: 438
#     Train Result: 0.1198     std: 0.0067
#
#     elapsed time: 11:07, 5 fold time: 0:43
#     time left: 8:53
#
#
#
# Fitting candidate 16 of 27
#     learning_rate : 0.05     max_depth : 6     min_child_weight : 4
#     Test Result: 1.1131     std: 0.0835       n iter: 458
#     Train Result: 0.0430     std: 0.0036
#
#     elapsed time: 11:59, 5 fold time: 0:52
#     time left: 8:14
#
#
#
# Fitting candidate 17 of 27
#     learning_rate : 0.05     max_depth : 6     min_child_weight : 5
#     Test Result: 1.1129     std: 0.0848       n iter: 833
#     Train Result: 0.0068     std: 0.0004
#
#     elapsed time: 13:27, 5 fold time: 1:28
#     time left: 7:55
#
#
#
# Fitting candidate 18 of 27
#     learning_rate : 0.05     max_depth : 6     min_child_weight : 6
#     Test Result: 1.1186     std: 0.0822       n iter: 400
#     Train Result: 0.0672     std: 0.0056
#
#     elapsed time: 14:13, 5 fold time: 0:47
#     time left: 7: 7
#
#
#
# Fitting candidate 19 of 27
#     learning_rate : 0.06     max_depth : 4     min_child_weight : 4
#     Test Result: 1.0822     std: 0.0771       n iter: 401
#     Train Result: 0.2032     std: 0.0064
#
#     elapsed time: 14:47, 5 fold time: 0:33
#     time left: 6:13
#
#
#
# Fitting candidate 20 of 27
#     learning_rate : 0.06     max_depth : 4     min_child_weight : 5
#     Test Result: 1.0780     std: 0.0819       n iter: 366
#     Train Result: 0.2305     std: 0.0065
#
#     elapsed time: 15:18, 5 fold time: 0:31
#     time left: 5:21
#
#
#
# Fitting candidate 21 of 27
#     learning_rate : 0.06     max_depth : 4     min_child_weight : 6
#     Test Result: 1.0785     std: 0.0833       n iter: 362
#     Train Result: 0.2411     std: 0.0068
#
#     elapsed time: 15:49, 5 fold time: 0:31
#     time left: 4:31
#
#
#
# Fitting candidate 22 of 27
#     learning_rate : 0.06     max_depth : 5     min_child_weight : 4
#     Test Result: 1.0935     std: 0.0885       n iter: 423
#     Train Result: 0.0835     std: 0.0045
#
#     elapsed time: 16:31, 5 fold time: 0:42
#     time left: 3:45
#
#
#
# Fitting candidate 23 of 27
#     learning_rate : 0.06     max_depth : 5     min_child_weight : 5
#     Test Result: 1.0845     std: 0.0687       n iter: 272
#     Train Result: 0.1783     std: 0.0098
#
#     elapsed time: 17:00, 5 fold time: 0:29
#     time left: 2:57
#
#
#
# Fitting candidate 24 of 27
#     learning_rate : 0.06     max_depth : 5     min_child_weight : 6
#     Test Result: 1.0967     std: 0.0843       n iter: 382
#     Train Result: 0.1122     std: 0.0047
#
#     elapsed time: 17:39, 5 fold time: 0:39
#     time left: 2:12
#
#
#
# Fitting candidate 25 of 27
#     learning_rate : 0.06     max_depth : 6     min_child_weight : 4
#     Test Result: 1.1141     std: 0.0926       n iter: 307
#     Train Result: 0.0698     std: 0.0050
#
#     elapsed time: 18:16, 5 fold time: 0:38
#     time left: 1:28
#
#
#
# Fitting candidate 26 of 27
#     learning_rate : 0.06     max_depth : 6     min_child_weight : 5
#     Test Result: 1.1108     std: 0.0945       n iter: 389
#     Train Result: 0.0428     std: 0.0052
#
#     elapsed time: 19:02, 5 fold time: 0:46
#     time left: 0:44
#
#
#
# Fitting candidate 27 of 27
#     learning_rate : 0.06     max_depth : 6     min_child_weight : 6
#     Test Result: 1.1126     std: 0.0807       n iter: 282
#     Train Result: 0.0954     std: 0.0061
#
#     elapsed time: 19:37, 5 fold time: 0:35
#     time left: 0: 0
# array([[[1.086913 , 1.0771684, 1.0856828],
#         [1.0926478, 1.0864948, 1.0876948],
#         [1.1162306, 1.1161928, 1.1088026]],
#
#        [[1.0816768, 1.0831562, 1.0861786],
#         [1.0942084, 1.092819 , 1.091935 ],
#         [1.1131416, 1.1129282, 1.11859  ]],
#
#        [[1.0822082, 1.0780404, 1.0785066],
#         [1.0935046, 1.084495 , 1.0966552],
#         [1.114132 , 1.1108054, 1.1125692]]])

# %%
GS_ESR1._best_score
# Out:
# 1.0771684000000001

# %%
get_best_params(GS_ESR1)
# Out:
#     Learning_rate:     0.04
#     max_depth:         4
#     min_child_weight:  5

# %% [markdown]
# ### ERBB2

# %%
param_test_ERBB2 = {
    "learning_rate" : [0.02, 0.03, 0.04],
    "max_depth" : [4, 5, 6],
    "min_child_weight" : [4, 5, 6]
}

# %%
GS_ERBB2 = XGBGridSearch(xgb1, param_test_ERBB2, cv=5)
X = datasets["ERBB2"]["X_train"]
Y = datasets["ERBB2"]["y_train"]
GS_ERBB2.fit(X, Y)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits.
# Fitting candidate 1 of 27
#     learning_rate : 0.02     max_depth : 4     min_child_weight : 4
#     Test Result: 1.2472     std: 0.0433       n iter: 529
#     Train Result: 0.7150     std: 0.0116
#
#     elapsed time: 0:52, 5 fold time: 0:52
#     time left: 22:26
#
#
#
# Fitting candidate 2 of 27
#     learning_rate : 0.02     max_depth : 4     min_child_weight : 5
#     Test Result: 1.2477     std: 0.0475       n iter: 537
#     Train Result: 0.7131     std: 0.0116
#
#     elapsed time: 1:44, 5 fold time: 0:52
#     time left: 21:39
#
#
#
# Fitting candidate 3 of 27
#     learning_rate : 0.02     max_depth : 4     min_child_weight : 6
#     Test Result: 1.2506     std: 0.0476       n iter: 407
#     Train Result: 0.7911     std: 0.0106
#
#     elapsed time: 2:26, 5 fold time: 0:42
#     time left: 19:26
#
#
#
# Fitting candidate 4 of 27
#     learning_rate : 0.02     max_depth : 5     min_child_weight : 4
#     Test Result: 1.2497     std: 0.0475       n iter: 504
#     Train Result: 0.5453     std: 0.0103
#
#     elapsed time: 3:26, 5 fold time: 1:00
#     time left: 19:44
#
#
#
# Fitting candidate 5 of 27
#     learning_rate : 0.02     max_depth : 5     min_child_weight : 5
#     Test Result: 1.2470     std: 0.0479       n iter: 484
#     Train Result: 0.5575     std: 0.0190
#
#     elapsed time: 4:24, 5 fold time: 0:58
#     time left: 19:20
#
#
#
# Fitting candidate 6 of 27
#     learning_rate : 0.02     max_depth : 5     min_child_weight : 6
#     Test Result: 1.2447     std: 0.0498       n iter: 538
#     Train Result: 0.5299     std: 0.0182
#
#     elapsed time: 5:27, 5 fold time: 1:03
#     time left: 19: 3
#
#
#
# Fitting candidate 7 of 27
#     learning_rate : 0.02     max_depth : 6     min_child_weight : 4
#     Test Result: 1.2440     std: 0.0433       n iter: 379
#     Train Result: 0.4718     std: 0.0127
#
#     elapsed time: 6:22, 5 fold time: 0:56
#     time left: 18:13
#
#
#
# Fitting candidate 8 of 27
#     learning_rate : 0.02     max_depth : 6     min_child_weight : 5
#     Test Result: 1.2391     std: 0.0471       n iter: 606
#     Train Result: 0.3149     std: 0.0083
#
#     elapsed time: 7:45, 5 fold time: 1:23
#     time left: 18:25
#
#
#
# Fitting candidate 9 of 27
#     learning_rate : 0.02     max_depth : 6     min_child_weight : 6
#     Test Result: 1.2459     std: 0.0523       n iter: 321
#     Train Result: 0.5377     std: 0.0101
#
#     elapsed time: 8:33, 5 fold time: 0:48
#     time left: 17: 7
#
#
#
# Fitting candidate 10 of 27
#     learning_rate : 0.03     max_depth : 4     min_child_weight : 4
#     Test Result: 1.2462     std: 0.0457       n iter: 346
#     Train Result: 0.7188     std: 0.0135
#
#     elapsed time: 9:10, 5 fold time: 0:36
#     time left: 15:35
#
#
#
# Fitting candidate 11 of 27
#     learning_rate : 0.03     max_depth : 4     min_child_weight : 5
#     Test Result: 1.2475     std: 0.0470       n iter: 312
#     Train Result: 0.7488     std: 0.0106
#
#     elapsed time: 9:43, 5 fold time: 0:33
#     time left: 14: 8
#
#
#
# Fitting candidate 12 of 27
#     learning_rate : 0.03     max_depth : 4     min_child_weight : 6
#     Test Result: 1.2501     std: 0.0473       n iter: 383
#     Train Result: 0.6905     std: 0.0156
#
#     elapsed time: 10:22, 5 fold time: 0:39
#     time left: 12:58
#
#
#
# Fitting candidate 13 of 27
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 4
#     Test Result: 1.2454     std: 0.0461       n iter: 326
#     Train Result: 0.5539     std: 0.0157
#
#     elapsed time: 11:04, 5 fold time: 0:42
#     time left: 11:55
#
#
#
# Fitting candidate 14 of 27
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 5
#     Test Result: 1.2485     std: 0.0503       n iter: 338
#     Train Result: 0.5440     std: 0.0164
#
#     elapsed time: 11:47, 5 fold time: 0:43
#     time left: 10:56
#
#
#
# Fitting candidate 15 of 27
#     learning_rate : 0.03     max_depth : 5     min_child_weight : 6
#     Test Result: 1.2463     std: 0.0485       n iter: 414
#     Train Result: 0.4776     std: 0.0163
#
#     elapsed time: 12:37, 5 fold time: 0:50
#     time left: 10: 6
#
#
#
# Fitting candidate 16 of 27
#     learning_rate : 0.03     max_depth : 6     min_child_weight : 4
#     Test Result: 1.2442     std: 0.0420       n iter: 283
#     Train Result: 0.4288     std: 0.0160
#
#     elapsed time: 13:21, 5 fold time: 0:44
#     time left: 9:11
#
#
#
# Fitting candidate 17 of 27
#     learning_rate : 0.03     max_depth : 6     min_child_weight : 5
#     Test Result: 1.2410     std: 0.0497       n iter: 364
#     Train Result: 0.3560     std: 0.0119
#
#     elapsed time: 14:14, 5 fold time: 0:53
#     time left: 8:23
#
#
#
# Fitting candidate 18 of 27
#     learning_rate : 0.03     max_depth : 6     min_child_weight : 6
#     Test Result: 1.2484     std: 0.0507       n iter: 207
#     Train Result: 0.5469     std: 0.0149
#
#     elapsed time: 14:49, 5 fold time: 0:34
#     time left: 7:24
#
#
#
# Fitting candidate 19 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 4
#     Test Result: 1.2477     std: 0.0447       n iter: 201
#     Train Result: 0.7904     std: 0.0072
#
#     elapsed time: 15:13, 5 fold time: 0:24
#     time left: 6:24
#
#
#
# Fitting candidate 20 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 5
#     Test Result: 1.2487     std: 0.0460       n iter: 248
#     Train Result: 0.7331     std: 0.0127
#
#     elapsed time: 15:40, 5 fold time: 0:28
#     time left: 5:29
#
#
#
# Fitting candidate 21 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 6
#     Test Result: 1.2503     std: 0.0459       n iter: 214
#     Train Result: 0.7761     std: 0.0136
#
#     elapsed time: 16:05, 5 fold time: 0:25
#     time left: 4:36
#
#
#
# Fitting candidate 22 of 27
#     learning_rate : 0.04     max_depth : 5     min_child_weight : 4
#     Test Result: 1.2464     std: 0.0475       n iter: 206
#     Train Result: 0.6105     std: 0.0141
#
#     elapsed time: 16:35, 5 fold time: 0:29
#     time left: 3:46
#
#
#
# Fitting candidate 23 of 27
#     learning_rate : 0.04     max_depth : 5     min_child_weight : 5
#     Test Result: 1.2481     std: 0.0488       n iter: 200
#     Train Result: 0.6238     std: 0.0207
#
#     elapsed time: 17:04, 5 fold time: 0:29
#     time left: 2:58
#
#
#
# Fitting candidate 24 of 27
#     learning_rate : 0.04     max_depth : 5     min_child_weight : 6
#     Test Result: 1.2506     std: 0.0521       n iter: 208
#     Train Result: 0.6128     std: 0.0146
#
#     elapsed time: 17:33, 5 fold time: 0:29
#     time left: 2:12
#
#
#
# Fitting candidate 25 of 27
#     learning_rate : 0.04     max_depth : 6     min_child_weight : 4
#     Test Result: 1.2453     std: 0.0487       n iter: 204
#     Train Result: 0.4448     std: 0.0075
#
#     elapsed time: 18:07, 5 fold time: 0:34
#     time left: 1:27
#
#
#
# Fitting candidate 26 of 27
#     learning_rate : 0.04     max_depth : 6     min_child_weight : 5
#     Test Result: 1.2487     std: 0.0494       n iter: 128
#     Train Result: 0.5980     std: 0.0170
#
#     elapsed time: 18:32, 5 fold time: 0:25
#     time left: 0:43
#
#
#
# Fitting candidate 27 of 27
#     learning_rate : 0.04     max_depth : 6     min_child_weight : 6
#     Test Result: 1.2489     std: 0.0509       n iter: 219
#     Train Result: 0.4197     std: 0.0113
#
#     elapsed time: 19:08, 5 fold time: 0:36
#     time left: 0: 0
# array([[[1.2471612, 1.2476714, 1.2506022],
#         [1.2497324, 1.2469806, 1.2447368],
#         [1.244046 , 1.2391032, 1.2458712]],
#
#        [[1.2461772, 1.2475256, 1.2500908],
#         [1.2453734, 1.2485238, 1.2462764],
#         [1.2441536, 1.2409586, 1.2483748]],
#
#        [[1.2477356, 1.2486928, 1.2502862],
#         [1.2464464, 1.2481086, 1.2506102],
#         [1.2453188, 1.2487146, 1.2488696]]])

# %%
GS_ERBB2._best_score
# Out:
# 1.2391032000000002

# %%
get_best_params(GS_ERBB2)
# Out:
#     Learning_rate:     0.02
#     max_depth:         6
#     min_child_weight:  5

# %% [markdown]
# ### CDK4

# %%
param_test_CDK4 = {
    "learning_rate" : [0.04, 0.05, 0.06],
    "max_depth" : [2, 3, 4],
    "min_child_weight" : [4, 5, 6]
}

# %%
GS_CDK4 = XGBGridSearch(xgb1, param_test_CDK4, cv=5)
X = datasets["ERBB2"]["X_train"]
Y = datasets["ERBB2"]["y_train"]
GS_CDK4.fit(X, Y)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits.
# Fitting candidate 1 of 27
#     learning_rate : 0.04     max_depth : 2     min_child_weight : 4
#     Test Result: 1.2642     std: 0.0385       n iter: 538
#     Train Result: 0.9356     std: 0.0072
#
#     elapsed time: 0:30, 5 fold time: 0:30
#     time left: 12:54
#
#
#
# Fitting candidate 2 of 27
#     learning_rate : 0.04     max_depth : 2     min_child_weight : 5
#     Test Result: 1.2651     std: 0.0393       n iter: 424
#     Train Result: 0.9810     std: 0.0076
#
#     elapsed time: 0:54, 5 fold time: 0:24
#     time left: 11:18
#
#
#
# Fitting candidate 3 of 27
#     learning_rate : 0.04     max_depth : 2     min_child_weight : 6
#     Test Result: 1.2660     std: 0.0384       n iter: 531
#     Train Result: 0.9384     std: 0.0061
#
#     elapsed time: 1:24, 5 fold time: 0:30
#     time left: 11:11
#
#
#
# Fitting candidate 4 of 27
#     learning_rate : 0.04     max_depth : 3     min_child_weight : 4
#     Test Result: 1.2532     std: 0.0431       n iter: 396
#     Train Result: 0.7962     std: 0.0089
#
#     elapsed time: 1:55, 5 fold time: 0:32
#     time left: 11: 3
#
#
#
# Fitting candidate 5 of 27
#     learning_rate : 0.04     max_depth : 3     min_child_weight : 5
#     Test Result: 1.2545     std: 0.0456       n iter: 246
#     Train Result: 0.9088     std: 0.0054
#
#     elapsed time: 2:17, 5 fold time: 0:22
#     time left: 10: 2
#
#
#
# Fitting candidate 6 of 27
#     learning_rate : 0.04     max_depth : 3     min_child_weight : 6
#     Test Result: 1.2513     std: 0.0401       n iter: 393
#     Train Result: 0.8002     std: 0.0084
#
#     elapsed time: 2:48, 5 fold time: 0:31
#     time left: 9:49
#
#
#
# Fitting candidate 7 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 4
#     Test Result: 1.2477     std: 0.0447       n iter: 201
#     Train Result: 0.7904     std: 0.0072
#
#     elapsed time: 3:12, 5 fold time: 0:24
#     time left: 9: 9
#
#
#
# Fitting candidate 8 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 5
#     Test Result: 1.2487     std: 0.0460       n iter: 248
#     Train Result: 0.7331     std: 0.0127
#
#     elapsed time: 3:40, 5 fold time: 0:28
#     time left: 8:42
#
#
#
# Fitting candidate 9 of 27
#     learning_rate : 0.04     max_depth : 4     min_child_weight : 6
#     Test Result: 1.2503     std: 0.0459       n iter: 214
#     Train Result: 0.7761     std: 0.0136
#
#     elapsed time: 4:05, 5 fold time: 0:25
#     time left: 8: 9
#
#
#
# Fitting candidate 10 of 27
#     learning_rate : 0.05     max_depth : 2     min_child_weight : 4
#     Test Result: 1.2645     std: 0.0387       n iter: 435
#     Train Result: 0.9339     std: 0.0085
#
#     elapsed time: 4:30, 5 fold time: 0:25
#     time left: 7:39
#
#
#
# Fitting candidate 11 of 27
#     learning_rate : 0.05     max_depth : 2     min_child_weight : 5
#     Test Result: 1.2652     std: 0.0345       n iter: 436
#     Train Result: 0.9329     std: 0.0073
#
#     elapsed time: 4:55, 5 fold time: 0:25
#     time left: 7: 9
#
#
#
# Fitting candidate 12 of 27
#     learning_rate : 0.05     max_depth : 2     min_child_weight : 6
#     Test Result: 1.2680     std: 0.0375       n iter: 348
#     Train Result: 0.9754     std: 0.0072
#
#     elapsed time: 5:16, 5 fold time: 0:21
#     time left: 6:35
#
#
#
# Fitting candidate 13 of 27
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 4
#     Test Result: 1.2550     std: 0.0448       n iter: 247
#     Train Result: 0.8561     std: 0.0067
#
#     elapsed time: 5:38, 5 fold time: 0:22
#     time left: 6: 4
#
#
#
# Fitting candidate 14 of 27
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 5
#     Test Result: 1.2533     std: 0.0457       n iter: 292
#     Train Result: 0.8186     std: 0.0075
#
#     elapsed time: 6:03, 5 fold time: 0:25
#     time left: 5:37
#
#
#
# Fitting candidate 15 of 27
#     learning_rate : 0.05     max_depth : 3     min_child_weight : 6
#     Test Result: 1.2552     std: 0.0454       n iter: 324
#     Train Result: 0.7886     std: 0.0061
#
#     elapsed time: 6:29, 5 fold time: 0:27
#     time left: 5:12
#
#
#
# Fitting candidate 16 of 27
#     learning_rate : 0.05     max_depth : 4     min_child_weight : 4
#     Test Result: 1.2466     std: 0.0446       n iter: 187
#     Train Result: 0.7465     std: 0.0089
#
#     elapsed time: 6:52, 5 fold time: 0:23
#     time left: 4:43
#
#
#
# Fitting candidate 17 of 27
#     learning_rate : 0.05     max_depth : 4     min_child_weight : 5
#     Test Result: 1.2561     std: 0.0467       n iter: 153
#     Train Result: 0.8031     std: 0.0138
#
#     elapsed time: 7:12, 5 fold time: 0:20
#     time left: 4:14
#
#
#
# Fitting candidate 18 of 27
#     learning_rate : 0.05     max_depth : 4     min_child_weight : 6
#     Test Result: 1.2540     std: 0.0444       n iter: 172
#     Train Result: 0.7708     std: 0.0105
#
#     elapsed time: 7:33, 5 fold time: 0:21
#     time left: 3:47
#
#
#
# Fitting candidate 19 of 27
#     learning_rate : 0.06     max_depth : 2     min_child_weight : 4
#     Test Result: 1.2642     std: 0.0410       n iter: 291
#     Train Result: 0.9748     std: 0.0075
#
#     elapsed time: 7:51, 5 fold time: 0:18
#     time left: 3:18
#
#
#
# Fitting candidate 20 of 27
#     learning_rate : 0.06     max_depth : 2     min_child_weight : 5
#     Test Result: 1.2640     std: 0.0391       n iter: 302
#     Train Result: 0.9686     std: 0.0066
#
#     elapsed time: 8:10, 5 fold time: 0:19
#     time left: 2:51
#
#
#
# Fitting candidate 21 of 27
#     learning_rate : 0.06     max_depth : 2     min_child_weight : 6
#     Test Result: 1.2649     std: 0.0392       n iter: 346
#     Train Result: 0.9422     std: 0.0067
#
#     elapsed time: 8:31, 5 fold time: 0:21
#     time left: 2:26
#
#
#
# Fitting candidate 22 of 27
#     learning_rate : 0.06     max_depth : 3     min_child_weight : 4
#     Test Result: 1.2581     std: 0.0401       n iter: 254
#     Train Result: 0.8043     std: 0.0077
#
#     elapsed time: 8:54, 5 fold time: 0:22
#     time left: 2: 1
#
#
#
# Fitting candidate 23 of 27
#     learning_rate : 0.06     max_depth : 3     min_child_weight : 5
#     Test Result: 1.2532     std: 0.0437       n iter: 263
#     Train Result: 0.7942     std: 0.0062
#
#     elapsed time: 9:16, 5 fold time: 0:23
#     time left: 1:37
#
#
#
# Fitting candidate 24 of 27
#     learning_rate : 0.06     max_depth : 3     min_child_weight : 6
#     Test Result: 1.2530     std: 0.0471       n iter: 239
#     Train Result: 0.8216     std: 0.0056
#
#     elapsed time: 9:38, 5 fold time: 0:21
#     time left: 1:12
#
#
#
# Fitting candidate 25 of 27
#     learning_rate : 0.06     max_depth : 4     min_child_weight : 4
#     Test Result: 1.2458     std: 0.0407       n iter: 182
#     Train Result: 0.7010     std: 0.0116
#
#     elapsed time: 9:60, 5 fold time: 0:22
#     time left: 0:48
#
#
#
# Fitting candidate 26 of 27
#     learning_rate : 0.06     max_depth : 4     min_child_weight : 5
#     Test Result: 1.2492     std: 0.0443       n iter: 147
#     Train Result: 0.7640     std: 0.0134
#
#     elapsed time: 10:19, 5 fold time: 0:19
#     time left: 0:24
#
#
#
# Fitting candidate 27 of 27
#     learning_rate : 0.06     max_depth : 4     min_child_weight : 6
#     Test Result: 1.2507     std: 0.0434       n iter: 174
#     Train Result: 0.7163     std: 0.0095
#
#     elapsed time: 10:41, 5 fold time: 0:22
#     time left: 0: 0
# array([[[1.2642074, 1.2651386, 1.2659778],
#         [1.2532082, 1.2545066, 1.2512548],
#         [1.2477356, 1.2486928, 1.2502862]],
#
#        [[1.264482 , 1.2651654, 1.2679814],
#         [1.2550032, 1.2532502, 1.255223 ],
#         [1.2465514, 1.2560804, 1.2539526]],
#
#        [[1.2641636, 1.2639614, 1.2649286],
#         [1.2581212, 1.2531802, 1.2530012],
#         [1.2458494, 1.2491978, 1.2506916]]])

# %%
GS_CDK4._best_score
# Out:
# 1.2458494000000002

# %%
get_best_params(GS_CDK4)
# Out:
#     Learning_rate:     0.06
#     max_depth:         4
#     min_child_weight:  4

# %% [markdown]
# ### CDK1

# %%
param_test_CDK1 = {
    "learning_rate" : [0.06, 0.07, 0.08],
    "max_depth" : [2, 3, 4],
    "min_child_weight" : [6, 7, 8]
}

# %%
GS_CDK1 = XGBGridSearch(xgb1, param_test_CDK1, cv=5)
X = datasets[gene]["X_train"]
Y = datasets[gene]["y_train"]
GS_CDK1.fit(X, Y)

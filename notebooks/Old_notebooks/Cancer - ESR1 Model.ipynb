# %% [markdown]
# # Predicting expression of ESR1 using single cell data

# %% [markdown]
# We use XGBoost to predict the expression of a gene based on the expression of the other genes in the cell.

# %%
import pandas as pd
from src.grid_search import create_model
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
import pickle
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler

from src.modules import train_test_val_split, plot_prediction, shap_tester, plot_importance, plot_training_xgb, XGB_CV
from src.data_handling import transpose_set_ind, compute_correlation, root_mse, count_non_nans

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_pickle("/data/severs/rna_scaled_cancer_T_NaN.pkl")

# %%
with open('/data/severs/high_q_cell_names.pkl', 'rb') as handle:
    high_quality_cells = pickle.load(handle)

# %%
df = df.loc[high_quality_cells["Cancer"]]

# %%
correlation, p_values, n = compute_correlation(df, "ESR1", fdr=True)
# Out:
#   0%|          | 0/28635 [00:00<?, ?it/s]
# divide by zero encountered in double_scalars

# %%
ESR1_df = pd.DataFrame()

# %%
ESR1_df = ESR1_df.append(pd.Series(correlation, name="Correlation"))
ESR1_df = ESR1_df.append(pd.Series(p_values, name="FDR p-values"))

# %%
ESR1_df = ESR1_df.append(pd.Series(n, name="# non-NaNs"))

# %%
ESR1_df.columns = df.columns

# %%
ESR1_df.to_pickle("/data/severs/ESR1_correlation_p_values.pkl")

# %%
ESR1_df = ESR1_df.T

# %%
ESR1_df = ESR1_df[ESR1_df['# non-NaNs'] > 0.8*df.shape[0]]

# %%
ESR1_df = ESR1_df[ESR1_df['FDR p-values'] < 0.05]

# %%
input_variables = ESR1_df.sort_values("Correlation").index[-1001:-1]

# %%
X = df[input_variables]
Y = df.ESR1

# %%
fig, ax = plt.subplots(dpi=200)
ax.scatter(np.arange(28635),abs(correlation[sorter]), s=0.6)
ax.scatter(np.arange(28635),p_values[sorter]*2, s=0.3)
ax.scatter(np.arange(28635),fdr[1][sorter], s=0.3)
ax.plot((0,28635), (0.05, 0.05), color="r")
ax2 = ax.twinx()

# %%
df_new = pd.read_csv("/data/xiaoral/ESR1_cancer_corr.csv")

# %%
df_new = df_new.sort_values("ESR1_pvals")

# %%
df_new
# Out:
#            Unnamed: 0   cor_pearson  ESR1_pvals  ESR1_padjust
# 18645       LINC00508  9.918604e-01    0.000000      0.000000
# 16345        ANKRD30A  3.182781e-01    0.000000      0.000000
# 8511             STC2  3.173193e-01    0.000000      0.000000
# 3651             AFF3  3.142950e-01    0.000000      0.000000
# 16999           GFRA1  3.110341e-01    0.000000      0.000000
# ...               ...           ...         ...           ...
# 18536   RP11-173P15.9 -5.136561e-06    0.999573      0.999713
# 28231  CH507-154B10.1 -3.504492e-06    0.999644      0.999748
# 12602          SMIM18  3.083198e-06    0.999695      0.999765
# 16285    RP11-85G18.6  2.419339e-06    0.999755      0.999789
# 22486    RP11-190D6.2  2.485070e-08    0.999999      0.999999
#
# [28634 rows x 4 columns]

# %%
fig, ax = plt.subplots(dpi=150)
ax.scatter(np.arange(28634),abs(df_new.cor_pearson), s=0.6)
ax.scatter(np.arange(28634),df_new.ESR1_pvals, s=0.3)
ax.scatter(np.arange(28634),df_new.ESR1_padjust, s=0.3)
ax.plot((0,28635), (0.05, 0.05), color="r")
ax2 = ax.twinx()

# %%
df_new
# Out:
#          Unnamed: 0  cor_pearson  ESR1_pvals  ESR1_padjust
# 0      RP11-34P13.3    -0.002411    0.912028      0.948430
# 1      RP11-34P13.7    -0.000186    0.981236      0.989530
# 2      RP11-34P13.8    -0.013423    0.259052      0.393826
# 3        FO538757.3     0.017909    0.026310      0.061838
# 4        FO538757.2     0.010062    0.199834      0.322859
# ...             ...          ...         ...           ...
# 28629    AC023491.2     0.013891    0.610368      0.733888
# 28630    AC004556.1     0.002263    0.785676      0.864473
# 28631    AC233755.2     0.011715    0.227133      0.356291
# 28632    AC233755.1     0.019461    0.030943      0.070955
# 28633    AC240274.1     0.018578    0.017923      0.044887
#
# [28634 rows x 4 columns]

# %% [markdown]
# # Simple first model

# %%
import xgboost as xgb
from xgboost.sklearn import XGBRegressor

# %%
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", seed=1, eta=0.03, n_estimators=1000, n_jobs=80, max_depth=3)

# %%
X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(X, Y)

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]

# %%
# %time xgb_model.fit(X_train, y_train, verbose=False, early_stopping_rounds=30, eval_set = eval_set)
# Out:
# CPU times: user 19min 45s, sys: 8.69 s, total: 19min 53s
# Wall time: 15 s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eta=0.03, gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.0299999993, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=80, num_parallel_tree=1, random_state=1,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred_xgb = xgb_model.predict(X_test)

# %%
y_pred_xgb_val = xgb_model.predict(X_val)

# %%
y_pred_xgb_train = xgb_model.predict(X_train)

# %%
fig, axes = plt.subplots(2,2, figsize=(14,10), dpi=300)
plot_prediction(y_test, y_pred_xgb, fig=fig, ax=axes[0][0], title="Pred on test");
plot_prediction(y_val, y_pred_xgb_val, fig=fig, ax=axes[1][0], title="Predictions on validation set");
plot_prediction(y_train, y_pred_xgb_train, fig=fig, ax=axes[0][1], title="Pred on train");
plot_training_xgb(xgb_model.evals_result_, fig=fig, ax=axes[1][1], title="Training error")
fig.savefig("predictions.png", dpi=300)

# %% [markdown]
# # Model tuning ESR1

# %% [markdown]
# We do a stepwise tuning where we tune groups of parameters instead of all at once to save computing power

# %%
from src.model_selection import XGBGridSearch

# %%
# The base model used for tuning
xgb1 = XGBRegressor(objective="reg:squarederror", 
                   seed=1, 
                   learning_rate=0.03, 
                   n_estimators=1000, 
                   n_jobs=80, max_depth=3, 
                   colsample_bytree=1,
                   subsample=1, verbosity=0, silent=True)

# %%
X = df[input_variables]
Y = df.ESR1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)

# %%
param_test1 = {
   'learning_rate' : [0.01, 0.03, 0.07, 0.1, 0.15],
    'max_depth' : [3,5,7]
}

# %%
GS1 = XGBGridSearch(xgb1, param_test1, cv=5)

# %%
GS1.fit(X, Y)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 candidates.
# Fitting candidate 1 of 15
#     learning_rate : 0.01     max_depth : 3
#     Test Result: 0.8183     std: 0.0402       n iter: 600
#     Train Result: 0.6395     std: 0.0091
#
#
# Fitting candidate 2 of 15
#     learning_rate : 0.01     max_depth : 5
#     Test Result: 0.8095     std: 0.0413       n iter: 600
#     Train Result: 0.4602     std: 0.0074
#
#
# Fitting candidate 3 of 15
#     learning_rate : 0.01     max_depth : 7
#     Test Result: 0.8237     std: 0.0330       n iter: 600
#     Train Result: 0.3028     std: 0.0067
#
#
# Fitting candidate 4 of 15
#     learning_rate : 0.03     max_depth : 3
#     Test Result: 0.8126     std: 0.0385       n iter: 377
#     Train Result: 0.5606     std: 0.0071
#
#
# Fitting candidate 5 of 15
#     learning_rate : 0.03     max_depth : 5
#     Test Result: 0.8053     std: 0.0378       n iter: 308
#     Train Result: 0.3924     std: 0.0072
#
#
# Fitting candidate 6 of 15
#     learning_rate : 0.03     max_depth : 7
#     Test Result: 0.8210     std: 0.0342       n iter: 267
#     Train Result: 0.2526     std: 0.0099
#
#
# Fitting candidate 7 of 15
#     learning_rate : 0.07     max_depth : 3
#     Test Result: 0.8134     std: 0.0386       n iter: 226
#     Train Result: 0.5098     std: 0.0085
#
#
# Fitting candidate 8 of 15
#     learning_rate : 0.07     max_depth : 5
#     Test Result: 0.8099     std: 0.0405       n iter: 139
#     Train Result: 0.3824     std: 0.0104
#
#
# Fitting candidate 9 of 15
#     learning_rate : 0.07     max_depth : 7
#     Test Result: 0.8283     std: 0.0364       n iter: 113
#     Train Result: 0.2535     std: 0.0064
#
#
# Fitting candidate 10 of 15
#     learning_rate : 0.1     max_depth : 3
#     Test Result: 0.8107     std: 0.0376       n iter: 171
#     Train Result: 0.4984     std: 0.0073
#
#
# Fitting candidate 11 of 15
#     learning_rate : 0.1     max_depth : 5
#     Test Result: 0.8143     std: 0.0438       n iter: 73
#     Train Result: 0.4279     std: 0.0066
#
#
# Fitting candidate 12 of 15
#     learning_rate : 0.1     max_depth : 7
#     Test Result: 0.8285     std: 0.0329       n iter: 89
#     Train Result: 0.2333     std: 0.0049
#
#
# Fitting candidate 13 of 15
#     learning_rate : 0.15     max_depth : 3
#     Test Result: 0.8209     std: 0.0347       n iter: 114
#     Train Result: 0.4990     std: 0.0102
#
#
# Fitting candidate 14 of 15
#     learning_rate : 0.15     max_depth : 5
#     Test Result: 0.8181     std: 0.0365       n iter: 60
#     Train Result: 0.3981     std: 0.0093
#
#
# Fitting candidate 15 of 15
#     learning_rate : 0.15     max_depth : 7
#     Test Result: 0.8346     std: 0.0444       n iter: 46
#     Train Result: 0.2787     std: 0.0130
# array([[0.81828  , 0.8094724, 0.8237374],
#        [0.812628 , 0.8052946, 0.8210024],
#        [0.813352 , 0.8098998, 0.828257 ],
#        [0.8107044, 0.8143066, 0.8284724],
#        [0.8209286, 0.818097 , 0.8346214]])

# %%
GS1.plot_search(title="Grid search for max_depth and learning_rate")
# Out:
# (None,
#  <AxesSubplot:title={'center':'Grid search for max_depth and learning_rate'}, xlabel='max_depth', ylabel='learning_rate'>)

# %%
param_test2 = {
   'learning_rate' : [0.02, 0.03, 0.04],
    'max_depth' : [4,5,6]
}

# %%
GS2 = XGBGridSearch(xgb1, param_test2, cv=5)

# %%
GS2.fit(X, Y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 candidates.
# Fitting candidate 1 of 9
#     learning_rate : 0.02     max_depth : 4
#     Test Result: 0.8075     std: 0.0392       n iter: 600
#     Train Result: 0.4457     std: 0.0093
#
#
# Fitting candidate 2 of 9
#     learning_rate : 0.02     max_depth : 5
#     Test Result: 0.8052     std: 0.0394       n iter: 462
#     Train Result: 0.3921     std: 0.0077
#
#
# Fitting candidate 3 of 9
#     learning_rate : 0.02     max_depth : 6
#     Test Result: 0.8172     std: 0.0386       n iter: 422
#     Train Result: 0.3175     std: 0.0048
#
#
# Fitting candidate 4 of 9
#     learning_rate : 0.03     max_depth : 4
#     Test Result: 0.8090     std: 0.0391       n iter: 324
#     Train Result: 0.4779     std: 0.0090
#
#
# Fitting candidate 5 of 9
#     learning_rate : 0.03     max_depth : 5
#     Test Result: 0.8053     std: 0.0378       n iter: 308
#     Train Result: 0.3924     std: 0.0072
#
#
# Fitting candidate 6 of 9
#     learning_rate : 0.03     max_depth : 6
#     Test Result: 0.8156     std: 0.0392       n iter: 281
#     Train Result: 0.3182     std: 0.0080
#
#
# Fitting candidate 7 of 9
#     learning_rate : 0.04     max_depth : 4
#     Test Result: 0.8080     std: 0.0418       n iter: 208
#     Train Result: 0.5002     std: 0.0093
#
#
# Fitting candidate 8 of 9
#     learning_rate : 0.04     max_depth : 5
#     Test Result: 0.8104     std: 0.0392       n iter: 239
#     Train Result: 0.3863     std: 0.0074
#
#
# Fitting candidate 9 of 9
#     learning_rate : 0.04     max_depth : 6
#     Test Result: 0.8184     std: 0.0372       n iter: 220
#     Train Result: 0.3105     std: 0.0122
# array([[0.8074836, 0.8052338, 0.8171634],
#        [0.8089648, 0.8052946, 0.8156252],
#        [0.8080354, 0.8104008, 0.8183932]])

# %%
GS2.plot_search()
# Out:
# (None,
#  <AxesSubplot:title={'center':'Grid Search for XGBRegressor'}, xlabel='max_depth', ylabel='learning_rate'>)

# %%
GS1._best_model
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=1, gamma=None, gpu_id=None,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.03, max_delta_step=None, max_depth=5,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=308, n_jobs=80, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, seed=1, silent=True, subsample=1,
#              tree_method=None, validate_parameters=None, verbosity=0)

# %% [markdown]
# ### Tune subsample, colsample_bytree and min_child_weight

# %%
xgb2 = XGBRegressor( learning_rate =0.03, n_estimators=1000, max_depth=5,
 min_child_weight=1, gamma=0, subsample=1, colsample_bytree=1,
 objective= 'reg:squarederror', scale_pos_weight=1, seed=27, verbosity = 0)

# %%
param_test3 = {
                'subsample' : [0.7,0.8,0.9, 1],
                'min_child_weight':[2, 3], 
                'colsample_bytree' : [0.1, 0.2, 0.3]
}

# %%
param_test3 = {
                'subsample' : [0.7,0.8,0.9, 1],
                'min_child_weight':list(range(1,10,2)), 
                'colsample_bytree' : [0.7,0.8,0.9, 1]
}

# %%
GS3 = XGBGridSearch(GS1._best_model, param_test3, cv=5)

# %%
GS3.fit(X, Y)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 candidates.
# Fitting candidate 1 of 80
#     colsample_bytree : 0.7     min_child_weight : 1     subsample : 0.7
#     Test Result: 0.8088     std: 0.0489       n iter: 306
#     Train Result: 0.4233     std: 0.0057
#
#
# Fitting candidate 2 of 80
#     colsample_bytree : 0.7     min_child_weight : 1     subsample : 0.8
#     Test Result: 0.8081     std: 0.0477       n iter: 244
#     Train Result: 0.4455     std: 0.0062
#
#
# Fitting candidate 3 of 80
#     colsample_bytree : 0.7     min_child_weight : 1     subsample : 0.9
#     Test Result: 0.8049     std: 0.0424       n iter: 325
#     Train Result: 0.3874     std: 0.0076
#
#
# Fitting candidate 4 of 80
#     colsample_bytree : 0.7     min_child_weight : 1     subsample : 1
#     Test Result: 0.8075     std: 0.0387       n iter: 359
#     Train Result: 0.3719     std: 0.0095
#
#
# Fitting candidate 5 of 80
#     colsample_bytree : 0.7     min_child_weight : 3     subsample : 0.7
#     Test Result: 0.8066     std: 0.0472       n iter: 354
#     Train Result: 0.4129     std: 0.0101
#
#
# Fitting candidate 6 of 80
#     colsample_bytree : 0.7     min_child_weight : 3     subsample : 0.8
#     Test Result: 0.8029     std: 0.0461       n iter: 600
#     Train Result: 0.3183     std: 0.0126
#
#
# Fitting candidate 7 of 80
#     colsample_bytree : 0.7     min_child_weight : 3     subsample : 0.9
#     Test Result: 0.8023     std: 0.0429       n iter: 409
#     Train Result: 0.3718     std: 0.0108
#
#
# Fitting candidate 8 of 80
#     colsample_bytree : 0.7     min_child_weight : 3     subsample : 1
#     Test Result: 0.8109     std: 0.0377       n iter: 487
#     Train Result: 0.3367     std: 0.0098
#
#
# Fitting candidate 9 of 80
#     colsample_bytree : 0.7     min_child_weight : 5     subsample : 0.7
#     Test Result: 0.8068     std: 0.0445       n iter: 600
#     Train Result: 0.3517     std: 0.0113
#
#
# Fitting candidate 10 of 80
#     colsample_bytree : 0.7     min_child_weight : 5     subsample : 0.8
#     Test Result: 0.8039     std: 0.0464       n iter: 600
#     Train Result: 0.3407     std: 0.0090
#
#
# Fitting candidate 11 of 80
#     colsample_bytree : 0.7     min_child_weight : 5     subsample : 0.9
#     Test Result: 0.8029     std: 0.0436       n iter: 600
#     Train Result: 0.3351     std: 0.0103
#
#
# Fitting candidate 12 of 80
#     colsample_bytree : 0.7     min_child_weight : 5     subsample : 1
#     Test Result: 0.8070     std: 0.0419       n iter: 600
#     Train Result: 0.3276     std: 0.0112
#
#
# Fitting candidate 13 of 80
#     colsample_bytree : 0.7     min_child_weight : 7     subsample : 0.7
#     Test Result: 0.8052     std: 0.0459       n iter: 504
#     Train Result: 0.3981     std: 0.0114
#
#
# Fitting candidate 14 of 80
#     colsample_bytree : 0.7     min_child_weight : 7     subsample : 0.8
#     Test Result: 0.8041     std: 0.0463       n iter: 448
#     Train Result: 0.4048     std: 0.0094
#
#
# Fitting candidate 15 of 80
#     colsample_bytree : 0.7     min_child_weight : 7     subsample : 0.9
#     Test Result: 0.8004     std: 0.0437       n iter: 419
#     Train Result: 0.4105     std: 0.0072
#
#
# Fitting candidate 16 of 80
#     colsample_bytree : 0.7     min_child_weight : 7     subsample : 1
#     Test Result: 0.8067     std: 0.0426       n iter: 402
#     Train Result: 0.4133     std: 0.0103
#
#
# Fitting candidate 17 of 80
#     colsample_bytree : 0.7     min_child_weight : 9     subsample : 0.7
#     Test Result: 0.8072     std: 0.0463       n iter: 600
#     Train Result: 0.3902     std: 0.0121
#
#
# Fitting candidate 18 of 80
#     colsample_bytree : 0.7     min_child_weight : 9     subsample : 0.8
#     Test Result: 0.8072     std: 0.0495       n iter: 450
#     Train Result: 0.4225     std: 0.0102
#
#
# Fitting candidate 19 of 80
#     colsample_bytree : 0.7     min_child_weight : 9     subsample : 0.9
#     Test Result: 0.8022     std: 0.0424       n iter: 448
#     Train Result: 0.4150     std: 0.0101
#
#
# Fitting candidate 20 of 80
#     colsample_bytree : 0.7     min_child_weight : 9     subsample : 1
#     Test Result: 0.8040     std: 0.0465       n iter: 462
#     Train Result: 0.4098     std: 0.0116
#
#
# Fitting candidate 21 of 80
#     colsample_bytree : 0.8     min_child_weight : 1     subsample : 0.7
#     Test Result: 0.8081     std: 0.0423       n iter: 600
#     Train Result: 0.3014     std: 0.0075
#
#
# Fitting candidate 22 of 80
#     colsample_bytree : 0.8     min_child_weight : 1     subsample : 0.8
#     Test Result: 0.8081     std: 0.0491       n iter: 358
#     Train Result: 0.3835     std: 0.0082
#
#
# Fitting candidate 23 of 80
#     colsample_bytree : 0.8     min_child_weight : 1     subsample : 0.9
#     Test Result: 0.8043     std: 0.0405       n iter: 294
#     Train Result: 0.4049     std: 0.0074
#
#
# Fitting candidate 24 of 80
#     colsample_bytree : 0.8     min_child_weight : 1     subsample : 1
#     Test Result: 0.8055     std: 0.0399       n iter: 383
#     Train Result: 0.3584     std: 0.0099
#
#
# Fitting candidate 25 of 80
#     colsample_bytree : 0.8     min_child_weight : 3     subsample : 0.7
#     Test Result: 0.8066     std: 0.0445       n iter: 600
#     Train Result: 0.3306     std: 0.0124
#
#
# Fitting candidate 26 of 80
#     colsample_bytree : 0.8     min_child_weight : 3     subsample : 0.8
#     Test Result: 0.8038     std: 0.0452       n iter: 353
#     Train Result: 0.4012     std: 0.0087
#
#
# Fitting candidate 27 of 80
#     colsample_bytree : 0.8     min_child_weight : 3     subsample : 0.9
#     Test Result: 0.8046     std: 0.0377       n iter: 336
#     Train Result: 0.4009     std: 0.0083
#
#
# Fitting candidate 28 of 80
#     colsample_bytree : 0.8     min_child_weight : 3     subsample : 1
#     Test Result: 0.8077     std: 0.0405       n iter: 286
#     Train Result: 0.4228     std: 0.0070
#
#
# Fitting candidate 29 of 80
#     colsample_bytree : 0.8     min_child_weight : 5     subsample : 0.7
#     Test Result: 0.8069     std: 0.0421       n iter: 511
#     Train Result: 0.3749     std: 0.0098
#
#
# Fitting candidate 30 of 80
#     colsample_bytree : 0.8     min_child_weight : 5     subsample : 0.8
#     Test Result: 0.8046     std: 0.0452       n iter: 600
#     Train Result: 0.3389     std: 0.0099
#
#
# Fitting candidate 31 of 80
#     colsample_bytree : 0.8     min_child_weight : 5     subsample : 0.9
#     Test Result: 0.8017     std: 0.0427       n iter: 600
#     Train Result: 0.3354     std: 0.0106
#
#
# Fitting candidate 32 of 80
#     colsample_bytree : 0.8     min_child_weight : 5     subsample : 1
#     Test Result: 0.8083     std: 0.0403       n iter: 600
#     Train Result: 0.3260     std: 0.0113
#
#
# Fitting candidate 33 of 80
#     colsample_bytree : 0.8     min_child_weight : 7     subsample : 0.7
#     Test Result: 0.8071     std: 0.0445       n iter: 600
#     Train Result: 0.3713     std: 0.0129
#
#
# Fitting candidate 34 of 80
#     colsample_bytree : 0.8     min_child_weight : 7     subsample : 0.8
#     Test Result: 0.8040     std: 0.0477       n iter: 600
#     Train Result: 0.3623     std: 0.0103
#
#
# Fitting candidate 35 of 80
#     colsample_bytree : 0.8     min_child_weight : 7     subsample : 0.9
#     Test Result: 0.8011     std: 0.0441       n iter: 297
#     Train Result: 0.4579     std: 0.0072
#
#
# Fitting candidate 36 of 80
#     colsample_bytree : 0.8     min_child_weight : 7     subsample : 1
#     Test Result: 0.8088     std: 0.0434       n iter: 428
#     Train Result: 0.4029     std: 0.0111
#
#
# Fitting candidate 37 of 80
#     colsample_bytree : 0.8     min_child_weight : 9     subsample : 0.7
#     Test Result: 0.8073     std: 0.0461       n iter: 471
#     Train Result: 0.4239     std: 0.0115
#
#
# Fitting candidate 38 of 80
#     colsample_bytree : 0.8     min_child_weight : 9     subsample : 0.8
#     Test Result: 0.8054     std: 0.0476       n iter: 450
#     Train Result: 0.4216     std: 0.0096
#
#
# Fitting candidate 39 of 80
#     colsample_bytree : 0.8     min_child_weight : 9     subsample : 0.9
#     Test Result: 0.7983     std: 0.0441       n iter: 451
#     Train Result: 0.4135     std: 0.0091
#
#
# Fitting candidate 40 of 80
#     colsample_bytree : 0.8     min_child_weight : 9     subsample : 1
#     Test Result: 0.8053     std: 0.0456       n iter: 375
#     Train Result: 0.4409     std: 0.0107
#
#
# Fitting candidate 41 of 80
#     colsample_bytree : 0.9     min_child_weight : 1     subsample : 0.7
#     Test Result: 0.8059     std: 0.0448       n iter: 600
#     Train Result: 0.3019     std: 0.0062
#
#
# Fitting candidate 42 of 80
#     colsample_bytree : 0.9     min_child_weight : 1     subsample : 0.8
#     Test Result: 0.8091     std: 0.0518       n iter: 293
#     Train Result: 0.4173     std: 0.0068
#
#
# Fitting candidate 43 of 80
#     colsample_bytree : 0.9     min_child_weight : 1     subsample : 0.9
#     Test Result: 0.8086     std: 0.0422       n iter: 325
#     Train Result: 0.3870     std: 0.0078
#
#
# Fitting candidate 44 of 80
#     colsample_bytree : 0.9     min_child_weight : 1     subsample : 1
#     Test Result: 0.8069     std: 0.0411       n iter: 317
#     Train Result: 0.3890     std: 0.0082
#
#
# Fitting candidate 45 of 80
#     colsample_bytree : 0.9     min_child_weight : 3     subsample : 0.7
#     Test Result: 0.8053     std: 0.0385       n iter: 600
#     Train Result: 0.3285     std: 0.0145
#
#
# Fitting candidate 46 of 80
#     colsample_bytree : 0.9     min_child_weight : 3     subsample : 0.8
#     Test Result: 0.8063     std: 0.0494       n iter: 485
#     Train Result: 0.3507     std: 0.0123
#
#
# Fitting candidate 47 of 80
#     colsample_bytree : 0.9     min_child_weight : 3     subsample : 0.9
#     Test Result: 0.8049     std: 0.0418       n iter: 485
#     Train Result: 0.3418     std: 0.0123
#
#
# Fitting candidate 48 of 80
#     colsample_bytree : 0.9     min_child_weight : 3     subsample : 1
#     Test Result: 0.8081     std: 0.0392       n iter: 482
#     Train Result: 0.3333     std: 0.0084
#
#
# Fitting candidate 49 of 80
#     colsample_bytree : 0.9     min_child_weight : 5     subsample : 0.7
#     Test Result: 0.8037     std: 0.0422       n iter: 358
#     Train Result: 0.4264     std: 0.0090
#
#
# Fitting candidate 50 of 80
#     colsample_bytree : 0.9     min_child_weight : 5     subsample : 0.8
#     Test Result: 0.8081     std: 0.0477       n iter: 448
#     Train Result: 0.3824     std: 0.0090
#
#
# Fitting candidate 51 of 80
#     colsample_bytree : 0.9     min_child_weight : 5     subsample : 0.9
#     Test Result: 0.8018     std: 0.0422       n iter: 600
#     Train Result: 0.3319     std: 0.0106
#
#
# Fitting candidate 52 of 80
#     colsample_bytree : 0.9     min_child_weight : 5     subsample : 1
#     Test Result: 0.8079     std: 0.0427       n iter: 338
#     Train Result: 0.4161     std: 0.0097
#
#
# Fitting candidate 53 of 80
#     colsample_bytree : 0.9     min_child_weight : 7     subsample : 0.7
#     Test Result: 0.8006     std: 0.0464       n iter: 361
#     Train Result: 0.4461     std: 0.0086
#
#
# Fitting candidate 54 of 80
#     colsample_bytree : 0.9     min_child_weight : 7     subsample : 0.8
#     Test Result: 0.8056     std: 0.0478       n iter: 372
#     Train Result: 0.4307     std: 0.0097
#
#
# Fitting candidate 55 of 80
#     colsample_bytree : 0.9     min_child_weight : 7     subsample : 0.9
#     Test Result: 0.8033     std: 0.0469       n iter: 600
#     Train Result: 0.3530     std: 0.0087
#
#
# Fitting candidate 56 of 80
#     colsample_bytree : 0.9     min_child_weight : 7     subsample : 1
#     Test Result: 0.8028     std: 0.0429       n iter: 444
#     Train Result: 0.3967     std: 0.0074
#
#
# Fitting candidate 57 of 80
#     colsample_bytree : 0.9     min_child_weight : 9     subsample : 0.7
#     Test Result: 0.8011     std: 0.0445       n iter: 511
#     Train Result: 0.4115     std: 0.0130
#
#
# Fitting candidate 58 of 80
#     colsample_bytree : 0.9     min_child_weight : 9     subsample : 0.8
#     Test Result: 0.8047     std: 0.0448       n iter: 388
#     Train Result: 0.4413     std: 0.0103
#
#
# Fitting candidate 59 of 80
#     colsample_bytree : 0.9     min_child_weight : 9     subsample : 0.9
#     Test Result: 0.8027     std: 0.0429       n iter: 300
#     Train Result: 0.4690     std: 0.0081
#
#
# Fitting candidate 60 of 80
#     colsample_bytree : 0.9     min_child_weight : 9     subsample : 1
#     Test Result: 0.8063     std: 0.0450       n iter: 301
#     Train Result: 0.4694     std: 0.0082
#
#
# Fitting candidate 61 of 80
#     colsample_bytree : 1     min_child_weight : 1     subsample : 0.7
#     Test Result: 0.8110     std: 0.0469       n iter: 456
#     Train Result: 0.3514     std: 0.0077
#
#
# Fitting candidate 62 of 80
#     colsample_bytree : 1     min_child_weight : 1     subsample : 0.8
#     Test Result: 0.8115     std: 0.0510       n iter: 600
#     Train Result: 0.2871     std: 0.0075
#
#
# Fitting candidate 63 of 80
#     colsample_bytree : 1     min_child_weight : 1     subsample : 0.9
#     Test Result: 0.8066     std: 0.0425       n iter: 306
#     Train Result: 0.3965     std: 0.0057
#
#
# Fitting candidate 64 of 80
#     colsample_bytree : 1     min_child_weight : 1     subsample : 1
#     Test Result: 0.8053     std: 0.0378       n iter: 308
#     Train Result: 0.3924     std: 0.0072
#
#
# Fitting candidate 65 of 80
#     colsample_bytree : 1     min_child_weight : 3     subsample : 0.7
#     Test Result: 0.8036     std: 0.0406       n iter: 600
#     Train Result: 0.3284     std: 0.0127
#
#
# Fitting candidate 66 of 80
#     colsample_bytree : 1     min_child_weight : 3     subsample : 0.8
#     Test Result: 0.8086     std: 0.0446       n iter: 600
#     Train Result: 0.3182     std: 0.0140
#
#
# Fitting candidate 67 of 80
#     colsample_bytree : 1     min_child_weight : 3     subsample : 0.9
#     Test Result: 0.8037     std: 0.0429       n iter: 600
#     Train Result: 0.3114     std: 0.0152
#
#
# Fitting candidate 68 of 80
#     colsample_bytree : 1     min_child_weight : 3     subsample : 1
#     Test Result: 0.8107     std: 0.0390       n iter: 335
#     Train Result: 0.3936     std: 0.0083
#
#
# Fitting candidate 69 of 80
#     colsample_bytree : 1     min_child_weight : 5     subsample : 0.7
#     Test Result: 0.8051     std: 0.0445       n iter: 512
#     Train Result: 0.3708     std: 0.0109
#
#
# Fitting candidate 70 of 80
#     colsample_bytree : 1     min_child_weight : 5     subsample : 0.8
#     Test Result: 0.8051     std: 0.0448       n iter: 376
#     Train Result: 0.4084     std: 0.0079
#
#
# Fitting candidate 71 of 80
#     colsample_bytree : 1     min_child_weight : 5     subsample : 0.9
#     Test Result: 0.8059     std: 0.0430       n iter: 600
#     Train Result: 0.3335     std: 0.0091
#
#
# Fitting candidate 72 of 80
#     colsample_bytree : 1     min_child_weight : 5     subsample : 1
#     Test Result: 0.8078     std: 0.0423       n iter: 600
#     Train Result: 0.3248     std: 0.0111
#
#
# Fitting candidate 73 of 80
#     colsample_bytree : 1     min_child_weight : 7     subsample : 0.7
#     Test Result: 0.8035     std: 0.0426       n iter: 435
#     Train Result: 0.4169     std: 0.0106
#
#
# Fitting candidate 74 of 80
#     colsample_bytree : 1     min_child_weight : 7     subsample : 0.8
#     Test Result: 0.8061     std: 0.0493       n iter: 354
#     Train Result: 0.4355     std: 0.0085
#
#
# Fitting candidate 75 of 80
#     colsample_bytree : 1     min_child_weight : 7     subsample : 0.9
#     Test Result: 0.8046     std: 0.0429       n iter: 600
#     Train Result: 0.3534     std: 0.0111
#
#
# Fitting candidate 76 of 80
#     colsample_bytree : 1     min_child_weight : 7     subsample : 1
#     Test Result: 0.8064     std: 0.0437       n iter: 384
#     Train Result: 0.4167     std: 0.0082
#
#
# Fitting candidate 77 of 80
#     colsample_bytree : 1     min_child_weight : 9     subsample : 0.7
#     Test Result: 0.8083     std: 0.0440       n iter: 428
#     Train Result: 0.4365     std: 0.0126
#
#
# Fitting candidate 78 of 80
#     colsample_bytree : 1     min_child_weight : 9     subsample : 0.8
#     Test Result: 0.8017     std: 0.0486       n iter: 481
#     Train Result: 0.4085     std: 0.0131
#
#
# Fitting candidate 79 of 80
#     colsample_bytree : 1     min_child_weight : 9     subsample : 0.9
#     Test Result: 0.8034     std: 0.0462       n iter: 489
#     Train Result: 0.3986     std: 0.0099
#
#
# Fitting candidate 80 of 80
#     colsample_bytree : 1     min_child_weight : 9     subsample : 1
#     Test Result: 0.8050     std: 0.0439       n iter: 436
#     Train Result: 0.4160     std: 0.0099
# array([[[0.808847 , 0.8081298, 0.8048564, 0.807482 ],
#         [0.8065652, 0.8028648, 0.802311 , 0.8108934],
#         [0.8068456, 0.803883 , 0.802875 , 0.8070142],
#         [0.8051702, 0.8041406, 0.8003864, 0.806671 ],
#         [0.8071664, 0.8071856, 0.8021542, 0.8039636]],
#
#        [[0.808054 , 0.8080916, 0.804312 , 0.8055006],
#         [0.8065892, 0.8038312, 0.8045734, 0.8076736],
#         [0.8069364, 0.8045692, 0.8016932, 0.8083472],
#         [0.8070692, 0.8039752, 0.8011318, 0.8087596],
#         [0.8072602, 0.8054302, 0.7982938, 0.8052904]],
#
#        [[0.8058548, 0.8090544, 0.8085852, 0.8068796],
#         [0.8053298, 0.8062614, 0.804933 , 0.8081072],
#         [0.803685 , 0.8080922, 0.8018118, 0.8079328],
#         [0.8005632, 0.80559  , 0.8032848, 0.8027892],
#         [0.801062 , 0.8046522, 0.8026912, 0.8062922]],
#
#        [[0.8109794, 0.8115096, 0.806568 , 0.8052946],
#         [0.803589 , 0.808567 , 0.8036696, 0.8107266],
#         [0.805073 , 0.805102 , 0.8059498, 0.8077978],
#         [0.8034968, 0.8060582, 0.8046312, 0.8063962],
#         [0.8083224, 0.8017148, 0.803379 , 0.8049898]]])

# %%
GS3._best_params
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': 0.8,
#  'gamma': None,
#  'gpu_id': None,
#  'importance_type': 'gain',
#  'interaction_constraints': None,
#  'learning_rate': 0.03,
#  'max_delta_step': None,
#  'max_depth': 5,
#  'min_child_weight': 9,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 451,
#  'n_jobs': 80,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'scale_pos_weight': None,
#  'subsample': 0.9,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': 0,
#  'seed': 1,
#  'silent': True}

# %%
GS3._best_score
# Out:
# 0.7982937999999999

# %%
param_test4 = {
    "max_depth" : [3, 5, 7, 9],
    "min_child_weight" : [3, 5, 7]
}

# %%
GS4 = XGBGridSearch(GS3._best_model, param_test4, cv=8)

# %%
GS4.fit(X, Y)
# Out:
# Fitting 8 folds for each of 12 candidates, totalling 96 fits.
# Fitting candidate 1 of 12
#     max_depth : 3     min_child_weight : 3
#     Test Result: 0.8091     std: 0.0644       n iter: 600
#     Train Result: 0.5126     std: 0.0073
#
#
# Fitting candidate 2 of 12
#     max_depth : 3     min_child_weight : 5
#     Test Result: 0.8083     std: 0.0630       n iter: 600
#     Train Result: 0.5234     std: 0.0062
#
#
# Fitting candidate 3 of 12
#     max_depth : 3     min_child_weight : 7
#     Test Result: 0.8094     std: 0.0656       n iter: 600
#     Train Result: 0.5327     std: 0.0064
#
#
# Fitting candidate 4 of 12
#     max_depth : 5     min_child_weight : 3

# %% [markdown]
# We find that a minimum child weight of 5 and max depth of 5 are the optimal values. We continue by fine tuning our search by checking for 4-6 for each of the parameters.

# %%
param_test2 = {
 'max_depth':list(range(4,7,1)),
 'min_child_weight':list(range(4,7,1))
}
GS2 = XGBGridSearch(xgb2, param_test2, cv=5)

# %%
GS2.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 candidates.
# Fitting candidate 1 of 9
#     max_depth : 4,     min_child_weight : 4,
#     Result: 0.7428     std: 0.0354
# Fitting candidate 2 of 9
#     max_depth : 4,     min_child_weight : 5,
#     Result: 0.7424     std: 0.0349
# Fitting candidate 3 of 9
#     max_depth : 4,     min_child_weight : 6,
#     Result: 0.7423     std: 0.0361
# Fitting candidate 4 of 9
#     max_depth : 5,     min_child_weight : 4,
#     Result: 0.7412     std: 0.0383
# Fitting candidate 5 of 9
#     max_depth : 5,     min_child_weight : 5,
#     Result: 0.7418     std: 0.0362
# Fitting candidate 6 of 9
#     max_depth : 5,     min_child_weight : 6,
#     Result: 0.7415     std: 0.0376
# Fitting candidate 7 of 9
#     max_depth : 6,     min_child_weight : 4,
#     Result: 0.7412     std: 0.0417
# Fitting candidate 8 of 9
#     max_depth : 6,     min_child_weight : 5,
#     Result: 0.7397     std: 0.0403
# Fitting candidate 9 of 9
#     max_depth : 6,     min_child_weight : 6,
#     Result: 0.7426     std: 0.0407
# array([[0.7428166, 0.742351 , 0.742338 ],
#        [0.7412128, 0.7418472, 0.7414978],
#        [0.7412122, 0.739726 , 0.74263  ]])

# %%
GS2.plot_search()
# Out:
# (None,
#  <AxesSubplot:title={'center':'Grid Search for XGBRegressor'}, xlabel='min_child_weight', ylabel='max_depth'>)

# %% [markdown]
# ### Tune sample_bytree and sub_sample

# %%
param_test3 = {
 'sample_bytree':[0.6,0.8,0.9, 1],
 'sub_sample':[0.6,0.8,0.9, 1]
}

# %%
xgb3 = XGBRegressor( learning_rate =0.03, n_estimators=352, max_depth=6,
 min_child_weight=5, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'reg:squarederror', scale_pos_weight=1, seed=27, verbosity = 0)

# %%
GS3 = XGBGridSearch(xgb3, param_test3, cv=5)

# %%
GS3.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 candidates.
# Fitting candidate 1 of 16
#     sample_bytree : 0.6,     sub_sample : 0.6,
#     Result: 0.7397     std: 0.0403
# Best ^^^
# Fitting candidate 2 of 16
#     sample_bytree : 0.6,     sub_sample : 0.8,
#     Result: 0.7397     std: 0.0403
# Fitting candidate 3 of 16
#     sample_bytree : 0.6,     sub_sample : 0.9,
#     Result: 0.7397     std: 0.0403
# Fitting candidate 4 of 16
#     sample_bytree : 0.6,     sub_sample : 1,
#     Result: 0.7397     std: 0.0403
# Fitting candidate 5 of 16
#     sample_bytree : 0.8,     sub_sample : 0.6,
#     Result: 0.7397     std: 0.0403
# Fitting candidate 6 of 16
#     sample_bytree : 0.8,     sub_sample : 0.8,
#     Result: 0.7397     std: 0.0403
# Fitting candidate 7 of 16
#     sample_bytree : 0.8,     sub_sample : 0.9,
#     Result: 0.7397     std: 0.0403
# Fitting candidate 8 of 16
#     sample_bytree : 0.8,     sub_sample : 1,
#     Result: 0.7397     std: 0.0403
# Fitting candidate 9 of 16
#     sample_bytree : 0.9,     sub_sample : 0.6,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-369-640413eefb3b> in <module>
# ----> 1 GS3.fit(X_train, y_train)
#
# ~/SingleCells/src/model_selection.py in fit(self, X_train, y_train)
#     107
#     108             # Perform cross validation
# --> 109             cvresult = xgb.cv(model_params, xgtrain, num_boost_round=500, early_stopping_rounds=30,  nfold=self.cv, metrics="rmse")
#     110
#     111             # Retrieve results
#
# ~/.conda/envs/ml-severs/lib/python3.9/site-packages/xgboost/training.py in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks, shuffle)
#     513         if callbacks.before_iteration(booster, i, dtrain, None):
#     514             break
# --> 515         booster.update(i, obj)
#     516
#     517         should_break = callbacks.after_iteration(booster, i, dtrain, None)
#
# ~/.conda/envs/ml-severs/lib/python3.9/site-packages/xgboost/training.py in update(self, iteration, obj)
#     262         '''Iterate through folds for update'''
#     263         for fold in self.cvfolds:
# --> 264             fold.update(iteration, obj)
#     265
#     266     def eval(self, iteration, feval):
#
# ~/.conda/envs/ml-severs/lib/python3.9/site-packages/xgboost/training.py in update(self, iteration, fobj)
#     248     def update(self, iteration, fobj):
#     249         """"Update the boosters for one iteration"""
# --> 250         self.bst.update(self.dtrain, iteration, fobj)
#     251
#     252     def eval(self, iteration, feval):
#
# ~/.conda/envs/ml-severs/lib/python3.9/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1278
#    1279         if fobj is None:
# -> 1280             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1281                                                     ctypes.c_int(iteration),
#    1282                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
GS3.plot_search()

# %% [markdown]
# ### Learning rate and max_depth retuning

# %%
param_test4 = {
   'learning_rate' : [0.01, 0.03, 0.7, 0.1, 0.15],
    'max_depth' : [3,5]
}

# %%
#xgb4 = XGBRegressor(**GS3._best_params)
GS4 = XGBGridSearch(xgb3, param_test4, cv=5)

# %%
GS4.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 candidates.
# Fitting candidate 1 of 10
#     learning_rate : 0.01,     max_depth : 3,
#     Test Result: 0.7551     std: 0.0329       n iter: 500
#
#    Train Result: 0.6050     std: 0.0076
# Fitting candidate 2 of 10
#     learning_rate : 0.01,     max_depth : 5,
#     Test Result: 0.7433     std: 0.0348       n iter: 500
#
#    Train Result: 0.4786     std: 0.0077
# Fitting candidate 3 of 10
#     learning_rate : 0.03,     max_depth : 3,
#     Test Result: 0.7460     std: 0.0320       n iter: 500
#
#    Train Result: 0.4804     std: 0.0095
# Fitting candidate 4 of 10
#     learning_rate : 0.03,     max_depth : 5,
#     Test Result: 0.7418     std: 0.0362       n iter: 369
#
#    Train Result: 0.3706     std: 0.0085
# Fitting candidate 5 of 10
#     learning_rate : 0.7,     max_depth : 3,
#     Test Result: 0.8440     std: 0.0310       n iter: 3
#
#    Train Result: 0.7274     std: 0.0138
# Fitting candidate 6 of 10
#     learning_rate : 0.7,     max_depth : 5,
#     Test Result: 0.8379     std: 0.0394       n iter: 3
#
#    Train Result: 0.6450     std: 0.0107
# Fitting candidate 7 of 10
#     learning_rate : 0.1,     max_depth : 3,
#     Test Result: 0.7528     std: 0.0275       n iter: 146
#
#    Train Result: 0.4874     std: 0.0077
# Fitting candidate 8 of 10
#     learning_rate : 0.1,     max_depth : 5,
#     Test Result: 0.7525     std: 0.0343       n iter: 70
#
#    Train Result: 0.4423     std: 0.0088
# Fitting candidate 9 of 10
#     learning_rate : 0.15,     max_depth : 3,
#     Test Result: 0.7616     std: 0.0277       n iter: 63
#
#    Train Result: 0.5430     std: 0.0084
# Fitting candidate 10 of 10
#     learning_rate : 0.15,     max_depth : 5,
#     Test Result: 0.7613     std: 0.0357       n iter: 47
#
#    Train Result: 0.4451     std: 0.0119
# array([[0.755059 , 0.743285 ],
#        [0.7460378, 0.741847 ],
#        [0.8440126, 0.8378552],
#        [0.7527962, 0.7524692],
#        [0.7615556, 0.761301 ]])

# %%
GS4.plot_search()
# Out:
# (None,
#  <AxesSubplot:title={'center':'Grid Search for XGBRegressor'}, xlabel='max_depth', ylabel='learning_rate'>)

# %%
param_test5 = {
   'learning_rate' : [0.02, 0.025, 0.03, 0.035, 0.04],
    'max_depth' : [4,5,6]
}

xgb5 = XGBRegressor( learning_rate =0.03, n_estimators=352, max_depth=6,
 min_child_weight=5, gamma=0, subsample=1, colsample_bytree=1,
 objective= 'reg:squarederror', scale_pos_weight=1, seed=27, verbosity = 0)

# %%
GS5 = XGBGridSearch(xgb5, param_test5, cv=5)

GS5.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 candidates.
# Fitting candidate 1 of 15
#     learning_rate : 0.02     max_depth : 4
#     Test Result: 0.7402     std: 0.0382       n iter: 785
#    Train Result: 0.3882     std: 0.0117
#
#
# Fitting candidate 2 of 15
#     learning_rate : 0.02     max_depth : 5
#     Test Result: 0.7427     std: 0.0388       n iter: 677
#    Train Result: 0.3313     std: 0.0115
#
#
# Fitting candidate 3 of 15
#     learning_rate : 0.02     max_depth : 6
#     Test Result: 0.7416     std: 0.0415       n iter: 724
#    Train Result: 0.2585     std: 0.0079
#
#
# Fitting candidate 4 of 15
#     learning_rate : 0.025     max_depth : 4
#     Test Result: 0.7386     std: 0.0373       n iter: 610
#    Train Result: 0.3918     std: 0.0122
#
#
# Fitting candidate 5 of 15
#     learning_rate : 0.025     max_depth : 5
#     Test Result: 0.7414     std: 0.0397       n iter: 575
#    Train Result: 0.3227     std: 0.0102
#
#
# Fitting candidate 6 of 15
#     learning_rate : 0.025     max_depth : 6
#     Test Result: 0.7415     std: 0.0420       n iter: 489
#    Train Result: 0.2811     std: 0.0079
#
#
# Fitting candidate 7 of 15
#     learning_rate : 0.03     max_depth : 4
#     Test Result: 0.7426     std: 0.0402       n iter: 501
#    Train Result: 0.3942     std: 0.0115
#
#
# Fitting candidate 8 of 15
#     learning_rate : 0.03     max_depth : 5
#     Test Result: 0.7419     std: 0.0407       n iter: 525
#    Train Result: 0.3079     std: 0.0103
#
#
# Fitting candidate 9 of 15
#     learning_rate : 0.03     max_depth : 6
#     Test Result: 0.7441     std: 0.0412       n iter: 484
#    Train Result: 0.2578     std: 0.0077
#
#
# Fitting candidate 10 of 15
#     learning_rate : 0.035     max_depth : 4
#     Test Result: 0.7410     std: 0.0387       n iter: 287
#    Train Result: 0.4493     std: 0.0107
#
#
# Fitting candidate 11 of 15
#     learning_rate : 0.035     max_depth : 5
#     Test Result: 0.7419     std: 0.0418       n iter: 472
#    Train Result: 0.3014     std: 0.0091
#
#
# Fitting candidate 12 of 15
#     learning_rate : 0.035     max_depth : 6
#     Test Result: 0.7437     std: 0.0402       n iter: 299
#    Train Result: 0.3015     std: 0.0109
#
#
# Fitting candidate 13 of 15
#     learning_rate : 0.04     max_depth : 4
#     Test Result: 0.7388     std: 0.0398       n iter: 438
#    Train Result: 0.3684     std: 0.0099
#
#
# Fitting candidate 14 of 15
#     learning_rate : 0.04     max_depth : 5
#     Test Result: 0.7418     std: 0.0395       n iter: 343
#    Train Result: 0.3281     std: 0.0112
#
#
# Fitting candidate 15 of 15
#     learning_rate : 0.04     max_depth : 6
#     Test Result: 0.7438     std: 0.0435       n iter: 279
#    Train Result: 0.2939     std: 0.0099
# array([[0.7401882, 0.742678 , 0.7415538],
#        [0.7385784, 0.7413516, 0.7415422],
#        [0.7425924, 0.7419322, 0.7440758],
#        [0.7410332, 0.7418852, 0.7437156],
#        [0.738755 , 0.7417882, 0.7438116]])

# %%
GS5.plot_search()
# Out:
# (None,
#  <AxesSubplot:title={'center':'Grid Search for XGBRegressor'}, xlabel='max_depth', ylabel='learning_rate'>)

# %%
GS5._best_params["n_estimators"] = 610

# %% [markdown]
# # Best model

# %%
GS5._best_params
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'gpu_id': None,
#  'importance_type': 'gain',
#  'interaction_constraints': None,
#  'learning_rate': 0.025,
#  'max_delta_step': None,
#  'max_depth': 4,
#  'min_child_weight': 5,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 610,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': 0,
#  'seed': 27}

# %%
best_model = XGBRegressor(**GS5._best_params)

# %%
best_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)])
# Out:
# [0]	validation_0-rmse:1.11559	validation_1-rmse:1.07326
# [1]	validation_0-rmse:1.10404	validation_1-rmse:1.06439
# [2]	validation_0-rmse:1.09291	validation_1-rmse:1.05607
# [3]	validation_0-rmse:1.08217	validation_1-rmse:1.04649
# [4]	validation_0-rmse:1.07174	validation_1-rmse:1.03898
# [5]	validation_0-rmse:1.06130	validation_1-rmse:1.03047
# [6]	validation_0-rmse:1.05153	validation_1-rmse:1.02299
# [7]	validation_0-rmse:1.04174	validation_1-rmse:1.01432
# [8]	validation_0-rmse:1.03246	validation_1-rmse:1.00801
# [9]	validation_0-rmse:1.02348	validation_1-rmse:1.00154
# [10]	validation_0-rmse:1.01429	validation_1-rmse:0.99491
# [11]	validation_0-rmse:1.00520	validation_1-rmse:0.98686
# [12]	validation_0-rmse:0.99703	validation_1-rmse:0.98111
# [13]	validation_0-rmse:0.98894	validation_1-rmse:0.97410
# [14]	validation_0-rmse:0.98072	validation_1-rmse:0.96883
# [15]	validation_0-rmse:0.97267	validation_1-rmse:0.96258
# [16]	validation_0-rmse:0.96547	validation_1-rmse:0.95693
# [17]	validation_0-rmse:0.95836	validation_1-rmse:0.95162
# [18]	validation_0-rmse:0.95155	validation_1-rmse:0.94707
# [19]	validation_0-rmse:0.94460	validation_1-rmse:0.94185
# [20]	validation_0-rmse:0.93737	validation_1-rmse:0.93625
# [21]	validation_0-rmse:0.93115	validation_1-rmse:0.93161
# [22]	validation_0-rmse:0.92446	validation_1-rmse:0.92608
# [23]	validation_0-rmse:0.91789	validation_1-rmse:0.92209
# [24]	validation_0-rmse:0.91175	validation_1-rmse:0.91760
# [25]	validation_0-rmse:0.90563	validation_1-rmse:0.91396
# [26]	validation_0-rmse:0.89967	validation_1-rmse:0.91008
# [27]	validation_0-rmse:0.89373	validation_1-rmse:0.90561
# [28]	validation_0-rmse:0.88799	validation_1-rmse:0.90231
# [29]	validation_0-rmse:0.88246	validation_1-rmse:0.89872
# [30]	validation_0-rmse:0.87749	validation_1-rmse:0.89503
# [31]	validation_0-rmse:0.87194	validation_1-rmse:0.89234
# [32]	validation_0-rmse:0.86688	validation_1-rmse:0.88903
# [33]	validation_0-rmse:0.86141	validation_1-rmse:0.88498
# [34]	validation_0-rmse:0.85696	validation_1-rmse:0.88191
# [35]	validation_0-rmse:0.85248	validation_1-rmse:0.87879
# [36]	validation_0-rmse:0.84746	validation_1-rmse:0.87543
# [37]	validation_0-rmse:0.84271	validation_1-rmse:0.87327
# [38]	validation_0-rmse:0.83822	validation_1-rmse:0.87035
# [39]	validation_0-rmse:0.83409	validation_1-rmse:0.86757
# [40]	validation_0-rmse:0.82973	validation_1-rmse:0.86425
# [41]	validation_0-rmse:0.82548	validation_1-rmse:0.86182
# [42]	validation_0-rmse:0.82115	validation_1-rmse:0.86001
# [43]	validation_0-rmse:0.81741	validation_1-rmse:0.85753
# [44]	validation_0-rmse:0.81326	validation_1-rmse:0.85525
# [45]	validation_0-rmse:0.80942	validation_1-rmse:0.85294
# [46]	validation_0-rmse:0.80551	validation_1-rmse:0.85068
# [47]	validation_0-rmse:0.80167	validation_1-rmse:0.84898
# [48]	validation_0-rmse:0.79841	validation_1-rmse:0.84698
# [49]	validation_0-rmse:0.79495	validation_1-rmse:0.84498
# [50]	validation_0-rmse:0.79159	validation_1-rmse:0.84257
# [51]	validation_0-rmse:0.78822	validation_1-rmse:0.84066
# [52]	validation_0-rmse:0.78505	validation_1-rmse:0.83895
# [53]	validation_0-rmse:0.78163	validation_1-rmse:0.83725
# [54]	validation_0-rmse:0.77849	validation_1-rmse:0.83586
# [55]	validation_0-rmse:0.77553	validation_1-rmse:0.83455
# [56]	validation_0-rmse:0.77246	validation_1-rmse:0.83328
# [57]	validation_0-rmse:0.76978	validation_1-rmse:0.83164
# [58]	validation_0-rmse:0.76662	validation_1-rmse:0.82987
# [59]	validation_0-rmse:0.76381	validation_1-rmse:0.82865
# [60]	validation_0-rmse:0.76122	validation_1-rmse:0.82688
# [61]	validation_0-rmse:0.75843	validation_1-rmse:0.82591
# [62]	validation_0-rmse:0.75586	validation_1-rmse:0.82476
# [63]	validation_0-rmse:0.75353	validation_1-rmse:0.82289
# [64]	validation_0-rmse:0.75123	validation_1-rmse:0.82168
# [65]	validation_0-rmse:0.74911	validation_1-rmse:0.82038
# [66]	validation_0-rmse:0.74680	validation_1-rmse:0.81918
# [67]	validation_0-rmse:0.74430	validation_1-rmse:0.81818
# [68]	validation_0-rmse:0.74171	validation_1-rmse:0.81742
# [69]	validation_0-rmse:0.73956	validation_1-rmse:0.81605
# [70]	validation_0-rmse:0.73714	validation_1-rmse:0.81527
# [71]	validation_0-rmse:0.73491	validation_1-rmse:0.81458
# [72]	validation_0-rmse:0.73296	validation_1-rmse:0.81327
# [73]	validation_0-rmse:0.73072	validation_1-rmse:0.81256
# [74]	validation_0-rmse:0.72898	validation_1-rmse:0.81170
# [75]	validation_0-rmse:0.72704	validation_1-rmse:0.81045
# [76]	validation_0-rmse:0.72512	validation_1-rmse:0.80946
# [77]	validation_0-rmse:0.72297	validation_1-rmse:0.80879
# [78]	validation_0-rmse:0.72092	validation_1-rmse:0.80775
# [79]	validation_0-rmse:0.71920	validation_1-rmse:0.80700
# [80]	validation_0-rmse:0.71718	validation_1-rmse:0.80639
# [81]	validation_0-rmse:0.71544	validation_1-rmse:0.80534
# [82]	validation_0-rmse:0.71374	validation_1-rmse:0.80453
# [83]	validation_0-rmse:0.71180	validation_1-rmse:0.80411
# [84]	validation_0-rmse:0.70962	validation_1-rmse:0.80338
# [85]	validation_0-rmse:0.70793	validation_1-rmse:0.80261
# [86]	validation_0-rmse:0.70627	validation_1-rmse:0.80188
# [87]	validation_0-rmse:0.70470	validation_1-rmse:0.80109
# [88]	validation_0-rmse:0.70297	validation_1-rmse:0.80042
# [89]	validation_0-rmse:0.70156	validation_1-rmse:0.79989
# [90]	validation_0-rmse:0.69986	validation_1-rmse:0.79910
# [91]	validation_0-rmse:0.69831	validation_1-rmse:0.79855
# [92]	validation_0-rmse:0.69678	validation_1-rmse:0.79803
# [93]	validation_0-rmse:0.69519	validation_1-rmse:0.79722
# [94]	validation_0-rmse:0.69353	validation_1-rmse:0.79654
# [95]	validation_0-rmse:0.69177	validation_1-rmse:0.79630
# [96]	validation_0-rmse:0.69046	validation_1-rmse:0.79573
# [97]	validation_0-rmse:0.68905	validation_1-rmse:0.79509
# [98]	validation_0-rmse:0.68764	validation_1-rmse:0.79466
# [99]	validation_0-rmse:0.68617	validation_1-rmse:0.79390
# [100]	validation_0-rmse:0.68425	validation_1-rmse:0.79352
# [101]	validation_0-rmse:0.68295	validation_1-rmse:0.79310
# [102]	validation_0-rmse:0.68135	validation_1-rmse:0.79292
# [103]	validation_0-rmse:0.68005	validation_1-rmse:0.79263
# [104]	validation_0-rmse:0.67825	validation_1-rmse:0.79232
# [105]	validation_0-rmse:0.67658	validation_1-rmse:0.79150
# [106]	validation_0-rmse:0.67541	validation_1-rmse:0.79077
# [107]	validation_0-rmse:0.67373	validation_1-rmse:0.79046
# [108]	validation_0-rmse:0.67224	validation_1-rmse:0.78979
# [109]	validation_0-rmse:0.67103	validation_1-rmse:0.78934
# [110]	validation_0-rmse:0.66951	validation_1-rmse:0.78873
# [111]	validation_0-rmse:0.66824	validation_1-rmse:0.78858
# [112]	validation_0-rmse:0.66671	validation_1-rmse:0.78843
# [113]	validation_0-rmse:0.66536	validation_1-rmse:0.78767
# [114]	validation_0-rmse:0.66412	validation_1-rmse:0.78744
# [115]	validation_0-rmse:0.66265	validation_1-rmse:0.78684
# [116]	validation_0-rmse:0.66151	validation_1-rmse:0.78633
# [117]	validation_0-rmse:0.66012	validation_1-rmse:0.78591
# [118]	validation_0-rmse:0.65871	validation_1-rmse:0.78573
# [119]	validation_0-rmse:0.65736	validation_1-rmse:0.78567
# [120]	validation_0-rmse:0.65649	validation_1-rmse:0.78513
# [121]	validation_0-rmse:0.65520	validation_1-rmse:0.78449
# [122]	validation_0-rmse:0.65394	validation_1-rmse:0.78411
# [123]	validation_0-rmse:0.65269	validation_1-rmse:0.78380
# [124]	validation_0-rmse:0.65147	validation_1-rmse:0.78310
# [125]	validation_0-rmse:0.65055	validation_1-rmse:0.78274
# [126]	validation_0-rmse:0.64953	validation_1-rmse:0.78261
# [127]	validation_0-rmse:0.64818	validation_1-rmse:0.78253
# [128]	validation_0-rmse:0.64702	validation_1-rmse:0.78191
# [129]	validation_0-rmse:0.64590	validation_1-rmse:0.78160
# [130]	validation_0-rmse:0.64474	validation_1-rmse:0.78134
# [131]	validation_0-rmse:0.64387	validation_1-rmse:0.78108
# [132]	validation_0-rmse:0.64278	validation_1-rmse:0.78078
# [133]	validation_0-rmse:0.64177	validation_1-rmse:0.78044
# [134]	validation_0-rmse:0.64073	validation_1-rmse:0.78022
# [135]	validation_0-rmse:0.63977	validation_1-rmse:0.77984
# [136]	validation_0-rmse:0.63855	validation_1-rmse:0.77938
# [137]	validation_0-rmse:0.63739	validation_1-rmse:0.77937
# [138]	validation_0-rmse:0.63646	validation_1-rmse:0.77939
# [139]	validation_0-rmse:0.63560	validation_1-rmse:0.77923
# [140]	validation_0-rmse:0.63439	validation_1-rmse:0.77897
# [141]	validation_0-rmse:0.63326	validation_1-rmse:0.77868
# [142]	validation_0-rmse:0.63243	validation_1-rmse:0.77858
# [143]	validation_0-rmse:0.63143	validation_1-rmse:0.77824
# [144]	validation_0-rmse:0.63039	validation_1-rmse:0.77786
# [145]	validation_0-rmse:0.62926	validation_1-rmse:0.77756
# [146]	validation_0-rmse:0.62841	validation_1-rmse:0.77708
# [147]	validation_0-rmse:0.62732	validation_1-rmse:0.77703
# [148]	validation_0-rmse:0.62652	validation_1-rmse:0.77693
# [149]	validation_0-rmse:0.62512	validation_1-rmse:0.77681
# [150]	validation_0-rmse:0.62417	validation_1-rmse:0.77660
# [151]	validation_0-rmse:0.62305	validation_1-rmse:0.77657
# [152]	validation_0-rmse:0.62221	validation_1-rmse:0.77638
# [153]	validation_0-rmse:0.62107	validation_1-rmse:0.77610
# [154]	validation_0-rmse:0.62031	validation_1-rmse:0.77588
# [155]	validation_0-rmse:0.61951	validation_1-rmse:0.77543
# [156]	validation_0-rmse:0.61871	validation_1-rmse:0.77537
# [157]	validation_0-rmse:0.61793	validation_1-rmse:0.77501
# [158]	validation_0-rmse:0.61689	validation_1-rmse:0.77499
# [159]	validation_0-rmse:0.61566	validation_1-rmse:0.77501
# [160]	validation_0-rmse:0.61458	validation_1-rmse:0.77482
# [161]	validation_0-rmse:0.61378	validation_1-rmse:0.77458
# [162]	validation_0-rmse:0.61311	validation_1-rmse:0.77437
# [163]	validation_0-rmse:0.61250	validation_1-rmse:0.77408
# [164]	validation_0-rmse:0.61187	validation_1-rmse:0.77415
# [165]	validation_0-rmse:0.61063	validation_1-rmse:0.77412
# [166]	validation_0-rmse:0.60994	validation_1-rmse:0.77396
# [167]	validation_0-rmse:0.60916	validation_1-rmse:0.77387
# [168]	validation_0-rmse:0.60833	validation_1-rmse:0.77361
# [169]	validation_0-rmse:0.60753	validation_1-rmse:0.77359
# [170]	validation_0-rmse:0.60671	validation_1-rmse:0.77331
# [171]	validation_0-rmse:0.60598	validation_1-rmse:0.77333
# [172]	validation_0-rmse:0.60528	validation_1-rmse:0.77326
# [173]	validation_0-rmse:0.60471	validation_1-rmse:0.77308
# [174]	validation_0-rmse:0.60405	validation_1-rmse:0.77288
# [175]	validation_0-rmse:0.60315	validation_1-rmse:0.77284
# [176]	validation_0-rmse:0.60263	validation_1-rmse:0.77269
# [177]	validation_0-rmse:0.60214	validation_1-rmse:0.77263
# [178]	validation_0-rmse:0.60129	validation_1-rmse:0.77268
# [179]	validation_0-rmse:0.60022	validation_1-rmse:0.77273
# [180]	validation_0-rmse:0.59963	validation_1-rmse:0.77256
# [181]	validation_0-rmse:0.59898	validation_1-rmse:0.77242
# [182]	validation_0-rmse:0.59813	validation_1-rmse:0.77238
# [183]	validation_0-rmse:0.59744	validation_1-rmse:0.77216
# [184]	validation_0-rmse:0.59691	validation_1-rmse:0.77202
# [185]	validation_0-rmse:0.59626	validation_1-rmse:0.77186
# [186]	validation_0-rmse:0.59568	validation_1-rmse:0.77190
# [187]	validation_0-rmse:0.59506	validation_1-rmse:0.77157
# [188]	validation_0-rmse:0.59460	validation_1-rmse:0.77145
# [189]	validation_0-rmse:0.59400	validation_1-rmse:0.77136
# [190]	validation_0-rmse:0.59339	validation_1-rmse:0.77136
# [191]	validation_0-rmse:0.59233	validation_1-rmse:0.77155
# [192]	validation_0-rmse:0.59194	validation_1-rmse:0.77147
# [193]	validation_0-rmse:0.59142	validation_1-rmse:0.77116
# [194]	validation_0-rmse:0.59071	validation_1-rmse:0.77102
# [195]	validation_0-rmse:0.58956	validation_1-rmse:0.77096
# [196]	validation_0-rmse:0.58913	validation_1-rmse:0.77077
# [197]	validation_0-rmse:0.58832	validation_1-rmse:0.77064
# [198]	validation_0-rmse:0.58765	validation_1-rmse:0.77046
# [199]	validation_0-rmse:0.58701	validation_1-rmse:0.77046
# [200]	validation_0-rmse:0.58655	validation_1-rmse:0.77040
# [201]	validation_0-rmse:0.58596	validation_1-rmse:0.77021
# [202]	validation_0-rmse:0.58533	validation_1-rmse:0.76998
# [203]	validation_0-rmse:0.58491	validation_1-rmse:0.76994
# [204]	validation_0-rmse:0.58431	validation_1-rmse:0.76986
# [205]	validation_0-rmse:0.58406	validation_1-rmse:0.76978
# [206]	validation_0-rmse:0.58348	validation_1-rmse:0.76990
# [207]	validation_0-rmse:0.58302	validation_1-rmse:0.76971
# [208]	validation_0-rmse:0.58246	validation_1-rmse:0.76967
# [209]	validation_0-rmse:0.58185	validation_1-rmse:0.76952
# [210]	validation_0-rmse:0.58151	validation_1-rmse:0.76949
# [211]	validation_0-rmse:0.58088	validation_1-rmse:0.76965
# [212]	validation_0-rmse:0.58048	validation_1-rmse:0.76940
# [213]	validation_0-rmse:0.57997	validation_1-rmse:0.76925
# [214]	validation_0-rmse:0.57933	validation_1-rmse:0.76921
# [215]	validation_0-rmse:0.57898	validation_1-rmse:0.76919
# [216]	validation_0-rmse:0.57836	validation_1-rmse:0.76889
# [217]	validation_0-rmse:0.57794	validation_1-rmse:0.76883
# [218]	validation_0-rmse:0.57750	validation_1-rmse:0.76879
# [219]	validation_0-rmse:0.57705	validation_1-rmse:0.76871
# [220]	validation_0-rmse:0.57650	validation_1-rmse:0.76832
# [221]	validation_0-rmse:0.57611	validation_1-rmse:0.76807
# [222]	validation_0-rmse:0.57568	validation_1-rmse:0.76788
# [223]	validation_0-rmse:0.57510	validation_1-rmse:0.76797
# [224]	validation_0-rmse:0.57455	validation_1-rmse:0.76804
# [225]	validation_0-rmse:0.57423	validation_1-rmse:0.76801
# [226]	validation_0-rmse:0.57375	validation_1-rmse:0.76814
# [227]	validation_0-rmse:0.57342	validation_1-rmse:0.76799
# [228]	validation_0-rmse:0.57300	validation_1-rmse:0.76801
# [229]	validation_0-rmse:0.57261	validation_1-rmse:0.76801
# [230]	validation_0-rmse:0.57199	validation_1-rmse:0.76804
# [231]	validation_0-rmse:0.57140	validation_1-rmse:0.76796
# [232]	validation_0-rmse:0.57091	validation_1-rmse:0.76793
# [233]	validation_0-rmse:0.57056	validation_1-rmse:0.76792
# [234]	validation_0-rmse:0.57004	validation_1-rmse:0.76776
# [235]	validation_0-rmse:0.56953	validation_1-rmse:0.76760
# [236]	validation_0-rmse:0.56886	validation_1-rmse:0.76770
# [237]	validation_0-rmse:0.56856	validation_1-rmse:0.76756
# [238]	validation_0-rmse:0.56820	validation_1-rmse:0.76743
# [239]	validation_0-rmse:0.56764	validation_1-rmse:0.76745
# [240]	validation_0-rmse:0.56733	validation_1-rmse:0.76745
# [241]	validation_0-rmse:0.56669	validation_1-rmse:0.76750
# [242]	validation_0-rmse:0.56623	validation_1-rmse:0.76739
# [243]	validation_0-rmse:0.56565	validation_1-rmse:0.76731
# [244]	validation_0-rmse:0.56526	validation_1-rmse:0.76712
# [245]	validation_0-rmse:0.56459	validation_1-rmse:0.76729
# [246]	validation_0-rmse:0.56424	validation_1-rmse:0.76730
# [247]	validation_0-rmse:0.56392	validation_1-rmse:0.76725
# [248]	validation_0-rmse:0.56344	validation_1-rmse:0.76720
# [249]	validation_0-rmse:0.56305	validation_1-rmse:0.76707
# [250]	validation_0-rmse:0.56253	validation_1-rmse:0.76702
# [251]	validation_0-rmse:0.56228	validation_1-rmse:0.76695
# [252]	validation_0-rmse:0.56181	validation_1-rmse:0.76709
# [253]	validation_0-rmse:0.56137	validation_1-rmse:0.76699
# [254]	validation_0-rmse:0.56103	validation_1-rmse:0.76675
# [255]	validation_0-rmse:0.56078	validation_1-rmse:0.76667
# [256]	validation_0-rmse:0.56029	validation_1-rmse:0.76662
# [257]	validation_0-rmse:0.55979	validation_1-rmse:0.76660
# [258]	validation_0-rmse:0.55893	validation_1-rmse:0.76666
# [259]	validation_0-rmse:0.55840	validation_1-rmse:0.76664
# [260]	validation_0-rmse:0.55819	validation_1-rmse:0.76658
# [261]	validation_0-rmse:0.55761	validation_1-rmse:0.76651
# [262]	validation_0-rmse:0.55703	validation_1-rmse:0.76658
# [263]	validation_0-rmse:0.55641	validation_1-rmse:0.76667
# [264]	validation_0-rmse:0.55592	validation_1-rmse:0.76654
# [265]	validation_0-rmse:0.55548	validation_1-rmse:0.76648
# [266]	validation_0-rmse:0.55495	validation_1-rmse:0.76640
# [267]	validation_0-rmse:0.55466	validation_1-rmse:0.76631
# [268]	validation_0-rmse:0.55445	validation_1-rmse:0.76630
# [269]	validation_0-rmse:0.55399	validation_1-rmse:0.76632
# [270]	validation_0-rmse:0.55343	validation_1-rmse:0.76634
# [271]	validation_0-rmse:0.55290	validation_1-rmse:0.76634
# [272]	validation_0-rmse:0.55249	validation_1-rmse:0.76621
# [273]	validation_0-rmse:0.55215	validation_1-rmse:0.76612
# [274]	validation_0-rmse:0.55180	validation_1-rmse:0.76612
# [275]	validation_0-rmse:0.55121	validation_1-rmse:0.76610
# [276]	validation_0-rmse:0.55079	validation_1-rmse:0.76597
# [277]	validation_0-rmse:0.55048	validation_1-rmse:0.76582
# [278]	validation_0-rmse:0.55014	validation_1-rmse:0.76592
# [279]	validation_0-rmse:0.54988	validation_1-rmse:0.76582
# [280]	validation_0-rmse:0.54959	validation_1-rmse:0.76584
# [281]	validation_0-rmse:0.54905	validation_1-rmse:0.76589
# [282]	validation_0-rmse:0.54874	validation_1-rmse:0.76592
# [283]	validation_0-rmse:0.54830	validation_1-rmse:0.76590
# [284]	validation_0-rmse:0.54793	validation_1-rmse:0.76584
# [285]	validation_0-rmse:0.54743	validation_1-rmse:0.76575
# [286]	validation_0-rmse:0.54700	validation_1-rmse:0.76566
# [287]	validation_0-rmse:0.54661	validation_1-rmse:0.76564
# [288]	validation_0-rmse:0.54625	validation_1-rmse:0.76569
# [289]	validation_0-rmse:0.54583	validation_1-rmse:0.76567
# [290]	validation_0-rmse:0.54529	validation_1-rmse:0.76565
# [291]	validation_0-rmse:0.54458	validation_1-rmse:0.76567
# [292]	validation_0-rmse:0.54401	validation_1-rmse:0.76564
# [293]	validation_0-rmse:0.54365	validation_1-rmse:0.76562
# [294]	validation_0-rmse:0.54346	validation_1-rmse:0.76565
# [295]	validation_0-rmse:0.54285	validation_1-rmse:0.76577
# [296]	validation_0-rmse:0.54240	validation_1-rmse:0.76579
# [297]	validation_0-rmse:0.54217	validation_1-rmse:0.76571
# [298]	validation_0-rmse:0.54171	validation_1-rmse:0.76563
# [299]	validation_0-rmse:0.54118	validation_1-rmse:0.76535
# [300]	validation_0-rmse:0.54078	validation_1-rmse:0.76525
# [301]	validation_0-rmse:0.54031	validation_1-rmse:0.76536
# [302]	validation_0-rmse:0.53987	validation_1-rmse:0.76527
# [303]	validation_0-rmse:0.53959	validation_1-rmse:0.76520
# [304]	validation_0-rmse:0.53920	validation_1-rmse:0.76519
# [305]	validation_0-rmse:0.53909	validation_1-rmse:0.76515
# [306]	validation_0-rmse:0.53856	validation_1-rmse:0.76507
# [307]	validation_0-rmse:0.53816	validation_1-rmse:0.76500
# [308]	validation_0-rmse:0.53768	validation_1-rmse:0.76506
# [309]	validation_0-rmse:0.53731	validation_1-rmse:0.76504
# [310]	validation_0-rmse:0.53687	validation_1-rmse:0.76493
# [311]	validation_0-rmse:0.53656	validation_1-rmse:0.76499
# [312]	validation_0-rmse:0.53607	validation_1-rmse:0.76497
# [313]	validation_0-rmse:0.53575	validation_1-rmse:0.76496
# [314]	validation_0-rmse:0.53531	validation_1-rmse:0.76491
# [315]	validation_0-rmse:0.53462	validation_1-rmse:0.76502
# [316]	validation_0-rmse:0.53451	validation_1-rmse:0.76503
# [317]	validation_0-rmse:0.53423	validation_1-rmse:0.76486
# [318]	validation_0-rmse:0.53388	validation_1-rmse:0.76478
# [319]	validation_0-rmse:0.53330	validation_1-rmse:0.76491
# [320]	validation_0-rmse:0.53282	validation_1-rmse:0.76489
# [321]	validation_0-rmse:0.53252	validation_1-rmse:0.76484
# [322]	validation_0-rmse:0.53200	validation_1-rmse:0.76482
# [323]	validation_0-rmse:0.53174	validation_1-rmse:0.76483
# [324]	validation_0-rmse:0.53124	validation_1-rmse:0.76465
# [325]	validation_0-rmse:0.53080	validation_1-rmse:0.76455
# [326]	validation_0-rmse:0.53050	validation_1-rmse:0.76451
# [327]	validation_0-rmse:0.53004	validation_1-rmse:0.76440
# [328]	validation_0-rmse:0.52975	validation_1-rmse:0.76447
# [329]	validation_0-rmse:0.52942	validation_1-rmse:0.76457
# [330]	validation_0-rmse:0.52915	validation_1-rmse:0.76448
# [331]	validation_0-rmse:0.52886	validation_1-rmse:0.76448
# [332]	validation_0-rmse:0.52845	validation_1-rmse:0.76449
# [333]	validation_0-rmse:0.52811	validation_1-rmse:0.76451
# [334]	validation_0-rmse:0.52760	validation_1-rmse:0.76465
# [335]	validation_0-rmse:0.52690	validation_1-rmse:0.76464
# [336]	validation_0-rmse:0.52643	validation_1-rmse:0.76458
# [337]	validation_0-rmse:0.52607	validation_1-rmse:0.76456
# [338]	validation_0-rmse:0.52588	validation_1-rmse:0.76453
# [339]	validation_0-rmse:0.52556	validation_1-rmse:0.76451
# [340]	validation_0-rmse:0.52518	validation_1-rmse:0.76451
# [341]	validation_0-rmse:0.52483	validation_1-rmse:0.76450
# [342]	validation_0-rmse:0.52437	validation_1-rmse:0.76455
# [343]	validation_0-rmse:0.52382	validation_1-rmse:0.76452
# [344]	validation_0-rmse:0.52339	validation_1-rmse:0.76443
# [345]	validation_0-rmse:0.52303	validation_1-rmse:0.76439
# [346]	validation_0-rmse:0.52258	validation_1-rmse:0.76438
# [347]	validation_0-rmse:0.52223	validation_1-rmse:0.76428
# [348]	validation_0-rmse:0.52185	validation_1-rmse:0.76418
# [349]	validation_0-rmse:0.52157	validation_1-rmse:0.76426
# [350]	validation_0-rmse:0.52108	validation_1-rmse:0.76408
# [351]	validation_0-rmse:0.52093	validation_1-rmse:0.76400
# [352]	validation_0-rmse:0.52054	validation_1-rmse:0.76400
# [353]	validation_0-rmse:0.52021	validation_1-rmse:0.76392
# [354]	validation_0-rmse:0.51972	validation_1-rmse:0.76396
# [355]	validation_0-rmse:0.51937	validation_1-rmse:0.76392
# [356]	validation_0-rmse:0.51910	validation_1-rmse:0.76392
# [357]	validation_0-rmse:0.51877	validation_1-rmse:0.76390
# [358]	validation_0-rmse:0.51825	validation_1-rmse:0.76371
# [359]	validation_0-rmse:0.51784	validation_1-rmse:0.76380
# [360]	validation_0-rmse:0.51723	validation_1-rmse:0.76368
# [361]	validation_0-rmse:0.51685	validation_1-rmse:0.76361
# [362]	validation_0-rmse:0.51651	validation_1-rmse:0.76348
# [363]	validation_0-rmse:0.51616	validation_1-rmse:0.76360
# [364]	validation_0-rmse:0.51584	validation_1-rmse:0.76361
# [365]	validation_0-rmse:0.51565	validation_1-rmse:0.76360
# [366]	validation_0-rmse:0.51524	validation_1-rmse:0.76352
# [367]	validation_0-rmse:0.51508	validation_1-rmse:0.76346
# [368]	validation_0-rmse:0.51479	validation_1-rmse:0.76337
# [369]	validation_0-rmse:0.51426	validation_1-rmse:0.76326
# [370]	validation_0-rmse:0.51379	validation_1-rmse:0.76328
# [371]	validation_0-rmse:0.51351	validation_1-rmse:0.76323
# [372]	validation_0-rmse:0.51312	validation_1-rmse:0.76323
# [373]	validation_0-rmse:0.51269	validation_1-rmse:0.76333
# [374]	validation_0-rmse:0.51223	validation_1-rmse:0.76337
# [375]	validation_0-rmse:0.51176	validation_1-rmse:0.76318
# [376]	validation_0-rmse:0.51149	validation_1-rmse:0.76300
# [377]	validation_0-rmse:0.51135	validation_1-rmse:0.76291
# [378]	validation_0-rmse:0.51108	validation_1-rmse:0.76284
# [379]	validation_0-rmse:0.51057	validation_1-rmse:0.76273
# [380]	validation_0-rmse:0.51013	validation_1-rmse:0.76283
# [381]	validation_0-rmse:0.50991	validation_1-rmse:0.76280
# [382]	validation_0-rmse:0.50954	validation_1-rmse:0.76279
# [383]	validation_0-rmse:0.50909	validation_1-rmse:0.76273
# [384]	validation_0-rmse:0.50863	validation_1-rmse:0.76285
# [385]	validation_0-rmse:0.50826	validation_1-rmse:0.76297
# [386]	validation_0-rmse:0.50803	validation_1-rmse:0.76292
# [387]	validation_0-rmse:0.50770	validation_1-rmse:0.76287
# [388]	validation_0-rmse:0.50724	validation_1-rmse:0.76270
# [389]	validation_0-rmse:0.50693	validation_1-rmse:0.76279
# [390]	validation_0-rmse:0.50667	validation_1-rmse:0.76277
# [391]	validation_0-rmse:0.50622	validation_1-rmse:0.76273
# [392]	validation_0-rmse:0.50596	validation_1-rmse:0.76280
# [393]	validation_0-rmse:0.50571	validation_1-rmse:0.76282
# [394]	validation_0-rmse:0.50532	validation_1-rmse:0.76277
# [395]	validation_0-rmse:0.50495	validation_1-rmse:0.76279
# [396]	validation_0-rmse:0.50485	validation_1-rmse:0.76276
# [397]	validation_0-rmse:0.50457	validation_1-rmse:0.76282
# [398]	validation_0-rmse:0.50444	validation_1-rmse:0.76274
# [399]	validation_0-rmse:0.50416	validation_1-rmse:0.76272
# [400]	validation_0-rmse:0.50395	validation_1-rmse:0.76259
# [401]	validation_0-rmse:0.50375	validation_1-rmse:0.76257
# [402]	validation_0-rmse:0.50338	validation_1-rmse:0.76241
# [403]	validation_0-rmse:0.50309	validation_1-rmse:0.76238
# [404]	validation_0-rmse:0.50280	validation_1-rmse:0.76239
# [405]	validation_0-rmse:0.50229	validation_1-rmse:0.76249
# [406]	validation_0-rmse:0.50191	validation_1-rmse:0.76251
# [407]	validation_0-rmse:0.50138	validation_1-rmse:0.76242
# [408]	validation_0-rmse:0.50116	validation_1-rmse:0.76247
# [409]	validation_0-rmse:0.50091	validation_1-rmse:0.76255
# [410]	validation_0-rmse:0.50064	validation_1-rmse:0.76256
# [411]	validation_0-rmse:0.50026	validation_1-rmse:0.76251
# [412]	validation_0-rmse:0.50009	validation_1-rmse:0.76253
# [413]	validation_0-rmse:0.49967	validation_1-rmse:0.76246
# [414]	validation_0-rmse:0.49914	validation_1-rmse:0.76249
# [415]	validation_0-rmse:0.49876	validation_1-rmse:0.76243
# [416]	validation_0-rmse:0.49861	validation_1-rmse:0.76231
# [417]	validation_0-rmse:0.49852	validation_1-rmse:0.76228
# [418]	validation_0-rmse:0.49813	validation_1-rmse:0.76216
# [419]	validation_0-rmse:0.49773	validation_1-rmse:0.76219
# [420]	validation_0-rmse:0.49739	validation_1-rmse:0.76209
# [421]	validation_0-rmse:0.49705	validation_1-rmse:0.76198
# [422]	validation_0-rmse:0.49680	validation_1-rmse:0.76203
# [423]	validation_0-rmse:0.49641	validation_1-rmse:0.76223
# [424]	validation_0-rmse:0.49612	validation_1-rmse:0.76220
# [425]	validation_0-rmse:0.49586	validation_1-rmse:0.76228
# [426]	validation_0-rmse:0.49554	validation_1-rmse:0.76226
# [427]	validation_0-rmse:0.49518	validation_1-rmse:0.76212
# [428]	validation_0-rmse:0.49484	validation_1-rmse:0.76205
# [429]	validation_0-rmse:0.49444	validation_1-rmse:0.76207
# [430]	validation_0-rmse:0.49409	validation_1-rmse:0.76194
# [431]	validation_0-rmse:0.49366	validation_1-rmse:0.76201
# [432]	validation_0-rmse:0.49353	validation_1-rmse:0.76194
# [433]	validation_0-rmse:0.49328	validation_1-rmse:0.76194
# [434]	validation_0-rmse:0.49285	validation_1-rmse:0.76194
# [435]	validation_0-rmse:0.49248	validation_1-rmse:0.76198
# [436]	validation_0-rmse:0.49202	validation_1-rmse:0.76202
# [437]	validation_0-rmse:0.49186	validation_1-rmse:0.76202
# [438]	validation_0-rmse:0.49142	validation_1-rmse:0.76200
# [439]	validation_0-rmse:0.49107	validation_1-rmse:0.76195
# [440]	validation_0-rmse:0.49071	validation_1-rmse:0.76191
# [441]	validation_0-rmse:0.49042	validation_1-rmse:0.76203
# [442]	validation_0-rmse:0.49010	validation_1-rmse:0.76205
# [443]	validation_0-rmse:0.48979	validation_1-rmse:0.76215
# [444]	validation_0-rmse:0.48950	validation_1-rmse:0.76219
# [445]	validation_0-rmse:0.48916	validation_1-rmse:0.76227
# [446]	validation_0-rmse:0.48892	validation_1-rmse:0.76227
# [447]	validation_0-rmse:0.48846	validation_1-rmse:0.76208
# [448]	validation_0-rmse:0.48807	validation_1-rmse:0.76208
# [449]	validation_0-rmse:0.48771	validation_1-rmse:0.76209
# [450]	validation_0-rmse:0.48738	validation_1-rmse:0.76207
# [451]	validation_0-rmse:0.48712	validation_1-rmse:0.76209
# [452]	validation_0-rmse:0.48649	validation_1-rmse:0.76206
# [453]	validation_0-rmse:0.48633	validation_1-rmse:0.76203
# [454]	validation_0-rmse:0.48603	validation_1-rmse:0.76217
# [455]	validation_0-rmse:0.48574	validation_1-rmse:0.76221
# [456]	validation_0-rmse:0.48547	validation_1-rmse:0.76221
# [457]	validation_0-rmse:0.48513	validation_1-rmse:0.76207
# [458]	validation_0-rmse:0.48485	validation_1-rmse:0.76212
# [459]	validation_0-rmse:0.48457	validation_1-rmse:0.76223
# [460]	validation_0-rmse:0.48427	validation_1-rmse:0.76233
# [461]	validation_0-rmse:0.48402	validation_1-rmse:0.76243
# [462]	validation_0-rmse:0.48389	validation_1-rmse:0.76233
# [463]	validation_0-rmse:0.48356	validation_1-rmse:0.76228
# [464]	validation_0-rmse:0.48319	validation_1-rmse:0.76236
# [465]	validation_0-rmse:0.48294	validation_1-rmse:0.76240
# [466]	validation_0-rmse:0.48265	validation_1-rmse:0.76240
# [467]	validation_0-rmse:0.48245	validation_1-rmse:0.76247
# [468]	validation_0-rmse:0.48225	validation_1-rmse:0.76253
# [469]	validation_0-rmse:0.48184	validation_1-rmse:0.76276
# [470]	validation_0-rmse:0.48162	validation_1-rmse:0.76271
# [471]	validation_0-rmse:0.48122	validation_1-rmse:0.76267
# [472]	validation_0-rmse:0.48092	validation_1-rmse:0.76277
# [473]	validation_0-rmse:0.48053	validation_1-rmse:0.76275
# [474]	validation_0-rmse:0.48026	validation_1-rmse:0.76269
# [475]	validation_0-rmse:0.47995	validation_1-rmse:0.76273
# [476]	validation_0-rmse:0.47960	validation_1-rmse:0.76271
# [477]	validation_0-rmse:0.47931	validation_1-rmse:0.76258
# [478]	validation_0-rmse:0.47905	validation_1-rmse:0.76256
# [479]	validation_0-rmse:0.47891	validation_1-rmse:0.76256
# [480]	validation_0-rmse:0.47882	validation_1-rmse:0.76253
# [481]	validation_0-rmse:0.47838	validation_1-rmse:0.76258
# [482]	validation_0-rmse:0.47819	validation_1-rmse:0.76263
# [483]	validation_0-rmse:0.47789	validation_1-rmse:0.76264
# [484]	validation_0-rmse:0.47765	validation_1-rmse:0.76264
# [485]	validation_0-rmse:0.47734	validation_1-rmse:0.76266
# [486]	validation_0-rmse:0.47708	validation_1-rmse:0.76278
# [487]	validation_0-rmse:0.47681	validation_1-rmse:0.76276
# [488]	validation_0-rmse:0.47652	validation_1-rmse:0.76278
# [489]	validation_0-rmse:0.47615	validation_1-rmse:0.76264
# [490]	validation_0-rmse:0.47582	validation_1-rmse:0.76265
# [491]	validation_0-rmse:0.47567	validation_1-rmse:0.76260
# [492]	validation_0-rmse:0.47521	validation_1-rmse:0.76250
# [493]	validation_0-rmse:0.47487	validation_1-rmse:0.76249
# [494]	validation_0-rmse:0.47456	validation_1-rmse:0.76244
# [495]	validation_0-rmse:0.47429	validation_1-rmse:0.76246
# [496]	validation_0-rmse:0.47406	validation_1-rmse:0.76257
# [497]	validation_0-rmse:0.47375	validation_1-rmse:0.76254
# [498]	validation_0-rmse:0.47339	validation_1-rmse:0.76251
# [499]	validation_0-rmse:0.47313	validation_1-rmse:0.76244
# [500]	validation_0-rmse:0.47291	validation_1-rmse:0.76242
# [501]	validation_0-rmse:0.47255	validation_1-rmse:0.76243
# [502]	validation_0-rmse:0.47241	validation_1-rmse:0.76239
# [503]	validation_0-rmse:0.47203	validation_1-rmse:0.76243
# [504]	validation_0-rmse:0.47171	validation_1-rmse:0.76231
# [505]	validation_0-rmse:0.47142	validation_1-rmse:0.76232
# [506]	validation_0-rmse:0.47122	validation_1-rmse:0.76233
# [507]	validation_0-rmse:0.47088	validation_1-rmse:0.76234
# [508]	validation_0-rmse:0.47051	validation_1-rmse:0.76256
# [509]	validation_0-rmse:0.47022	validation_1-rmse:0.76255
# [510]	validation_0-rmse:0.46994	validation_1-rmse:0.76251
# [511]	validation_0-rmse:0.46965	validation_1-rmse:0.76257
# [512]	validation_0-rmse:0.46934	validation_1-rmse:0.76258
# [513]	validation_0-rmse:0.46907	validation_1-rmse:0.76260
# [514]	validation_0-rmse:0.46882	validation_1-rmse:0.76264
# [515]	validation_0-rmse:0.46846	validation_1-rmse:0.76277
# [516]	validation_0-rmse:0.46821	validation_1-rmse:0.76272
# [517]	validation_0-rmse:0.46801	validation_1-rmse:0.76278
# [518]	validation_0-rmse:0.46757	validation_1-rmse:0.76280
# [519]	validation_0-rmse:0.46716	validation_1-rmse:0.76288
# [520]	validation_0-rmse:0.46705	validation_1-rmse:0.76280
# [521]	validation_0-rmse:0.46677	validation_1-rmse:0.76280
# [522]	validation_0-rmse:0.46628	validation_1-rmse:0.76285
# [523]	validation_0-rmse:0.46595	validation_1-rmse:0.76288
# [524]	validation_0-rmse:0.46569	validation_1-rmse:0.76288
# [525]	validation_0-rmse:0.46525	validation_1-rmse:0.76288
# [526]	validation_0-rmse:0.46505	validation_1-rmse:0.76293
# [527]	validation_0-rmse:0.46483	validation_1-rmse:0.76292
# [528]	validation_0-rmse:0.46448	validation_1-rmse:0.76296
# [529]	validation_0-rmse:0.46432	validation_1-rmse:0.76296
# [530]	validation_0-rmse:0.46400	validation_1-rmse:0.76298
# [531]	validation_0-rmse:0.46372	validation_1-rmse:0.76295
# [532]	validation_0-rmse:0.46345	validation_1-rmse:0.76294
# [533]	validation_0-rmse:0.46324	validation_1-rmse:0.76297
# [534]	validation_0-rmse:0.46292	validation_1-rmse:0.76296
# [535]	validation_0-rmse:0.46247	validation_1-rmse:0.76307
# [536]	validation_0-rmse:0.46216	validation_1-rmse:0.76309
# [537]	validation_0-rmse:0.46205	validation_1-rmse:0.76300
# [538]	validation_0-rmse:0.46171	validation_1-rmse:0.76300
# [539]	validation_0-rmse:0.46153	validation_1-rmse:0.76305
# [540]	validation_0-rmse:0.46111	validation_1-rmse:0.76305
# [541]	validation_0-rmse:0.46076	validation_1-rmse:0.76298
# [542]	validation_0-rmse:0.46048	validation_1-rmse:0.76298
# [543]	validation_0-rmse:0.46017	validation_1-rmse:0.76291
# [544]	validation_0-rmse:0.45995	validation_1-rmse:0.76293
# [545]	validation_0-rmse:0.45971	validation_1-rmse:0.76292
# [546]	validation_0-rmse:0.45952	validation_1-rmse:0.76282
# [547]	validation_0-rmse:0.45931	validation_1-rmse:0.76290
# [548]	validation_0-rmse:0.45915	validation_1-rmse:0.76289
# [549]	validation_0-rmse:0.45891	validation_1-rmse:0.76280
# [550]	validation_0-rmse:0.45859	validation_1-rmse:0.76268
# [551]	validation_0-rmse:0.45823	validation_1-rmse:0.76257
# [552]	validation_0-rmse:0.45779	validation_1-rmse:0.76253
# [553]	validation_0-rmse:0.45737	validation_1-rmse:0.76247
# [554]	validation_0-rmse:0.45716	validation_1-rmse:0.76247
# [555]	validation_0-rmse:0.45677	validation_1-rmse:0.76246
# [556]	validation_0-rmse:0.45660	validation_1-rmse:0.76253
# [557]	validation_0-rmse:0.45639	validation_1-rmse:0.76254
# [558]	validation_0-rmse:0.45620	validation_1-rmse:0.76256
# [559]	validation_0-rmse:0.45595	validation_1-rmse:0.76258
# [560]	validation_0-rmse:0.45566	validation_1-rmse:0.76253
# [561]	validation_0-rmse:0.45540	validation_1-rmse:0.76250
# [562]	validation_0-rmse:0.45515	validation_1-rmse:0.76256
# [563]	validation_0-rmse:0.45479	validation_1-rmse:0.76260
# [564]	validation_0-rmse:0.45455	validation_1-rmse:0.76258
# [565]	validation_0-rmse:0.45427	validation_1-rmse:0.76267
# [566]	validation_0-rmse:0.45403	validation_1-rmse:0.76260
# [567]	validation_0-rmse:0.45378	validation_1-rmse:0.76251
# [568]	validation_0-rmse:0.45352	validation_1-rmse:0.76247
# [569]	validation_0-rmse:0.45322	validation_1-rmse:0.76247
# [570]	validation_0-rmse:0.45287	validation_1-rmse:0.76233
# [571]	validation_0-rmse:0.45262	validation_1-rmse:0.76228
# [572]	validation_0-rmse:0.45234	validation_1-rmse:0.76230
# [573]	validation_0-rmse:0.45195	validation_1-rmse:0.76228
# [574]	validation_0-rmse:0.45168	validation_1-rmse:0.76231
# [575]	validation_0-rmse:0.45138	validation_1-rmse:0.76232
# [576]	validation_0-rmse:0.45117	validation_1-rmse:0.76227
# [577]	validation_0-rmse:0.45096	validation_1-rmse:0.76222
# [578]	validation_0-rmse:0.45066	validation_1-rmse:0.76221
# [579]	validation_0-rmse:0.45047	validation_1-rmse:0.76221
# [580]	validation_0-rmse:0.45025	validation_1-rmse:0.76221
# [581]	validation_0-rmse:0.44998	validation_1-rmse:0.76225
# [582]	validation_0-rmse:0.44981	validation_1-rmse:0.76229
# [583]	validation_0-rmse:0.44957	validation_1-rmse:0.76231
# [584]	validation_0-rmse:0.44916	validation_1-rmse:0.76230
# [585]	validation_0-rmse:0.44878	validation_1-rmse:0.76228
# [586]	validation_0-rmse:0.44850	validation_1-rmse:0.76223
# [587]	validation_0-rmse:0.44832	validation_1-rmse:0.76214
# [588]	validation_0-rmse:0.44788	validation_1-rmse:0.76215
# [589]	validation_0-rmse:0.44781	validation_1-rmse:0.76212
# [590]	validation_0-rmse:0.44755	validation_1-rmse:0.76212
# [591]	validation_0-rmse:0.44733	validation_1-rmse:0.76204
# [592]	validation_0-rmse:0.44708	validation_1-rmse:0.76204
# [593]	validation_0-rmse:0.44672	validation_1-rmse:0.76208
# [594]	validation_0-rmse:0.44651	validation_1-rmse:0.76209
# [595]	validation_0-rmse:0.44608	validation_1-rmse:0.76197
# [596]	validation_0-rmse:0.44584	validation_1-rmse:0.76197
# [597]	validation_0-rmse:0.44554	validation_1-rmse:0.76201
# [598]	validation_0-rmse:0.44531	validation_1-rmse:0.76200
# [599]	validation_0-rmse:0.44506	validation_1-rmse:0.76206
# [600]	validation_0-rmse:0.44480	validation_1-rmse:0.76202
# [601]	validation_0-rmse:0.44439	validation_1-rmse:0.76198
# [602]	validation_0-rmse:0.44410	validation_1-rmse:0.76199
# [603]	validation_0-rmse:0.44380	validation_1-rmse:0.76194
# [604]	validation_0-rmse:0.44340	validation_1-rmse:0.76205
# [605]	validation_0-rmse:0.44311	validation_1-rmse:0.76207
# [606]	validation_0-rmse:0.44277	validation_1-rmse:0.76211
# [607]	validation_0-rmse:0.44261	validation_1-rmse:0.76213
# [608]	validation_0-rmse:0.44220	validation_1-rmse:0.76219
# [609]	validation_0-rmse:0.44197	validation_1-rmse:0.76221
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.025, max_delta_step=0, max_depth=4,
#              min_child_weight=5, missing=nan, monotone_constraints='()',
#              n_estimators=610, n_jobs=96, num_parallel_tree=1, random_state=27,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=27,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=0)

# %%
y_pred_test = best_model.predict(X_test)

# %%
y_pred_train = best_model.predict(X_train)

# %%
fig, axes = plt.subplots(2,2, figsize=(14,10), dpi=300)
plot_prediction(y_test, y_pred_test, fig=fig, ax=axes[0][0], title="Pred on test set");
plot_prediction(y_train, y_pred_train, fig=fig, ax=axes[0][1], title="Predictions on training set");
#plot_prediction(y_train, y_pred_xgb_train, fig=fig, ax=axes[0][1], title="Pred on train");
plot_training_xgb(best_model.evals_result_, fig=fig, ax=axes[1][1], title="Training error")
#fig.savefig("predictions.png", dpi=300)
# Out:
# (<Figure size 4200x3000 with 4 Axes>,
#  <AxesSubplot:title={'center':'XGBOOST Regression Error'}, xlabel='Nbr of trees (n_estimators)', ylabel='error : RMSE'>)

# %% [markdown]
# ### Cross validated best model

# %%
best_model_cv = xgb.cv(best_model.get_params(), xgb.DMatrix(X, label=Y), num_boost_round=best_model.get_params()['n_estimators'])

# %%
best_model_cv.tail()
# Out:
#      train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 605         0.414584        0.018151        0.815579       0.022295
# 606         0.414282        0.018127        0.815554       0.022301
# 607         0.414051        0.018072        0.815627       0.022269
# 608         0.413794        0.018084        0.815609       0.022278
# 609         0.413444        0.018109        0.815572       0.022333

# %% [markdown]
# # Feature selection with Hypetune

# %%
from scipy import stats
from shaphypetune import BoostSearch, BoostRFE

# %%
param_dist = {'n_estimators': 450,
              'learning_rate': [0.02, 0.03, 0.04],
              'max_depth': [3, 4]}

model = BoostRFE(XGBRegressor(), param_grid=param_dist, n_iter=10, sampling_seed=0,
                 min_features_to_select=100, step=1)
model.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=50, verbose=1)
# Out:
# 6 trials detected for ('n_estimators', 'learning_rate', 'max_depth')
#
# [0]	validation_0-rmse:1.07465
# [1]	validation_0-rmse:1.06704
# [2]	validation_0-rmse:1.05975
# [3]	validation_0-rmse:1.05326
# [4]	validation_0-rmse:1.04601
# [5]	validation_0-rmse:1.03990
# [6]	validation_0-rmse:1.03305
# [7]	validation_0-rmse:1.02764
# [8]	validation_0-rmse:1.02158
# [9]	validation_0-rmse:1.01528
# [10]	validation_0-rmse:1.00951
# [11]	validation_0-rmse:1.00468
# [12]	validation_0-rmse:0.99929
# [13]	validation_0-rmse:0.99456
# [14]	validation_0-rmse:0.98888
# [15]	validation_0-rmse:0.98386
# [16]	validation_0-rmse:0.97948
# [17]	validation_0-rmse:0.97506
# [18]	validation_0-rmse:0.97059
# [19]	validation_0-rmse:0.96599
# [20]	validation_0-rmse:0.96160
# [21]	validation_0-rmse:0.95700
# [22]	validation_0-rmse:0.95300
# [23]	validation_0-rmse:0.94941
# [24]	validation_0-rmse:0.94552
# [25]	validation_0-rmse:0.94159
# [26]	validation_0-rmse:0.93830
# [27]	validation_0-rmse:0.93461
# [28]	validation_0-rmse:0.93102
# [29]	validation_0-rmse:0.92759
# [30]	validation_0-rmse:0.92464
# [31]	validation_0-rmse:0.92131
# [32]	validation_0-rmse:0.91852
# [33]	validation_0-rmse:0.91568
# [34]	validation_0-rmse:0.91268
# [35]	validation_0-rmse:0.90959
# [36]	validation_0-rmse:0.90639
# [37]	validation_0-rmse:0.90438
# [38]	validation_0-rmse:0.90199
# [39]	validation_0-rmse:0.89950
# [40]	validation_0-rmse:0.89719
# [41]	validation_0-rmse:0.89446
# [42]	validation_0-rmse:0.89276
# [43]	validation_0-rmse:0.89088
# [44]	validation_0-rmse:0.88892
# [45]	validation_0-rmse:0.88643
# [46]	validation_0-rmse:0.88373
# [47]	validation_0-rmse:0.88143
# [48]	validation_0-rmse:0.87890
# [49]	validation_0-rmse:0.87719
# [50]	validation_0-rmse:0.87544
# [51]	validation_0-rmse:0.87339
# [52]	validation_0-rmse:0.87111
# [53]	validation_0-rmse:0.86958
# [54]	validation_0-rmse:0.86806
# [55]	validation_0-rmse:0.86630
# [56]	validation_0-rmse:0.86435
# [57]	validation_0-rmse:0.86277
# [58]	validation_0-rmse:0.86132
# [59]	validation_0-rmse:0.85979
# [60]	validation_0-rmse:0.85852
# [61]	validation_0-rmse:0.85674
# [62]	validation_0-rmse:0.85494
# [63]	validation_0-rmse:0.85298
# [64]	validation_0-rmse:0.85137
# [65]	validation_0-rmse:0.85019
# [66]	validation_0-rmse:0.84905
# [67]	validation_0-rmse:0.84794
# [68]	validation_0-rmse:0.84681
# [69]	validation_0-rmse:0.84549
# [70]	validation_0-rmse:0.84396
# [71]	validation_0-rmse:0.84272
# [72]	validation_0-rmse:0.84174
# [73]	validation_0-rmse:0.84035
# [74]	validation_0-rmse:0.83912
# [75]	validation_0-rmse:0.83796
# [76]	validation_0-rmse:0.83691
# [77]	validation_0-rmse:0.83571
# [78]	validation_0-rmse:0.83450
# [79]	validation_0-rmse:0.83319
# [80]	validation_0-rmse:0.83225
# [81]	validation_0-rmse:0.83094
# [82]	validation_0-rmse:0.83025
# [83]	validation_0-rmse:0.82932
# [84]	validation_0-rmse:0.82842
# [85]	validation_0-rmse:0.82735
# [86]	validation_0-rmse:0.82648
# [87]	validation_0-rmse:0.82539
# [88]	validation_0-rmse:0.82440
# [89]	validation_0-rmse:0.82334
# [90]	validation_0-rmse:0.82248
# [91]	validation_0-rmse:0.82147
# [92]	validation_0-rmse:0.82081
# [93]	validation_0-rmse:0.81955
# [94]	validation_0-rmse:0.81874
# [95]	validation_0-rmse:0.81786
# [96]	validation_0-rmse:0.81688
# [97]	validation_0-rmse:0.81612
# [98]	validation_0-rmse:0.81511
# [99]	validation_0-rmse:0.81456
# [100]	validation_0-rmse:0.81407
# [101]	validation_0-rmse:0.81312
# [102]	validation_0-rmse:0.81219
# [103]	validation_0-rmse:0.81133
# [104]	validation_0-rmse:0.81069
# [105]	validation_0-rmse:0.80983
# [106]	validation_0-rmse:0.80926
# [107]	validation_0-rmse:0.80885
# [108]	validation_0-rmse:0.80840
# [109]	validation_0-rmse:0.80765
# [110]	validation_0-rmse:0.80688
# [111]	validation_0-rmse:0.80641
# [112]	validation_0-rmse:0.80615
# [113]	validation_0-rmse:0.80569
# [114]	validation_0-rmse:0.80478
# [115]	validation_0-rmse:0.80420
# [116]	validation_0-rmse:0.80384
# [117]	validation_0-rmse:0.80327
# [118]	validation_0-rmse:0.80256
# [119]	validation_0-rmse:0.80207
# [120]	validation_0-rmse:0.80188
# [121]	validation_0-rmse:0.80148
# [122]	validation_0-rmse:0.80099
# [123]	validation_0-rmse:0.80018
# [124]	validation_0-rmse:0.79979
# [125]	validation_0-rmse:0.79952
# [126]	validation_0-rmse:0.79880
# [127]	validation_0-rmse:0.79835
# [128]	validation_0-rmse:0.79807
# [129]	validation_0-rmse:0.79769
# [130]	validation_0-rmse:0.79702
# [131]	validation_0-rmse:0.79658
# [132]	validation_0-rmse:0.79620
# [133]	validation_0-rmse:0.79540
# [134]	validation_0-rmse:0.79513
# [135]	validation_0-rmse:0.79491
# [136]	validation_0-rmse:0.79426
# [137]	validation_0-rmse:0.79404
# [138]	validation_0-rmse:0.79364
# [139]	validation_0-rmse:0.79326
# [140]	validation_0-rmse:0.79293
# [141]	validation_0-rmse:0.79242
# [142]	validation_0-rmse:0.79182
# [143]	validation_0-rmse:0.79162
# [144]	validation_0-rmse:0.79103
# [145]	validation_0-rmse:0.79092
# [146]	validation_0-rmse:0.79079
# [147]	validation_0-rmse:0.79034
# [148]	validation_0-rmse:0.78997
# [149]	validation_0-rmse:0.78960
# [150]	validation_0-rmse:0.78920
# [151]	validation_0-rmse:0.78903
# [152]	validation_0-rmse:0.78857
# [153]	validation_0-rmse:0.78847
# [154]	validation_0-rmse:0.78800
# [155]	validation_0-rmse:0.78780
# [156]	validation_0-rmse:0.78734
# [157]	validation_0-rmse:0.78701
# [158]	validation_0-rmse:0.78663
# [159]	validation_0-rmse:0.78636
# [160]	validation_0-rmse:0.78590
# [161]	validation_0-rmse:0.78606
# [162]	validation_0-rmse:0.78576
# [163]	validation_0-rmse:0.78527
# [164]	validation_0-rmse:0.78514
# [165]	validation_0-rmse:0.78484
# [166]	validation_0-rmse:0.78469
# [167]	validation_0-rmse:0.78435
# [168]	validation_0-rmse:0.78412
# [169]	validation_0-rmse:0.78381
# [170]	validation_0-rmse:0.78363
# [171]	validation_0-rmse:0.78341
# [172]	validation_0-rmse:0.78301
# [173]	validation_0-rmse:0.78265
# [174]	validation_0-rmse:0.78236
# [175]	validation_0-rmse:0.78204
# [176]	validation_0-rmse:0.78169
# [177]	validation_0-rmse:0.78150
# [178]	validation_0-rmse:0.78137
# [179]	validation_0-rmse:0.78118
# [180]	validation_0-rmse:0.78102
# [181]	validation_0-rmse:0.78071
# [182]	validation_0-rmse:0.78037
# [183]	validation_0-rmse:0.78038
# [184]	validation_0-rmse:0.78007
# [185]	validation_0-rmse:0.77987
# [186]	validation_0-rmse:0.77974
# [187]	validation_0-rmse:0.77955
# [188]	validation_0-rmse:0.77937
# [189]	validation_0-rmse:0.77916

# %%
from shap.utils._general import approximate_interactions

# %% [markdown]
# Guide on interaction function:
# https://github.com/slundberg/shap/blob/master/shap/utils/_general.py

# %%
cv_input_matrix = xgb.DMatrix(X, label=Y)

# %%
best_model.get_params()
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'gpu_id': -1,
#  'importance_type': 'gain',
#  'interaction_constraints': '',
#  'learning_rate': 0.025,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 5,
#  'missing': nan,
#  'monotone_constraints': '()',
#  'n_estimators': 610,
#  'n_jobs': 96,
#  'num_parallel_tree': 1,
#  'random_state': 27,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': 'exact',
#  'validate_parameters': 1,
#  'verbosity': 0,
#  'seed': 27}

# %%
cv_result = xgb.cv(best_model.get_params(),
                   cv_input_matrix,
                   num_boost_round=400,
                   verbose_eval=True,
                   early_stopping_rounds=80,
                   metrics="rmse",
                   nfold=2)
# Out:
# [0]	train-rmse:1.10381+0.03044	test-rmse:1.10710+0.03034
# [1]	train-rmse:1.09200+0.02969	test-rmse:1.09878+0.02926
# [2]	train-rmse:1.08060+0.02893	test-rmse:1.09055+0.02855
# [3]	train-rmse:1.06961+0.02821	test-rmse:1.08273+0.02737
# [4]	train-rmse:1.05871+0.02777	test-rmse:1.07514+0.02701
# [5]	train-rmse:1.04832+0.02705	test-rmse:1.06780+0.02643
# [6]	train-rmse:1.03812+0.02665	test-rmse:1.06114+0.02573
# [7]	train-rmse:1.02844+0.02596	test-rmse:1.05465+0.02508
# [8]	train-rmse:1.01891+0.02561	test-rmse:1.04866+0.02437
# [9]	train-rmse:1.00972+0.02513	test-rmse:1.04268+0.02380
# [10]	train-rmse:1.00089+0.02468	test-rmse:1.03722+0.02327
# [11]	train-rmse:0.99217+0.02413	test-rmse:1.03163+0.02311
# [12]	train-rmse:0.98357+0.02404	test-rmse:1.02646+0.02236
# [13]	train-rmse:0.97518+0.02346	test-rmse:1.02129+0.02209
# [14]	train-rmse:0.96665+0.02292	test-rmse:1.01585+0.02213
# [15]	train-rmse:0.95891+0.02217	test-rmse:1.01085+0.02249
# [16]	train-rmse:0.95087+0.02174	test-rmse:1.00602+0.02268
# [17]	train-rmse:0.94289+0.02092	test-rmse:1.00093+0.02281
# [18]	train-rmse:0.93582+0.02032	test-rmse:0.99642+0.02349
# [19]	train-rmse:0.92842+0.01961	test-rmse:0.99150+0.02399
# [20]	train-rmse:0.92099+0.01905	test-rmse:0.98686+0.02397
# [21]	train-rmse:0.91403+0.01859	test-rmse:0.98274+0.02363
# [22]	train-rmse:0.90734+0.01790	test-rmse:0.97868+0.02385
# [23]	train-rmse:0.90053+0.01755	test-rmse:0.97437+0.02376
# [24]	train-rmse:0.89423+0.01732	test-rmse:0.97081+0.02364
# [25]	train-rmse:0.88802+0.01661	test-rmse:0.96716+0.02393
# [26]	train-rmse:0.88199+0.01650	test-rmse:0.96355+0.02354
# [27]	train-rmse:0.87613+0.01600	test-rmse:0.95981+0.02392
# [28]	train-rmse:0.87006+0.01573	test-rmse:0.95650+0.02400
# [29]	train-rmse:0.86443+0.01514	test-rmse:0.95351+0.02379
# [30]	train-rmse:0.85885+0.01501	test-rmse:0.95056+0.02392
# [31]	train-rmse:0.85271+0.01438	test-rmse:0.94718+0.02433
# [32]	train-rmse:0.84730+0.01406	test-rmse:0.94439+0.02414
# [33]	train-rmse:0.84195+0.01304	test-rmse:0.94153+0.02448
# [34]	train-rmse:0.83683+0.01287	test-rmse:0.93880+0.02388
# [35]	train-rmse:0.83193+0.01273	test-rmse:0.93608+0.02368
# [36]	train-rmse:0.82656+0.01234	test-rmse:0.93350+0.02401
# [37]	train-rmse:0.82184+0.01165	test-rmse:0.93115+0.02419
# [38]	train-rmse:0.81715+0.01161	test-rmse:0.92882+0.02442
# [39]	train-rmse:0.81245+0.01126	test-rmse:0.92632+0.02435
# [40]	train-rmse:0.80821+0.01120	test-rmse:0.92383+0.02408
# [41]	train-rmse:0.80342+0.01052	test-rmse:0.92141+0.02386
# [42]	train-rmse:0.79928+0.01038	test-rmse:0.91928+0.02344
# [43]	train-rmse:0.79484+0.01021	test-rmse:0.91729+0.02349
# [44]	train-rmse:0.79073+0.00992	test-rmse:0.91544+0.02328
# [45]	train-rmse:0.78642+0.00946	test-rmse:0.91341+0.02350
# [46]	train-rmse:0.78289+0.00933	test-rmse:0.91170+0.02359
# [47]	train-rmse:0.77903+0.00897	test-rmse:0.90993+0.02384
# [48]	train-rmse:0.77537+0.00888	test-rmse:0.90870+0.02350
# [49]	train-rmse:0.77184+0.00891	test-rmse:0.90703+0.02303
# [50]	train-rmse:0.76795+0.00843	test-rmse:0.90555+0.02265
# [51]	train-rmse:0.76422+0.00850	test-rmse:0.90402+0.02269
# [52]	train-rmse:0.76061+0.00809	test-rmse:0.90224+0.02255
# [53]	train-rmse:0.75719+0.00842	test-rmse:0.90030+0.02200
# [54]	train-rmse:0.75395+0.00817	test-rmse:0.89877+0.02200
# [55]	train-rmse:0.75041+0.00817	test-rmse:0.89693+0.02135
# [56]	train-rmse:0.74680+0.00744	test-rmse:0.89556+0.02126
# [57]	train-rmse:0.74387+0.00750	test-rmse:0.89459+0.02106
# [58]	train-rmse:0.74066+0.00760	test-rmse:0.89287+0.02064
# [59]	train-rmse:0.73801+0.00755	test-rmse:0.89182+0.02031
# [60]	train-rmse:0.73494+0.00727	test-rmse:0.89028+0.02045
# [61]	train-rmse:0.73239+0.00707	test-rmse:0.88918+0.02067
# [62]	train-rmse:0.72946+0.00754	test-rmse:0.88812+0.02054
# [63]	train-rmse:0.72669+0.00720	test-rmse:0.88689+0.02044
# [64]	train-rmse:0.72389+0.00743	test-rmse:0.88578+0.02072
# [65]	train-rmse:0.72126+0.00732	test-rmse:0.88474+0.02065
# [66]	train-rmse:0.71879+0.00758	test-rmse:0.88378+0.02045
# [67]	train-rmse:0.71579+0.00735	test-rmse:0.88275+0.02027
# [68]	train-rmse:0.71347+0.00718	test-rmse:0.88183+0.02014
# [69]	train-rmse:0.71094+0.00719	test-rmse:0.88067+0.02024
# [70]	train-rmse:0.70823+0.00740	test-rmse:0.87969+0.02001
# [71]	train-rmse:0.70569+0.00779	test-rmse:0.87880+0.02003
# [72]	train-rmse:0.70365+0.00793	test-rmse:0.87800+0.01979
# [73]	train-rmse:0.70121+0.00785	test-rmse:0.87701+0.01971
# [74]	train-rmse:0.69914+0.00773	test-rmse:0.87626+0.01973
# [75]	train-rmse:0.69659+0.00792	test-rmse:0.87559+0.01946
# [76]	train-rmse:0.69449+0.00803	test-rmse:0.87467+0.01934
# [77]	train-rmse:0.69219+0.00817	test-rmse:0.87358+0.01916
# [78]	train-rmse:0.68990+0.00819	test-rmse:0.87278+0.01903
# [79]	train-rmse:0.68805+0.00816	test-rmse:0.87190+0.01908
# [80]	train-rmse:0.68592+0.00832	test-rmse:0.87097+0.01919
# [81]	train-rmse:0.68403+0.00834	test-rmse:0.87006+0.01898
# [82]	train-rmse:0.68182+0.00853	test-rmse:0.86919+0.01843
# [83]	train-rmse:0.67976+0.00850	test-rmse:0.86852+0.01838
# [84]	train-rmse:0.67756+0.00890	test-rmse:0.86771+0.01830
# [85]	train-rmse:0.67506+0.00901	test-rmse:0.86701+0.01831
# [86]	train-rmse:0.67284+0.00924	test-rmse:0.86619+0.01834
# [87]	train-rmse:0.67081+0.00940	test-rmse:0.86519+0.01804
# [88]	train-rmse:0.66921+0.00942	test-rmse:0.86452+0.01784
# [89]	train-rmse:0.66719+0.00993	test-rmse:0.86393+0.01782
# [90]	train-rmse:0.66536+0.00992	test-rmse:0.86350+0.01770
# [91]	train-rmse:0.66341+0.01024	test-rmse:0.86285+0.01765
# [92]	train-rmse:0.66151+0.01030	test-rmse:0.86203+0.01744
# [93]	train-rmse:0.65987+0.01036	test-rmse:0.86139+0.01753
# [94]	train-rmse:0.65785+0.01066	test-rmse:0.86102+0.01734
# [95]	train-rmse:0.65589+0.01075	test-rmse:0.86057+0.01765
# [96]	train-rmse:0.65427+0.01077	test-rmse:0.85991+0.01745
# [97]	train-rmse:0.65233+0.01096	test-rmse:0.85938+0.01739
# [98]	train-rmse:0.65080+0.01128	test-rmse:0.85868+0.01694
# [99]	train-rmse:0.64920+0.01146	test-rmse:0.85812+0.01683
# [100]	train-rmse:0.64754+0.01148	test-rmse:0.85768+0.01686
# [101]	train-rmse:0.64582+0.01170	test-rmse:0.85732+0.01672
# [102]	train-rmse:0.64414+0.01192	test-rmse:0.85683+0.01680
# [103]	train-rmse:0.64258+0.01198	test-rmse:0.85624+0.01676
# [104]	train-rmse:0.64121+0.01192	test-rmse:0.85587+0.01653
# [105]	train-rmse:0.63966+0.01201	test-rmse:0.85530+0.01645
# [106]	train-rmse:0.63824+0.01203	test-rmse:0.85495+0.01632
# [107]	train-rmse:0.63658+0.01177	test-rmse:0.85458+0.01620
# [108]	train-rmse:0.63483+0.01183	test-rmse:0.85418+0.01634
# [109]	train-rmse:0.63333+0.01185	test-rmse:0.85393+0.01644
# [110]	train-rmse:0.63206+0.01189	test-rmse:0.85343+0.01636
# [111]	train-rmse:0.63061+0.01197	test-rmse:0.85300+0.01626
# [112]	train-rmse:0.62896+0.01220	test-rmse:0.85259+0.01631
# [113]	train-rmse:0.62742+0.01256	test-rmse:0.85214+0.01631
# [114]	train-rmse:0.62576+0.01234	test-rmse:0.85177+0.01611
# [115]	train-rmse:0.62436+0.01259	test-rmse:0.85141+0.01616
# [116]	train-rmse:0.62279+0.01256	test-rmse:0.85094+0.01598
# [117]	train-rmse:0.62119+0.01287	test-rmse:0.85071+0.01597
# [118]	train-rmse:0.61940+0.01284	test-rmse:0.85043+0.01601
# [119]	train-rmse:0.61809+0.01298	test-rmse:0.85016+0.01582
# [120]	train-rmse:0.61671+0.01287	test-rmse:0.84990+0.01567
# [121]	train-rmse:0.61533+0.01293	test-rmse:0.84948+0.01576
# [122]	train-rmse:0.61409+0.01308	test-rmse:0.84939+0.01579
# [123]	train-rmse:0.61274+0.01312	test-rmse:0.84914+0.01578
# [124]	train-rmse:0.61123+0.01319	test-rmse:0.84906+0.01579
# [125]	train-rmse:0.61017+0.01319	test-rmse:0.84880+0.01588
# [126]	train-rmse:0.60855+0.01313	test-rmse:0.84847+0.01588
# [127]	train-rmse:0.60743+0.01312	test-rmse:0.84817+0.01586
# [128]	train-rmse:0.60628+0.01333	test-rmse:0.84789+0.01593
# [129]	train-rmse:0.60505+0.01334	test-rmse:0.84755+0.01603
# [130]	train-rmse:0.60404+0.01336	test-rmse:0.84750+0.01598
# [131]	train-rmse:0.60279+0.01355	test-rmse:0.84724+0.01580
# [132]	train-rmse:0.60167+0.01372	test-rmse:0.84699+0.01570
# [133]	train-rmse:0.60058+0.01378	test-rmse:0.84687+0.01566
# [134]	train-rmse:0.59950+0.01382	test-rmse:0.84660+0.01562
# [135]	train-rmse:0.59830+0.01411	test-rmse:0.84636+0.01561
# [136]	train-rmse:0.59704+0.01428	test-rmse:0.84625+0.01570
# [137]	train-rmse:0.59596+0.01444	test-rmse:0.84621+0.01558
# [138]	train-rmse:0.59477+0.01417	test-rmse:0.84594+0.01565
# [139]	train-rmse:0.59361+0.01437	test-rmse:0.84568+0.01549
# [140]	train-rmse:0.59245+0.01456	test-rmse:0.84549+0.01539
# [141]	train-rmse:0.59129+0.01482	test-rmse:0.84519+0.01538
# [142]	train-rmse:0.59032+0.01480	test-rmse:0.84494+0.01546
# [143]	train-rmse:0.58949+0.01484	test-rmse:0.84477+0.01546
# [144]	train-rmse:0.58831+0.01475	test-rmse:0.84447+0.01551
# [145]	train-rmse:0.58729+0.01488	test-rmse:0.84431+0.01557
# [146]	train-rmse:0.58642+0.01518	test-rmse:0.84404+0.01541
# [147]	train-rmse:0.58532+0.01544	test-rmse:0.84387+0.01520
# [148]	train-rmse:0.58427+0.01559	test-rmse:0.84367+0.01508
# [149]	train-rmse:0.58314+0.01572	test-rmse:0.84335+0.01504
# [150]	train-rmse:0.58212+0.01572	test-rmse:0.84310+0.01505
# [151]	train-rmse:0.58125+0.01571	test-rmse:0.84296+0.01500
# [152]	train-rmse:0.58009+0.01582	test-rmse:0.84280+0.01510
# [153]	train-rmse:0.57913+0.01599	test-rmse:0.84262+0.01499
# [154]	train-rmse:0.57795+0.01623	test-rmse:0.84240+0.01504
# [155]	train-rmse:0.57707+0.01630	test-rmse:0.84237+0.01490
# [156]	train-rmse:0.57590+0.01629	test-rmse:0.84218+0.01474
# [157]	train-rmse:0.57486+0.01649	test-rmse:0.84197+0.01456
# [158]	train-rmse:0.57409+0.01659	test-rmse:0.84183+0.01446
# [159]	train-rmse:0.57322+0.01661	test-rmse:0.84165+0.01447
# [160]	train-rmse:0.57243+0.01656	test-rmse:0.84158+0.01443
# [161]	train-rmse:0.57131+0.01667	test-rmse:0.84142+0.01441
# [162]	train-rmse:0.57046+0.01670	test-rmse:0.84123+0.01436
# [163]	train-rmse:0.56961+0.01673	test-rmse:0.84120+0.01434
# [164]	train-rmse:0.56848+0.01726	test-rmse:0.84107+0.01429
# [165]	train-rmse:0.56756+0.01720	test-rmse:0.84093+0.01424
# [166]	train-rmse:0.56655+0.01749	test-rmse:0.84084+0.01402
# [167]	train-rmse:0.56552+0.01764	test-rmse:0.84061+0.01391
# [168]	train-rmse:0.56449+0.01768	test-rmse:0.84049+0.01386
# [169]	train-rmse:0.56391+0.01778	test-rmse:0.84039+0.01382
# [170]	train-rmse:0.56302+0.01792	test-rmse:0.84028+0.01382
# [171]	train-rmse:0.56225+0.01820	test-rmse:0.84023+0.01376
# [172]	train-rmse:0.56145+0.01842	test-rmse:0.84018+0.01373
# [173]	train-rmse:0.56048+0.01848	test-rmse:0.83990+0.01364
# [174]	train-rmse:0.55945+0.01869	test-rmse:0.83993+0.01352
# [175]	train-rmse:0.55876+0.01875	test-rmse:0.83984+0.01347
# [176]	train-rmse:0.55758+0.01890	test-rmse:0.83972+0.01338
# [177]	train-rmse:0.55663+0.01900	test-rmse:0.83964+0.01331
# [178]	train-rmse:0.55591+0.01913	test-rmse:0.83948+0.01322
# [179]	train-rmse:0.55494+0.01928	test-rmse:0.83927+0.01317
# [180]	train-rmse:0.55421+0.01945	test-rmse:0.83911+0.01315
# [181]	train-rmse:0.55364+0.01963	test-rmse:0.83905+0.01309
# [182]	train-rmse:0.55276+0.01946	test-rmse:0.83886+0.01304
# [183]	train-rmse:0.55180+0.01950	test-rmse:0.83872+0.01291
# [184]	train-rmse:0.55099+0.01972	test-rmse:0.83867+0.01289
# [185]	train-rmse:0.54994+0.01989	test-rmse:0.83861+0.01274
# [186]	train-rmse:0.54939+0.01997	test-rmse:0.83861+0.01259
# [187]	train-rmse:0.54860+0.02011	test-rmse:0.83855+0.01259
# [188]	train-rmse:0.54783+0.02030	test-rmse:0.83845+0.01260
# [189]	train-rmse:0.54732+0.02038	test-rmse:0.83842+0.01260
# [190]	train-rmse:0.54652+0.02053	test-rmse:0.83830+0.01256
# [191]	train-rmse:0.54576+0.02044	test-rmse:0.83820+0.01248
# [192]	train-rmse:0.54529+0.02048	test-rmse:0.83812+0.01238
# [193]	train-rmse:0.54470+0.02044	test-rmse:0.83804+0.01242
# [194]	train-rmse:0.54418+0.02056	test-rmse:0.83796+0.01236
# [195]	train-rmse:0.54317+0.02088	test-rmse:0.83794+0.01230
# [196]	train-rmse:0.54255+0.02096	test-rmse:0.83798+0.01229
# [197]	train-rmse:0.54176+0.02111	test-rmse:0.83790+0.01229
# [198]	train-rmse:0.54119+0.02137	test-rmse:0.83783+0.01221
# [199]	train-rmse:0.54054+0.02159	test-rmse:0.83774+0.01216
# [200]	train-rmse:0.53978+0.02181	test-rmse:0.83757+0.01208
# [201]	train-rmse:0.53892+0.02179	test-rmse:0.83753+0.01211
# [202]	train-rmse:0.53836+0.02196	test-rmse:0.83750+0.01204
# [203]	train-rmse:0.53777+0.02211	test-rmse:0.83742+0.01195
# [204]	train-rmse:0.53677+0.02249	test-rmse:0.83731+0.01197
# [205]	train-rmse:0.53597+0.02275	test-rmse:0.83730+0.01190
# [206]	train-rmse:0.53526+0.02307	test-rmse:0.83718+0.01185
# [207]	train-rmse:0.53439+0.02293	test-rmse:0.83729+0.01180
# [208]	train-rmse:0.53393+0.02295	test-rmse:0.83725+0.01178
# [209]	train-rmse:0.53327+0.02287	test-rmse:0.83725+0.01169
# [210]	train-rmse:0.53273+0.02283	test-rmse:0.83721+0.01168
# [211]	train-rmse:0.53211+0.02298	test-rmse:0.83707+0.01169
# [212]	train-rmse:0.53154+0.02317	test-rmse:0.83709+0.01159
# [213]	train-rmse:0.53093+0.02342	test-rmse:0.83708+0.01154
# [214]	train-rmse:0.52999+0.02349	test-rmse:0.83699+0.01151
# [215]	train-rmse:0.52937+0.02341	test-rmse:0.83705+0.01158
# [216]	train-rmse:0.52886+0.02356	test-rmse:0.83698+0.01151
# [217]	train-rmse:0.52812+0.02371	test-rmse:0.83696+0.01152
# [218]	train-rmse:0.52749+0.02361	test-rmse:0.83696+0.01145
# [219]	train-rmse:0.52675+0.02376	test-rmse:0.83684+0.01154
# [220]	train-rmse:0.52613+0.02390	test-rmse:0.83668+0.01144
# [221]	train-rmse:0.52568+0.02397	test-rmse:0.83660+0.01143
# [222]	train-rmse:0.52514+0.02402	test-rmse:0.83654+0.01145
# [223]	train-rmse:0.52469+0.02403	test-rmse:0.83654+0.01144
# [224]	train-rmse:0.52394+0.02407	test-rmse:0.83648+0.01145
# [225]	train-rmse:0.52328+0.02423	test-rmse:0.83639+0.01135
# [226]	train-rmse:0.52274+0.02450	test-rmse:0.83639+0.01137
# [227]	train-rmse:0.52226+0.02455	test-rmse:0.83637+0.01134
# [228]	train-rmse:0.52155+0.02487	test-rmse:0.83627+0.01131
# [229]	train-rmse:0.52103+0.02505	test-rmse:0.83622+0.01125
# [230]	train-rmse:0.52048+0.02525	test-rmse:0.83622+0.01116
# [231]	train-rmse:0.51978+0.02533	test-rmse:0.83624+0.01114
# [232]	train-rmse:0.51913+0.02534	test-rmse:0.83612+0.01109
# [233]	train-rmse:0.51847+0.02540	test-rmse:0.83612+0.01104
# [234]	train-rmse:0.51782+0.02553	test-rmse:0.83607+0.01104
# [235]	train-rmse:0.51723+0.02542	test-rmse:0.83602+0.01094
# [236]	train-rmse:0.51672+0.02539	test-rmse:0.83589+0.01093
# [237]	train-rmse:0.51601+0.02533	test-rmse:0.83585+0.01090
# [238]	train-rmse:0.51547+0.02552	test-rmse:0.83573+0.01078
# [239]	train-rmse:0.51483+0.02548	test-rmse:0.83572+0.01070
# [240]	train-rmse:0.51447+0.02561	test-rmse:0.83565+0.01066
# [241]	train-rmse:0.51401+0.02556	test-rmse:0.83563+0.01067
# [242]	train-rmse:0.51340+0.02563	test-rmse:0.83563+0.01075
# [243]	train-rmse:0.51293+0.02553	test-rmse:0.83561+0.01072
# [244]	train-rmse:0.51219+0.02587	test-rmse:0.83547+0.01065
# [245]	train-rmse:0.51163+0.02582	test-rmse:0.83549+0.01071
# [246]	train-rmse:0.51106+0.02598	test-rmse:0.83546+0.01067
# [247]	train-rmse:0.51047+0.02600	test-rmse:0.83545+0.01066
# [248]	train-rmse:0.50999+0.02618	test-rmse:0.83535+0.01054
# [249]	train-rmse:0.50961+0.02625	test-rmse:0.83535+0.01054
# [250]	train-rmse:0.50915+0.02623	test-rmse:0.83531+0.01053
# [251]	train-rmse:0.50861+0.02614	test-rmse:0.83523+0.01051
# [252]	train-rmse:0.50811+0.02634	test-rmse:0.83514+0.01040
# [253]	train-rmse:0.50749+0.02626	test-rmse:0.83523+0.01035
# [254]	train-rmse:0.50691+0.02622	test-rmse:0.83527+0.01032
# [255]	train-rmse:0.50640+0.02651	test-rmse:0.83520+0.01028
# [256]	train-rmse:0.50592+0.02672	test-rmse:0.83526+0.01021
# [257]	train-rmse:0.50540+0.02668	test-rmse:0.83517+0.01018
# [258]	train-rmse:0.50496+0.02685	test-rmse:0.83506+0.01008
# [259]	train-rmse:0.50447+0.02681	test-rmse:0.83497+0.01002
# [260]	train-rmse:0.50391+0.02673	test-rmse:0.83502+0.01006
# [261]	train-rmse:0.50331+0.02666	test-rmse:0.83506+0.01010
# [262]	train-rmse:0.50254+0.02686	test-rmse:0.83507+0.01001
# [263]	train-rmse:0.50206+0.02697	test-rmse:0.83500+0.00999
# [264]	train-rmse:0.50167+0.02709	test-rmse:0.83499+0.00994
# [265]	train-rmse:0.50100+0.02709	test-rmse:0.83488+0.00993
# [266]	train-rmse:0.50056+0.02708	test-rmse:0.83485+0.00992
# [267]	train-rmse:0.50005+0.02717	test-rmse:0.83484+0.00985
# [268]	train-rmse:0.49952+0.02736	test-rmse:0.83474+0.00981
# [269]	train-rmse:0.49905+0.02748	test-rmse:0.83476+0.00986
# [270]	train-rmse:0.49846+0.02764	test-rmse:0.83471+0.00981
# [271]	train-rmse:0.49790+0.02773	test-rmse:0.83470+0.00987
# [272]	train-rmse:0.49736+0.02773	test-rmse:0.83467+0.00984
# [273]	train-rmse:0.49690+0.02778	test-rmse:0.83462+0.00980
# [274]	train-rmse:0.49642+0.02773	test-rmse:0.83463+0.00976
# [275]	train-rmse:0.49581+0.02788	test-rmse:0.83466+0.00972
# [276]	train-rmse:0.49539+0.02791	test-rmse:0.83471+0.00968
# [277]	train-rmse:0.49481+0.02769	test-rmse:0.83471+0.00962
# [278]	train-rmse:0.49432+0.02798	test-rmse:0.83467+0.00955
# [279]	train-rmse:0.49375+0.02806	test-rmse:0.83457+0.00953
# [280]	train-rmse:0.49313+0.02823	test-rmse:0.83461+0.00957
# [281]	train-rmse:0.49261+0.02827	test-rmse:0.83456+0.00948
# [282]	train-rmse:0.49208+0.02816	test-rmse:0.83449+0.00946
# [283]	train-rmse:0.49177+0.02824	test-rmse:0.83445+0.00939
# [284]	train-rmse:0.49134+0.02840	test-rmse:0.83435+0.00935
# [285]	train-rmse:0.49067+0.02835	test-rmse:0.83439+0.00939
# [286]	train-rmse:0.49031+0.02832	test-rmse:0.83439+0.00936
# [287]	train-rmse:0.48981+0.02838	test-rmse:0.83427+0.00933
# [288]	train-rmse:0.48927+0.02845	test-rmse:0.83425+0.00937
# [289]	train-rmse:0.48897+0.02846	test-rmse:0.83424+0.00937
# [290]	train-rmse:0.48848+0.02858	test-rmse:0.83428+0.00936
# [291]	train-rmse:0.48804+0.02854	test-rmse:0.83427+0.00936
# [292]	train-rmse:0.48757+0.02850	test-rmse:0.83428+0.00934
# [293]	train-rmse:0.48714+0.02858	test-rmse:0.83425+0.00936
# [294]	train-rmse:0.48662+0.02863	test-rmse:0.83420+0.00933
# [295]	train-rmse:0.48619+0.02864	test-rmse:0.83424+0.00931
# [296]	train-rmse:0.48573+0.02884	test-rmse:0.83425+0.00932
# [297]	train-rmse:0.48517+0.02889	test-rmse:0.83421+0.00923
# [298]	train-rmse:0.48470+0.02883	test-rmse:0.83421+0.00916
# [299]	train-rmse:0.48425+0.02885	test-rmse:0.83415+0.00918
# [300]	train-rmse:0.48363+0.02896	test-rmse:0.83416+0.00918
# [301]	train-rmse:0.48317+0.02905	test-rmse:0.83416+0.00914
# [302]	train-rmse:0.48274+0.02907	test-rmse:0.83411+0.00915
# [303]	train-rmse:0.48234+0.02906	test-rmse:0.83410+0.00920
# [304]	train-rmse:0.48204+0.02913	test-rmse:0.83411+0.00912
# [305]	train-rmse:0.48139+0.02898	test-rmse:0.83413+0.00914
# [306]	train-rmse:0.48093+0.02898	test-rmse:0.83415+0.00921
# [307]	train-rmse:0.48023+0.02896	test-rmse:0.83422+0.00919
# [308]	train-rmse:0.47991+0.02909	test-rmse:0.83419+0.00917
# [309]	train-rmse:0.47958+0.02919	test-rmse:0.83419+0.00915
# [310]	train-rmse:0.47910+0.02915	test-rmse:0.83418+0.00915
# [311]	train-rmse:0.47852+0.02937	test-rmse:0.83425+0.00913
# [312]	train-rmse:0.47787+0.02938	test-rmse:0.83423+0.00914
# [313]	train-rmse:0.47755+0.02946	test-rmse:0.83424+0.00908
# [314]	train-rmse:0.47702+0.02959	test-rmse:0.83427+0.00912
# [315]	train-rmse:0.47672+0.02968	test-rmse:0.83429+0.00912
# [316]	train-rmse:0.47632+0.02975	test-rmse:0.83427+0.00912
# [317]	train-rmse:0.47583+0.02995	test-rmse:0.83422+0.00910
# [318]	train-rmse:0.47540+0.02991	test-rmse:0.83424+0.00910
# [319]	train-rmse:0.47500+0.03008	test-rmse:0.83418+0.00910
# [320]	train-rmse:0.47467+0.02998	test-rmse:0.83414+0.00904
# [321]	train-rmse:0.47434+0.03004	test-rmse:0.83414+0.00897
# [322]	train-rmse:0.47390+0.03015	test-rmse:0.83408+0.00890
# [323]	train-rmse:0.47350+0.03021	test-rmse:0.83404+0.00891
# [324]	train-rmse:0.47301+0.03031	test-rmse:0.83397+0.00898
# [325]	train-rmse:0.47258+0.03037	test-rmse:0.83394+0.00901
# [326]	train-rmse:0.47200+0.03037	test-rmse:0.83392+0.00901
# [327]	train-rmse:0.47138+0.03060	test-rmse:0.83387+0.00896
# [328]	train-rmse:0.47070+0.03055	test-rmse:0.83391+0.00889
# [329]	train-rmse:0.47032+0.03066	test-rmse:0.83390+0.00889
# [330]	train-rmse:0.46979+0.03085	test-rmse:0.83396+0.00882
# [331]	train-rmse:0.46947+0.03093	test-rmse:0.83401+0.00884
# [332]	train-rmse:0.46904+0.03099	test-rmse:0.83403+0.00884
# [333]	train-rmse:0.46858+0.03088	test-rmse:0.83407+0.00881
# [334]	train-rmse:0.46806+0.03090	test-rmse:0.83396+0.00877
# [335]	train-rmse:0.46764+0.03099	test-rmse:0.83392+0.00870
# [336]	train-rmse:0.46721+0.03092	test-rmse:0.83395+0.00869
# [337]	train-rmse:0.46681+0.03095	test-rmse:0.83391+0.00872
# [338]	train-rmse:0.46657+0.03099	test-rmse:0.83391+0.00869
# [339]	train-rmse:0.46618+0.03095	test-rmse:0.83392+0.00872
# [340]	train-rmse:0.46579+0.03110	test-rmse:0.83390+0.00867
# [341]	train-rmse:0.46539+0.03115	test-rmse:0.83387+0.00871
# [342]	train-rmse:0.46493+0.03118	test-rmse:0.83382+0.00867
# [343]	train-rmse:0.46446+0.03118	test-rmse:0.83386+0.00859
# [344]	train-rmse:0.46389+0.03099	test-rmse:0.83391+0.00853
# [345]	train-rmse:0.46354+0.03103	test-rmse:0.83393+0.00851
# [346]	train-rmse:0.46307+0.03105	test-rmse:0.83395+0.00851
# [347]	train-rmse:0.46265+0.03098	test-rmse:0.83395+0.00849
# [348]	train-rmse:0.46223+0.03112	test-rmse:0.83395+0.00847
# [349]	train-rmse:0.46198+0.03115	test-rmse:0.83396+0.00845
# [350]	train-rmse:0.46168+0.03129	test-rmse:0.83398+0.00846
# [351]	train-rmse:0.46104+0.03160	test-rmse:0.83404+0.00844
# [352]	train-rmse:0.46053+0.03174	test-rmse:0.83400+0.00842
# [353]	train-rmse:0.46003+0.03189	test-rmse:0.83392+0.00846
# [354]	train-rmse:0.45959+0.03180	test-rmse:0.83390+0.00844
# [355]	train-rmse:0.45913+0.03191	test-rmse:0.83386+0.00846
# [356]	train-rmse:0.45869+0.03192	test-rmse:0.83385+0.00841
# [357]	train-rmse:0.45826+0.03189	test-rmse:0.83379+0.00852
# [358]	train-rmse:0.45767+0.03193	test-rmse:0.83383+0.00847
# [359]	train-rmse:0.45735+0.03209	test-rmse:0.83384+0.00845
# [360]	train-rmse:0.45691+0.03188	test-rmse:0.83389+0.00838
# [361]	train-rmse:0.45658+0.03193	test-rmse:0.83384+0.00841
# [362]	train-rmse:0.45623+0.03202	test-rmse:0.83382+0.00842
# [363]	train-rmse:0.45580+0.03210	test-rmse:0.83382+0.00845
# [364]	train-rmse:0.45526+0.03208	test-rmse:0.83370+0.00836
# [365]	train-rmse:0.45470+0.03187	test-rmse:0.83370+0.00835
# [366]	train-rmse:0.45432+0.03185	test-rmse:0.83367+0.00836
# [367]	train-rmse:0.45376+0.03175	test-rmse:0.83363+0.00832
# [368]	train-rmse:0.45328+0.03182	test-rmse:0.83358+0.00826
# [369]	train-rmse:0.45300+0.03190	test-rmse:0.83361+0.00825
# [370]	train-rmse:0.45242+0.03189	test-rmse:0.83372+0.00826
# [371]	train-rmse:0.45192+0.03192	test-rmse:0.83363+0.00829
# [372]	train-rmse:0.45155+0.03190	test-rmse:0.83359+0.00825
# [373]	train-rmse:0.45112+0.03196	test-rmse:0.83350+0.00825
# [374]	train-rmse:0.45087+0.03195	test-rmse:0.83349+0.00825
# [375]	train-rmse:0.45053+0.03195	test-rmse:0.83348+0.00823
# [376]	train-rmse:0.45002+0.03191	test-rmse:0.83347+0.00816
# [377]	train-rmse:0.44951+0.03206	test-rmse:0.83351+0.00820
# [378]	train-rmse:0.44915+0.03215	test-rmse:0.83352+0.00816
# [379]	train-rmse:0.44889+0.03217	test-rmse:0.83353+0.00818
# [380]	train-rmse:0.44849+0.03226	test-rmse:0.83357+0.00813
# [381]	train-rmse:0.44819+0.03232	test-rmse:0.83349+0.00810
# [382]	train-rmse:0.44784+0.03226	test-rmse:0.83343+0.00816
# [383]	train-rmse:0.44752+0.03240	test-rmse:0.83342+0.00811
# [384]	train-rmse:0.44701+0.03233	test-rmse:0.83339+0.00817
# [385]	train-rmse:0.44652+0.03225	test-rmse:0.83337+0.00818
# [386]	train-rmse:0.44615+0.03218	test-rmse:0.83334+0.00817
# [387]	train-rmse:0.44574+0.03221	test-rmse:0.83330+0.00815
# [388]	train-rmse:0.44550+0.03218	test-rmse:0.83330+0.00812
# [389]	train-rmse:0.44507+0.03227	test-rmse:0.83326+0.00813
# [390]	train-rmse:0.44472+0.03228	test-rmse:0.83326+0.00814
# [391]	train-rmse:0.44425+0.03236	test-rmse:0.83325+0.00814
# [392]	train-rmse:0.44389+0.03244	test-rmse:0.83321+0.00815
# [393]	train-rmse:0.44342+0.03262	test-rmse:0.83324+0.00818
# [394]	train-rmse:0.44296+0.03261	test-rmse:0.83321+0.00816
# [395]	train-rmse:0.44256+0.03262	test-rmse:0.83327+0.00820
# [396]	train-rmse:0.44197+0.03271	test-rmse:0.83316+0.00828
# [397]	train-rmse:0.44157+0.03288	test-rmse:0.83317+0.00832
# [398]	train-rmse:0.44117+0.03303	test-rmse:0.83312+0.00836
# [399]	train-rmse:0.44077+0.03309	test-rmse:0.83301+0.00836

# %%
cv_results = pd.DataFrame(columns=['train-rmse-mean', 'train-rmse-std', 'test-rmse-mean', 'test-rmse-std'])

# %%
cv_result.shape[0]
# Out:
# 400

# %%
cv_results = cv_results.append(cv_result.iloc[-1])
cv_results = cv_results.rename(index={cv_result.shape[0]-1:"ESR1"})

# %%
cv_results
# Out:
#       train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# ESR1         0.440771        0.033091        0.833013       0.008361

# %%
cv_result
# Out:
#      train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0           1.103808        0.030436        1.107101       0.030336
# 1           1.091998        0.029685        1.098778       0.029264
# 2           1.080599        0.028933        1.090551       0.028549
# 3           1.069606        0.028206        1.082727       0.027366
# 4           1.058709        0.027775        1.075141       0.027009
# ..               ...             ...             ...            ...
# 395         0.442560        0.032622        0.833268       0.008203
# 396         0.441974        0.032712        0.833164       0.008275
# 397         0.441570        0.032884        0.833173       0.008319
# 398         0.441172        0.033026        0.833115       0.008358
# 399         0.440771        0.033091        0.833013       0.008361
#
# [400 rows x 4 columns]

# %%
type(["ss", "sa"]) is list
# Out:
# True

# %%
import src.model_builder as mb

# %%
model_x = mb.CellLevelModel("Cancer", ["ESR1"])

# %%
model_x.build_model(params, cv=0)
# Out:
# CANCER
# ['ESR1']
# -----ESR1-----
# Building predicting model for ESR1

# %%
model_x.plot_results("ESR1")

# %%
model_x.shap_analysis("ESR1")

# %%
model_x.explainer.shap_values
# Out:
# <bound method Tree.shap_values of <shap.explainers._tree.Tree object at 0x7fd3b81fd400>>

# %%
shap_values = model_x.shap_vals["ESR1"]

# %%
model_x.shap_plot_bar("ESR1")

# %%
model_x.shap_plot_beeswarm("ESR1")

# %%
model_x.shap_scatter("ESR1", ["GFRA1", "TFF3", "ANKRD30A"]);

# %%
index = [i for i, col in enumerate(X.columns) if col == "TFF3"][0]

# %%
from shap.utils._general import approximate_interactions, potential_interactions

# %%
"GFRA1" in model_x.datasets["ESR1"][2].iloc[:,900:999].columns
# Out:
# True

# %%
interactions = potential_interactions(shap_values[:,index], shap_values)

# %%
ranked_interactions
# Out:
# array([978, 958, 592, 370, 209, 392, 742,  38, 996, 328, 504, 929, 828,
#        994, 765, 924, 584, 739, 340, 330, 950, 314, 204, 679, 203, 789,
#         68, 914,  52, 855, 975, 868, 969, 147, 758, 316, 464, 471, 122,
#        382, 772, 127, 408, 233, 562, 426, 887, 777, 723, 716, 939, 185,
#        266, 393, 541, 712, 948, 549, 156, 462, 822, 563, 827, 972, 251,
#        820,  15, 671, 998, 415, 457, 363, 949, 117, 876, 788, 445, 920,
#        436, 422,  48, 371, 237, 866, 730, 664, 961,  43, 816, 848,  14,
#        756, 444, 372,  30, 912, 565, 188, 990, 242, 743, 550, 355,  96,
#        446, 292, 339, 993, 225, 532, 348, 448, 624, 442, 139, 797, 232,
#        535, 529, 169, 973, 869, 632, 731, 693, 398, 930, 779, 542, 629,
#        709, 142,  36, 218,  26, 598, 428,  71, 152, 374, 649, 720, 441,
#        983, 124, 397, 608, 773, 965, 613, 832, 481, 886, 576, 997, 627,
#        849, 802, 976, 798, 526, 740, 656, 143, 842, 230, 968, 727, 493,
#        546, 982,  10, 323, 970, 501, 704, 473, 668, 781, 985, 905, 186,
#        409, 308, 641,   3, 621, 692, 433, 454, 619, 610, 189, 821,  74,
#        790, 751, 499, 963, 467, 468, 299,  32, 325, 784, 609, 109, 364,
#        674, 761, 724, 908, 625, 144, 582, 196,  95, 907, 197, 424, 708,
#        814,  23, 572, 879, 971,  98, 475, 150, 118, 280, 880,  72, 670,
#        919, 451, 678, 575, 496, 234, 440, 357, 759, 500, 763,  12, 458,
#        324, 184, 332,  81, 293, 537, 577,  83, 807,  40, 995, 569, 615,
#        932, 469, 839, 478, 646, 246, 495, 922, 680,  94, 320, 840, 217,
#        895,  29, 538,  82, 595, 258,  69, 319, 752, 155, 652, 815, 918,
#          4, 281,  76, 162, 864,  53,  11, 334, 516, 718, 676, 548,  35,
#          8, 134, 358, 271, 626, 734, 423, 675, 483, 421, 536, 695, 689,
#        847,  79, 755, 249, 749, 979, 129, 176, 418,  92, 239, 116, 406,
#         49, 623, 236, 304, 902, 347, 947, 275, 951, 741, 957, 257, 614,
#        296, 871, 173, 212, 927, 545, 774, 303, 573, 954, 956, 981, 628,
#         77, 126, 403, 931,  46, 953, 290, 937,  56, 911, 719, 843, 599,
#        214, 841, 980, 684, 449, 282, 616, 916, 244, 350, 750, 753, 390,
#        640, 248, 697, 170, 747,  25,  41, 618, 764, 647, 571, 894, 376,
#        171, 492, 335, 854, 900, 140, 518, 226, 830, 389, 497, 527, 211,
#        121, 265, 959, 429, 224, 396, 984, 833, 942, 375, 771, 891, 782,
#        570, 192, 311,  16, 315, 229,  97, 722, 796, 206,  93, 111, 131,
#        318, 161, 513, 706, 896, 240, 834, 502, 702,  59, 220, 736, 336,
#        174, 404, 857, 384, 352, 630, 603, 114, 194, 380, 378, 465, 539,
#         17, 198, 412, 661, 564, 778, 870, 437, 803, 566, 159,  84, 601,
#        141, 104, 534, 940, 799, 850, 103, 826, 757,  89, 505, 506, 991,
#        935, 252, 865, 711, 607, 768,  50, 967, 587, 559, 597, 463, 890,
#        112, 554, 312, 748, 474, 606, 921, 666, 400, 713, 605,  88, 901,
#        555, 508, 216, 151, 728, 125, 934, 326, 343, 838, 270, 455, 561,
#         55, 877,  28, 528,  37, 522, 368,  64, 175, 872, 703, 594, 925,
#        732, 377, 825,  27, 831, 524,  80,  70, 780, 472, 733, 484, 862,
#        631, 263, 811, 154,  42, 190,  60, 123, 858,  20, 254,  87, 498,
#        892, 219, 960, 654, 344, 491, 288, 401, 846, 791, 269,  34, 989,
#        909, 453, 379, 148, 952, 521, 447, 461, 746, 845, 823,  47, 829,
#        645,  75, 342, 520, 677, 636, 551, 450,  21, 137,  45, 510, 388,
#        673, 341, 642, 889,  44, 699, 160,  73,  86, 735, 785, 477, 179,
#        261, 107, 988, 620, 459, 102, 241, 362, 698, 883, 837, 413, 691,
#        187, 385,  57, 659, 657, 737, 228, 256, 874,  24, 586, 210, 208,
#        881, 884,  51, 590, 769, 583, 283, 824, 875, 309,  91,   7, 285,
#        660, 899, 729, 172, 987,  66, 787, 690, 933,   6, 259, 804, 715,
#        333, 337, 346, 480, 452, 279,  62, 762, 132, 383, 317, 120, 511,
#        885, 543, 806, 913, 533, 277, 544, 726, 812, 581, 430, 904, 167,
#        149, 365, 923, 634, 602, 611, 856, 253, 557, 354,  61, 568, 643,
#        221, 115, 417, 494, 238, 195, 770, 345, 701, 515, 633, 873, 813,
#        612, 917, 588, 276, 420, 604, 669,  90, 794, 694, 419, 651, 859,
#        302,   1, 966, 470, 178, 136, 792, 213, 667, 235, 801, 138, 844,
#        488, 946, 130, 201, 291, 264, 893,  85, 267, 177, 411, 361, 395,
#        286, 146, 745, 596,  39, 655, 128, 394, 567, 205, 523, 808, 707,
#         22, 767, 490, 941, 305, 910, 255, 560, 861, 818,  67, 574, 817,
#        888, 593, 725, 658, 556, 351, 405, 360, 153, 432, 717, 133, 653,
#        294, 897, 247,   9, 321, 663, 635, 215, 273, 944, 227, 105, 322,
#        760,  13, 525, 644, 166, 349, 207, 903, 926, 434, 435, 110, 585,
#        863, 157,   0, 738, 589, 754, 622, 915, 682, 805, 637, 353, 686,
#        744, 466, 776, 456, 243, 381, 262, 416, 938, 766,  54, 835, 191,
#        278, 369, 482, 775, 943, 819, 407, 489, 509, 547, 665, 809,   5,
#        366, 882, 359, 106, 662, 530, 431, 687, 999, 836, 410, 617, 367,
#        289, 878,  19, 135, 158, 100,  18, 222, 180, 145, 386, 443, 638,
#         63, 507, 650, 517, 867, 685,   2, 274, 945, 356,  78, 540, 245,
#         99, 810, 485, 301, 579, 165, 906, 307, 786, 306, 683, 373, 260,
#        688, 519, 202,  58, 721, 272, 313, 580, 578, 783, 119, 860,  65,
#        531, 600, 231, 223, 113, 696, 425, 486, 295, 460, 327, 164, 193,
#        851, 479, 700, 182, 181, 438, 503, 681, 101, 439, 898, 387, 639,
#        200, 974, 287, 992, 427, 329, 168, 962, 487, 284, 705, 199, 300,
#        476, 795, 977, 512, 986, 183, 514, 399, 672, 402, 928, 800, 331,
#        648, 936, 553,  31, 853, 338, 552, 710, 955, 793, 163, 298, 250,
#        591,  33, 558, 414, 310, 852, 714, 268, 108, 297, 391, 964])

# %%
X.columns
# Out:
# Index(['TMEM181', 'CLGN', 'BAG1', 'CENPP', 'PLS1', 'IER2', 'SULT1A1', 'MOK',
#        'MISP', 'CCDC57',
#        ...
#        'PI15', 'SPDEF', 'LINC00993', 'MLPH', 'AR', 'CAPN8', 'GFRA1', 'AFF3',
#        'STC2', 'ANKRD30A'],
#       dtype='object', name='Genes', length=1000)

# %%
shap_values.values
# Out:
# array([[ 9.0387410e-05, -5.4046902e-04, -1.1963300e-05, ...,
#         -7.8893118e-03, -6.4169336e-03, -1.4612371e-02],
#        [ 9.5716467e-05,  1.1416404e-04, -1.1963300e-05, ...,
#         -7.5854780e-03, -6.5163528e-03, -1.4718538e-02],
#        [ 9.3165814e-05, -5.3894368e-04, -1.1963300e-05, ...,
#         -7.8859748e-03, -7.0530851e-03, -1.4684780e-02],
#        ...,
#        [-3.9723735e-05, -5.3620373e-04, -1.1963300e-05, ...,
#         -7.7811722e-03, -6.8641999e-03, -1.4705786e-02],
#        [ 9.3165814e-05, -5.3894368e-04, -1.1963300e-05, ...,
#         -8.6589539e-03, -6.8601710e-03, -1.4448310e-02],
#        [-3.7832750e-05, -5.3545454e-04, -1.1963300e-05, ...,
#         -7.8455415e-03, -7.8554386e-03, -1.4859707e-02]], dtype=float32)

# %%
interactions = approximate_interactions(index, shap_values.values, model_x.datasets["ESR1"][2])

# %%
params = {'objective': 'reg:squarederror',
 'base_score': 0.5,
 'booster': 'gbtree',
 'colsample_bylevel': 1,
 'colsample_bynode': 1,
 'colsample_bytree': 1,
 'gamma': 0,
 'gpu_id': -1,
 'importance_type': 'gain',
 'interaction_constraints': '',
 'learning_rate': 0.025,
 'max_delta_step': 0,
 'max_depth': 4,
 'min_child_weight': 5,
 'missing': float("nan"),
 'monotone_constraints': '()',
 'n_estimators': 1000,
 'n_jobs': 90,
 'num_parallel_tree': 1,
 'random_state': 27,
 'reg_alpha': 0,
 'reg_lambda': 1,
 'scale_pos_weight': 1,
 'subsample': 1,
 'tree_method': 'exact',
 'validate_parameters': 1,
 'verbosity': 0,
 'seed': None}

# %%
d = pd.DataFrame(np.arange(36).reshape((9,4)), columns = ["a", "b", "c", "d"])

# %%
d["c"].reshape(3,3)
# Out:
# 0     2
# 1     6
# 2    10
# 3    14
# 4    18
# 5    22
# 6    26
# 7    30
# 8    34
# Name: c, dtype: int64
